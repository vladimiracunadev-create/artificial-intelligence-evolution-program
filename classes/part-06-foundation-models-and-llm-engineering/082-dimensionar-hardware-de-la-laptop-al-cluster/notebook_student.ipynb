# %% [markdown]
# # 082 — Dimensionar hardware: de la laptop al clúster
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Pesos.** Un modelo de 13B: calcula los GB que ocupa en FP32,
# BF16, INT8 y GGUF Q4_K_M (0,57 B/parámetro). ¿Cuáles caben en una GPU de 24 GB
# dejando 4 GB para KV, activaciones y overhead?
#
# **Ejercicio 2 — El sumando olvidado.** Modelo tipo Llama-8B: 32 capas, GQA con 8
# cabezas KV, `d_head` = 128, KV en FP16. Calcula el KV por token, y el KV total
# para 16 sesiones concurrentes de 8 192 tokens. Súmalo a los pesos en Q4 (4,6 GB)
# más 2 GB de overhead: ¿entra en una RTX 4090 de 24 GB?
#
# **Ejercicio 3 — Entrenamiento.** Con 16 B/parámetro para fine-tuning completo,
# ¿cuánta memoria pide un 8B? Compáralo con QLoRA (base en 4 bits ≈ 0,5 B/parámetro
# más ~2 GB de adaptadores y activaciones). ¿Cuántas H100 de 80 GB hacen falta en
# cada caso?
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("evaluation",
# seed=82)` y valida el contrato. ¿Por qué dimensionar es un problema de
# *evaluación* y no una simple división?

# %%
# TU RESPUESTA AQUÍ
# Ejercicio 1:
n_params = 13e9
bytes_por_param = {"FP32": 4, "BF16": 2, "INT8": 1, "Q4_K_M": 0.57}
# pesos_gb = ...

# Ejercicio 2:
capas, kv_heads, d_head, b = 32, 8, 128, 2
sesiones, contexto = 16, 8192
# kv_por_token = ...
# kv_total_gb = ...
# total_gb = ...

# Ejercicio 3:
# full_ft_gb = 8e9 * 16 / 1e9
# qlora_gb = ...

# Ejercicio 4:
# result = run_lab("evaluation", seed=82)
# assert ...

# %% [markdown]
# ## Reflexión
#
# 1. En el ejercicio 2 el KV cache triplica a los pesos. ¿Qué tres palancas tienes
#    para que quepa, y cuál degrada menos el producto?
# 2. Tu equipo pide "una GPU más grande" porque el modelo no entra. ¿Qué preguntas
#    harías antes de aprobar la compra?
# 3. ¿En qué condiciones una máquina con memoria unificada de 192 GB es mejor
#    elección que dos GPUs de 48 GB, y en cuáles es claramente peor?
