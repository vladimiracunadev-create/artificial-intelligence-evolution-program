# %% [markdown]
# # 083 — El ecosistema del cómputo: fabricantes, nubes y laboratorios
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Auditar una afirmación.** Un proveedor afirma: *"3× el throughput
# de una H100 en LLM"*. La letra pequeña dice: FP8 con dispersión 2:4, modelo propio
# de 7B, lote 512, contexto 256, medición interna. Aplica las cinco preguntas y
# redacta la reformulación honesta en una sola frase.
#
# **Ejercicio 2 — Mapa de dependencias.** Tu servicio usa un modelo abierto de 70B,
# servido con vLLM sobre GPUs NVIDIA alquiladas en una sola región de un único
# hiperescalar. Lista la dependencia de cada una de las cuatro capas y cuenta en
# cuántas tienes un solo proveedor viable. ¿Cuál eliminarías primero y a qué costo?
#
# **Ejercicio 3 — Clasificar por madurez.** Clasifica como `current`,
# `needs_replication` o `unverified`: (a) una especificación publicada por el
# fabricante con datasheet; (b) un resultado de MLPerf verificado; (c) un hilo en
# redes con capturas de un benchmark casero; (d) un preprint sin código. Justifica
# usando el mismo criterio que aplica el laboratorio.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("frontier",
# seed=83)` y comprueba qué afirmaciones quedan fuera de
# `accepted_for_curriculum` y por qué.

# %%
# TU RESPUESTA AQUÍ
# Ejercicio 1: reformulación honesta
preguntas = ["precisión", "densa/dispersa", "lote y contexto", "modelo", "quién midió"]
# reformulacion = "..."

# Ejercicio 2: dependencias por capa
dependencias = {
    "fabricacion": None,
    "acelerador": None,
    "infraestructura": None,
    "modelo": None,
}
# proveedor_unico = ...

# Ejercicio 3:
afirmaciones = {"a": None, "b": None, "c": None, "d": None}

# Ejercicio 4:
# result = run_lab("frontier", seed=83)
# assert ...

# %% [markdown]
# ## Reflexión
#
# 1. ¿Cuál de las cuatro capas de tu propio proyecto es la más difícil de sustituir,
#    y qué tendrías que haber hecho distinto al empezar para que no lo fuera?
# 2. Un modelo con pesos abiertos elimina la dependencia de la capa 4. ¿Qué
#    dependencias *no* elimina, y por qué se confunden tan a menudo?
# 3. ¿Qué señal observable te haría revisar este mapa antes de la fecha prevista,
#    y cuál sería sólo ruido de anuncio?
