# %% [markdown]
# # 083 — El ecosistema del cómputo: fabricantes, nubes y laboratorios
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %% [markdown]
# ## 📖 Resumen de la materia
#
# - **Cuatro capas**: fabricación y HBM → aceleradores → infraestructura →
#   modelos, con el software (CUDA, ROCm, XLA, PyTorch) atravesándolas todas.
# - **El foso es el software**: CUDA acumula librerías, kernels y herramientas que
#   hacen cara la migración aunque otro chip ofrezca mejor precio por FLOP.
# - **Apuestas alternativas**: TPU y arreglos sistólicos; silicio propio de los
#   hiperescalares; Groq y Cerebras manteniendo pesos en SRAM en vez de HBM para
#   atacar el límite de ancho de banda de la clase 081.
# - **Restricciones no técnicas**: concentración de la fabricación avanzada,
#   controles de exportación y residencia de datos operan como requisitos de
#   diseño, no como noticias.
# - **Cinco preguntas** ante cualquier cifra: precisión, densa o dispersa, lote y
#   contexto, modelo exacto, y quién midió.
# - **Fecha**: este mapa describe 2026-08; la estructura dura, los nombres no.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %%
result = run_lab("frontier", seed=83)
show(result)

# %% [markdown]
# ## Reflexión
#
# 1. ¿Cuál de las cuatro capas de tu propio proyecto es la más difícil de sustituir,
#    y qué tendrías que haber hecho distinto al empezar para que no lo fuera?
# 2. Un modelo con pesos abiertos elimina la dependencia de la capa 4. ¿Qué
#    dependencias *no* elimina, y por qué se confunden tan a menudo?
# 3. ¿Qué señal observable te haría revisar este mapa antes de la fecha prevista,
#    y cuál sería sólo ruido de anuncio?
