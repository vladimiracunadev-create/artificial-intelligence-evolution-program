# %% [markdown]
# # 079 — Prompting, contexto y resultados estructurados
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Diseñar few-shot.** Escribe un prompt few-shot (2 ejemplos) para
# clasificar tickets en `facturacion` / `tecnico` / `otro`, eligiendo ejemplos que
# cubran un caso frontera (un ticket ambiguo). Explica por qué elegiste esos dos.
#
# **Ejercicio 2 — Predecir el fallo.** Un compañero pide: "Devuélveme los datos como
# JSON" sin esquema, sin ejemplo y sin validación. Lista 3 modos de fallo concretos
# que verá en producción y la capa de la "escalera de garantías" que corrige cada uno.
#
# **Ejercicio 3 — CoT a mano.** Resuelve como lo haría un modelo con CoT: "Un lote
# tiene 240 unidades; el 15 % está defectuoso y de los defectuosos el 40 % es
# reparable. ¿Cuántas unidades son irreparables?" Escribe la cadena paso a paso y
# la respuesta final.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("llm", seed=79)`,
# valida `kind`, `evidence`, `limitations`, y explica qué relación hay entre el
# contrato JSON del laboratorio y la salida estructurada vista en la clase.

# %%
# TU RESPUESTA AQUÍ
# Ejercicio 1: escribe el prompt como string multilínea.
prompt_fewshot = '''
...
'''

# Ejercicio 2:
# fallos = [("fallo", "capa correctora"), ...]

# Ejercicio 3:
# defectuosos = ...
# reparables = ...
# irreparables = ...

# Ejercicio 4:
# result = run_lab("llm", seed=79)
# assert ...

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué generar tokens intermedios (CoT) amplía la clase de problemas que el
#    modelo puede resolver respecto a responder en un solo salto?
# 2. La decodificación restringida garantiza JSON sintácticamente válido: ¿qué clase
#    de errores NO puede prevenir y cómo los atraparías?
# 3. Si un prompt funciona hoy y falla tras una actualización del modelo, ¿qué
#    prácticas de "prompt como código" te habrían protegido?
