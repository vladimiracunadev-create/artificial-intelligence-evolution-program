# %% [markdown]
# # 081 — Aceleradores, memoria y el límite real del cómputo
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Codo del roofline.** Una A100 de 80 GB alcanza 312 TFLOP/s densos
# en BF16 con 2,039 TB/s de ancho de banda. Calcula su punto de codo en FLOP/byte y
# compáralo con los 295 de la H100. ¿Qué acelerador tolera mejor una carga de baja
# intensidad aritmética?
#
# **Ejercicio 2 — Techo de tokens por segundo.** Un modelo de 8B en GGUF Q4_K_M
# ocupa 4,6 GB. Calcula el techo teórico de generación con lote 1 en una RTX 4090
# (1 008 GB/s) y en un Apple M4 Max (546 GB/s), y luego el valor esperable con un
# MBU del 70 %.
#
# **Ejercicio 3 — Lote necesario para llegar al codo.** Con `I = 2B/b`, ¿qué lote
# `B` hace falta en una H100 (codo 295) si los pesos están en FP16 (b = 2 bytes por
# parámetro)? ¿Y si están en Q4_K_M (b ≈ 0,57)? Explica por qué cuantizar *reduce*
# el lote necesario.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("observability",
# seed=81)` y valida el contrato. ¿Por qué el límite de esta clase es un problema
# de *observabilidad* y no sólo de arquitectura?

# %%
# TU RESPUESTA AQUÍ
# Ejercicio 1:
pico_a100_tflops, bw_a100_tbs = 312, 2.039
# codo_a100 = ...

# Ejercicio 2:
modelo_gb = 4.6
bw = {"rtx4090": 1008, "m4max": 546}  # GB/s
# techo = ...
# con_mbu = ...

# Ejercicio 3:
codo = 295
# lote_fp16 = ...
# lote_q4 = ...

# Ejercicio 4:
# result = run_lab("observability", seed=81)
# assert ...

# %% [markdown]
# ## Reflexión
#
# 1. Si tu servicio mide 480 tok/s y el techo teórico con lote 1 es 728, ¿qué
#    optimizaciones dejan de tener sentido y cuáles siguen valiendo la pena?
# 2. Un proveedor anuncia 2× los TFLOPS de la H100 con el mismo ancho de banda.
#    ¿Cuánto mejora tu decode con lote 1, y por qué?
# 3. ¿Por qué el prefill y el decode piden aceleradores con perfiles distintos, y
#    qué implicaría separarlos en dos flotas?
