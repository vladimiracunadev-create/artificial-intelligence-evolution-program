# %% [markdown]
# # 076 — Instruction tuning y datos de instrucciones
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Loss masking a mano.** Para el ejemplo con plantilla
# `<u> ¿2+2? </u> <a> 4 </a>` (9 tokens en total, la respuesta ocupa los 3 últimos:
# `<a>`, `4`, `</a>`), indica sobre qué posiciones se computa la pérdida y calcula L
# si el modelo asigna P(`<a>`) = 0,9, P(`4`) = 0,5, P(`</a>`) = 0,8.
#
# **Ejercicio 2 — Clasificar estrategias.** Para cada situación elige la estrategia de
# datos (demos humanas / FLAN multitarea / Self-Instruct / curación tipo LIMA) y
# justifica en una frase: (a) startup sin presupuesto de anotación; (b) laboratorio
# que quiere zero-shot robusto en tareas NLP; (c) equipo con 5 expertos legales y
# necesidad de tono impecable.
#
# **Ejercicio 3 — Filtro de Self-Instruct.** Se generaron 4 instrucciones candidatas;
# las semillas incluyen "Resume el siguiente texto". Candidatas: (1) "Resume este
# texto", (2) "Escribe un haiku sobre el mar", (3) "asdfgh", (4) "Traduce al francés
# la palabra 'libro'". Indica cuáles sobreviven a un filtro de deduplicación por
# similitud + validez, y por qué.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("llm", seed=76)` y
# comprueba `kind`, `evidence`, `limitations`. ¿Qué limitación del contrato conecta
# directamente con los riesgos de datos sintéticos vistos aquí?

# %%
# TU RESPUESTA AQUÍ
import math

# Ejercicio 1:
# posiciones_con_perdida = [...]
# L = ...

# Ejercicio 2: escribe tus elecciones y justificaciones.
# a = "..."
# b = "..."
# c = "..."

# Ejercicio 3:
# sobreviven = [...]

# Ejercicio 4:
# result = run_lab("llm", seed=76)
# assert ...

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué el loss masking cambia lo que el modelo aprende aunque el objetivo siga
#    siendo next-token, y qué pasaría sin él con diálogos largos de usuario?
# 2. FLAN mejora tareas nunca vistas: ¿qué evidencia daría para argumentar que el
#    modelo aprendió el "formato instrucción" y no las tareas concretas?
# 3. Si generas datos con Self-Instruct usando el mismo modelo que luego vas a
#    evaluar como juez, ¿qué sesgo introduces y cómo lo detectarías?
