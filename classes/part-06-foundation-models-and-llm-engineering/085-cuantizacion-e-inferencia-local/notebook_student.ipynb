# %% [markdown]
# # 085 — Cuantización e inferencia local
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — INT8 a mano.** Cuantiza simétricamente a INT8 el vector
# w = [0,12, −0,50, 0,25, −0,10]: calcula s = max|w|/127, los q enteros, los valores
# descuantizados x̂ y el error máximo. Verifica que el error ≤ s/2.
#
# **Ejercicio 2 — El outlier.** Repite el ejercicio 1 añadiendo w₅ = 8,0 con UNA
# escala global, y luego con dos grupos ([w₁..w₄] y [w₅] con escalas propias).
# Compara el error máximo de los cuatro pesos pequeños en ambos casos.
#
# **Ejercicio 3 — Presupuesto de memoria.** ¿Cuánta RAM aproximada necesita un modelo
# de 8·10⁹ parámetros en FP16, INT8 y Q4_K_M (~4,55 bits/peso)? ¿Cuál cabe en un
# portátil con 8 GB (dejando ~2 GB al sistema y al KV cache)?
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("neural", seed=85)` y
# valida `kind`, `evidence`, `limitations`. ¿Qué limitación declararías tú antes de
# recomendar un modelo cuantizado para un caso clínico o legal?

# %%
# TU RESPUESTA AQUÍ
# Ejercicio 1:
w = [0.12, -0.50, 0.25, -0.10]
# s = ...
# q = [...]
# x_hat = [...]
# err_max = ...

# Ejercicio 2:
w5 = 8.0
# escala global: ...
# por grupos: ...

# Ejercicio 3:
N = 8e9
# fp16_gb, int8_gb, q4_gb = ...

# Ejercicio 4:
# result = run_lab("neural", seed=85)
# assert ...

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué la cuantización acelera el decode aunque la GPU tenga que descuantizar
#    cada peso antes de multiplicar?
# 2. Un outlier de magnitud 12 entre pesos de magnitud <1 multiplica el error de
#    todos: ¿qué dos técnicas distintas de la clase lo neutralizan y en qué difieren?
# 3. ¿En qué escenarios el modelo local en Q4 supera *en la práctica* a un modelo
#    mayor vía API, aun perdiendo en benchmarks de calidad?
