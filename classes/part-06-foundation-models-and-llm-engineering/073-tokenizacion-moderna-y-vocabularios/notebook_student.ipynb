# %% [markdown]
# # 073 — Tokenización moderna y vocabularios
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — BPE a mano.** Corpus: `ab ×4`, `abc ×3`, `bcd ×2` (añade `_` al final
# de cada palabra). Calcula las frecuencias de pares y ejecuta las **3 primeras merges**
# de BPE, mostrando el estado del corpus tras cada una.
#
# **Ejercicio 2 — Tokenizar palabra nueva.** Con las merges del ejemplo del README
# (`es`, `est`, `est_`, `lo`, `low`), tokeniza a mano la palabra nueva `west`
# (secuencia inicial `w e s t _`). ¿Cuántos tokens resultan y cuáles?
#
# **Ejercicio 3 — Fertilidad.** Un texto de 900 palabras en inglés produce 1 200 tokens
# y su traducción al español, de 950 palabras, produce 1 700 tokens. Calcula la
# fertilidad de cada idioma y el sobrecosto porcentual del español si la API cobra por
# token de entrada.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("llm", seed=73)`,
# verifica que el resultado contiene `kind`, `evidence` y `limitations`, y explica qué
# elemento de la evidencia depende de la semilla.

# %%
# TU RESPUESTA AQUÍ
# Ejercicio 1: escribe los conteos de pares y el corpus tras cada merge.
# merge_1 = ...
# merge_2 = ...
# merge_3 = ...

# Ejercicio 2: aplica las merges en orden a ['w','e','s','t','_'].
# tokens_west = [...]

# Ejercicio 3:
palabras_en, tokens_en = 900, 1200
palabras_es, tokens_es = 950, 1700
# fertilidad_en = ...
# fertilidad_es = ...
# sobrecosto_pct = ...

# Ejercicio 4:
# result = run_lab("llm", seed=73)
# assert ...

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué un vocabulario BPE entrenado sobre texto mayoritariamente inglés castiga
#    (en tokens y en dinero) a quien escribe en guaraní o quechua?
# 2. Si "1234" es un token único pero "1235" son dos, ¿qué implica para pedirle
#    aritmética a un LLM y cómo lo mitigarías?
# 3. ¿Qué ventaja concreta aporta el muestreo de segmentaciones del modelo unigram
#    durante el entrenamiento que BPE determinista no ofrece?
