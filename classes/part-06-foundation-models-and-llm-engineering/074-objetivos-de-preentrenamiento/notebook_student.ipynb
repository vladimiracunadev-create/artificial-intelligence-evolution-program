# %% [markdown]
# # 074 — Objetivos de preentrenamiento
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Perplejidad a mano.** Un modelo causal asigna al token correcto las
# probabilidades 0,5, 0,25 y 0,125 en tres posiciones consecutivas. Calcula la pérdida
# total, la pérdida media por token y la perplejidad (usa ln; recuerda PPL = e^L).
#
# **Ejercicio 2 — Construir ejemplos MLM.** Para la secuencia
# `[los, modelos, aprenden, de, los, datos]` con enmascaramiento en las posiciones 2 y
# 6, escribe la entrada y el objetivo del entrenamiento MLM. ¿Por qué BERT a veces
# sustituye el token elegido por uno aleatorio en lugar de `[MASK]`?
#
# **Ejercicio 3 — Objetivo T5.** Aplica corrupción de spans a
# `el entrenamiento distribuido requiere sincronizar gradientes` eliminando los spans
# `distribuido` y `sincronizar gradientes`. Escribe entrada y objetivo con centinelas
# `<X>`, `<Y>`, `<Z>`.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("llm", seed=74)` y
# verifica el contrato (`kind`, `evidence`, `limitations`). ¿Qué parte del resultado
# cambiaría con otra semilla y cuál no?

# %%
# TU RESPUESTA AQUÍ
import math

# Ejercicio 1:
p = [0.5, 0.25, 0.125]
# L_total = ...
# L_media = ...
# ppl = ...

# Ejercicio 2: escribe entrada y objetivo como listas de tokens.
# entrada_mlm = [...]
# objetivo_mlm = {...}

# Ejercicio 3:
# entrada_t5 = "..."
# objetivo_t5 = "..."

# Ejercicio 4:
# result = run_lab("llm", seed=74)
# assert ...

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué el objetivo causal aprovecha el 100 % de las posiciones como señal y MLM
#    solo ~15 %, y qué implica eso para el costo de alcanzar una misma calidad?
# 2. Un modelo preentrenado solo con next-token completa "La capital de Francia es"
#    correctamente pero responde mal a "¿Cuál es la capital de Francia?". ¿Qué explica
#    la diferencia y qué etapa posterior la corrige?
# 3. Si tu tarea es clasificar 50 000 tickets de soporte con presupuesto mínimo,
#    ¿qué familia (GPT, BERT, T5) elegirías y por qué?
