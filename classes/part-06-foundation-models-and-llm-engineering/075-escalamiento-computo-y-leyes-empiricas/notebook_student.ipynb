# %% [markdown]
# # 075 — Escalamiento, cómputo y leyes empíricas
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Presupuesto Chinchilla.** Con C = 2,4·10²² FLOPs y las reglas
# D = 20·N, C = 6·N·D, calcula N* y D* óptimos. Redondea a órdenes legibles.
#
# **Ejercicio 2 — Diagnóstico de un modelo.** Un equipo entrenó 40B parámetros con
# 200B tokens. ¿Cuántos tokens/parámetro usó? ¿Está sub- o sobre-entrenado según
# Chinchilla? ¿Qué C consumió (en FLOPs, usando C = 6·N·D)?
#
# **Ejercicio 3 — Ley de potencia.** Con L(D) = (5,4·10¹³ / D)^0,095, calcula la
# pérdida para D = 10¹⁰ y D = 10¹². ¿Cuánto hay que multiplicar los datos para bajar
# la pérdida un 10 %? (Pista: despeja el factor k tal que k^−0,095 = 0,9.)
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("evaluation", seed=75)`
# y verifica `kind`, `evidence`, `limitations`. ¿Por qué este laboratorio es de tipo
# `evaluation` y no de entrenamiento?

# %%
# TU RESPUESTA AQUÍ
import math

# Ejercicio 1:
C = 2.4e22
# N_opt = ...
# D_opt = ...

# Ejercicio 2:
N, D = 40e9, 200e9
# tokens_por_param = ...
# C_consumido = ...

# Ejercicio 3:
# L10 = ...
# L12 = ...
# k = ...

# Ejercicio 4:
# result = run_lab("evaluation", seed=75)
# assert ...

# %% [markdown]
# ## Reflexión
#
# 1. Con cómputo fijo, ¿por qué un modelo de 280B puede perder contra uno de 70B y qué
#    papel juega la cantidad de tokens en esa derrota?
# 2. Si tu producto servirá 10⁹ requests/mes, ¿por qué podrías apartarte
#    deliberadamente del óptimo de Chinchilla y en qué dirección?
# 3. ¿Qué riesgo hay en extrapolar leyes ajustadas hasta 10²⁴ FLOPs a presupuestos de
#    10²⁶, y qué límite físico (no monetario) aparece primero?
