# %% [markdown]
# # 083 — Selección de modelo, costo, latencia y privacidad
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %% [markdown]
# ## 📖 Resumen de la materia
#
# - **Costo API**: R·[(T_in/1000)·p_in + (T_out/1000)·p_out]; la salida cuesta 3–5×
#   más; palancas: caché de prompts, batch, enrutamiento a modelos pequeños, recortar
#   el prompt de sistema. Infra propia = costo fijo: conviene con volumen sostenido.
# - **Latencia**: total ≈ TTFT + TPOT·tokens_out; chat optimiza TTFT p99 con
#   streaming; batch optimiza throughput; tiempo real estricto exige modelos
#   pequeños/locales.
# - **Privacidad**: espectro API pública → acuerdo empresarial → VPC → on-premise →
#   local; los datos regulados convierten la privacidad en restricción dura.
# - **Método**: golden set propio + métrica definida a priori + medir 2–4 candidatos
#   (calidad, costo/tarea, p50/p99) + decidir con la matriz y re-evaluar
#   periódicamente. Los leaderboards solo preseleccionan.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %%
result = run_lab("evaluation", seed=83)
show(result)

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué "costo por tarea resuelta" es la métrica correcta y comparar precios
#    por token entre proveedores puede engañar en ambas direcciones?
# 2. Da un ejemplo concreto donde el p99 de TTFT importe más que el p50 y otro donde
#    ninguna latencia importe en absoluto.
# 3. ¿Qué evidencia mínima te haría confiar en un LLM-judge como métrica de calidad
#    de tu golden set?
