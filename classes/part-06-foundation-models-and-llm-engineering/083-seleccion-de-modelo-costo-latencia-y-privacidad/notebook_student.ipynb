# %% [markdown]
# # 083 — Selección de modelo, costo, latencia y privacidad
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Factura mensual.** Un servicio hace 2 M de requests/mes con
# T_in = 1 200 y T_out = 250 tokens. Precios: p_in = $0,001, p_out = $0,005 por 1k
# tokens. Calcula el costo mensual y el ahorro si un caché de prompts reduce el 60 %
# de los tokens de entrada a la mitad de precio.
#
# **Ejercicio 2 — Punto de equilibrio.** Servir un modelo abierto cuesta $2 100/mes
# fijos (GPU + operación) con capacidad sobrada. La alternativa API cuesta $0,0009
# por request en promedio. ¿A partir de cuántas requests/mes conviene la GPU propia?
# ¿Qué supuesto frágil tiene este cálculo?
#
# **Ejercicio 3 — Matriz de decisión.** Con la tabla del ejemplo trabajado (A, B, C),
# recomienda modelo para: (a) triaje de currículums con datos personales que no
# pueden salir del país; (b) chatbot público de marketing; (c) resumen nocturno de
# 10 000 documentos internos no sensibles. Justifica con el criterio dominante.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("evaluation",
# seed=83)` y valida el contrato. ¿Por qué la evidencia y las limitaciones del
# laboratorio son el mismo patrón que exigirías en un informe de selección de modelo?

# %%
# TU RESPUESTA AQUÍ
# Ejercicio 1:
R, T_in, T_out = 2_000_000, 1200, 250
p_in, p_out = 0.001, 0.005
# costo = ...
# costo_con_cache = ...

# Ejercicio 2:
fijo, por_request = 2100, 0.0009
# umbral = ...

# Ejercicio 3:
# a = "..."; b = "..."; c = "..."

# Ejercicio 4:
# result = run_lab("evaluation", seed=83)
# assert ...

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué "costo por tarea resuelta" es la métrica correcta y comparar precios
#    por token entre proveedores puede engañar en ambas direcciones?
# 2. Da un ejemplo concreto donde el p99 de TTFT importe más que el p50 y otro donde
#    ninguna latencia importe en absoluto.
# 3. ¿Qué evidencia mínima te haría confiar en un LLM-judge como métrica de calidad
#    de tu golden set?
