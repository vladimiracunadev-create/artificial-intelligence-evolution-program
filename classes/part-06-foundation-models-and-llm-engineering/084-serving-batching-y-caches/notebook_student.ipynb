# %% [markdown]
# # 084 — Serving, batching y cachés
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Memoria del KV cache.** Para un modelo con 40 capas, 40 cabezas KV,
# d_head = 128, FP16 (2 bytes): calcula los bytes de KV por token y el caché total de
# una secuencia de 8 192 tokens. Repite con GQA de 8 cabezas KV.
#
# **Ejercicio 2 — Concurrencia.** GPU de 80 GB, pesos del modelo 28 GB, 4 GB de
# overhead. Con el KV por token del ejercicio 1 (versión GQA), ¿cuántas secuencias de
# 2 048 tokens caben con reserva estática a 8 192? ¿Y con asignación paginada exacta
# (2 048 tokens reales)?
#
# **Ejercicio 3 — Batching estático vs continuo.** Un lote estático de 4 secuencias
# genera respuestas de 100, 200, 400 y 800 tokens (1 token/paso por secuencia). Los
# slots liberados no se reutilizan hasta acabar el lote. Calcula los pasos-slot
# desperdiciados y el porcentaje de utilización; compara con continuous batching
# ideal (utilización ~100 %).
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("observability",
# seed=84)` y valida el contrato. ¿Por qué el serving es un problema de
# *observabilidad* tanto como de algoritmos?

# %%
# TU RESPUESTA AQUÍ
# Ejercicio 1:
capas, kv_heads, d_head, bytes_dtype = 40, 40, 128, 2
# kv_por_token = ...
# cache_8192 = ...
# con GQA (8 cabezas): ...

# Ejercicio 2:
mem_disponible_gb = 80 - 28 - 4
# n_estatico = ...
# n_paginado = ...

# Ejercicio 3:
longitudes = [100, 200, 400, 800]
# pasos_slot_totales = ...
# pasos_slot_utiles = ...
# utilizacion = ...

# Ejercicio 4:
# result = run_lab("observability", seed=84)
# assert ...

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué el decode está limitado por ancho de banda y no por FLOPs, y qué
#    implica para elegir GPU de serving frente a GPU de entrenamiento?
# 2. Un prompt de sistema de 2 000 tokens compartido por todos los usuarios: ¿qué
#    mecanismo de esta clase lo convierte en casi gratis y por qué?
# 3. Si tu p99 de TPOT empeora al subir el tamaño máximo de lote, ¿qué compromiso
#    estás viendo y cómo fijarías el límite?
