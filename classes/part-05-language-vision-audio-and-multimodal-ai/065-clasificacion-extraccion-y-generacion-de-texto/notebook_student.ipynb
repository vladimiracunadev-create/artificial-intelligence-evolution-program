# %% [markdown]
# # 065 — Clasificación, extracción y generación de texto
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %% [markdown]
# ## 📖 Resumen de la materia
#
# **Clasificación:** `texto → TF-IDF → clasificador lineal` sigue siendo un baseline serio.
# `tfidf(t,d) = tf(t,d) · log(N/df(t))`: términos frecuentes en el documento pero raros en
# el corpus pesan más; "el" (df = N) pesa 0. Evaluar con F1 **por clase** (macro/micro), no
# con accuracy global si hay desbalance.
#
# **Extracción (NER):** etiquetado token a token con esquema **BIO** (`B-PER I-PER O …`);
# la métrica es F1 **por entidad completa** (span + tipo exactos).
#
# **Generación:** un modelo de lenguaje factoriza `P(w1…wn) = Π P(wi | contexto)` y genera
# muestreando. **Perplejidad** `PP = P(secuencia)^(-1/n)` = factor de ramificación efectivo
# (PP 4 → duda entre ~4 opciones por token); menor es mejor, solo comparable con mismo
# tokenizador y corpus. Fluidez ≠ veracidad.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — TF-IDF a mano.** Corpus: `d1 = "ia genera texto"`,
# `d2 = "ia clasifica texto"`, `d3 = "el modelo genera codigo"`. Calcula idf de cada término
# (ln, N=3) y el vector TF-IDF de `d1`. ¿Qué término pesa más y por qué?
#
# **Ejercicio 2 — Etiquetas BIO.** Etiqueta con BIO (tipos PER, ORG, LOC) la frase:
# `Pedro Pascal visitó la sede de Naciones Unidas en Nueva York`. ¿Cuántas entidades hay?
# Si un modelo etiqueta `Naciones` como `B-ORG` y `Unidas` como `O`, ¿cuenta como acierto
# parcial en F1 por entidad?
#
# **Ejercicio 3 — Perplejidad.** Un modelo asigna a una frase de 3 tokens las probabilidades
# `0.1, 0.1, 0.1`. Calcula la perplejidad. Otro modelo asigna `0.5, 0.02, 0.5` (mismo
# tokenizador). Calcula ambas y explica cuál "duda menos" en promedio y por qué el token de
# 0.02 pesa tanto.
#
# **Ejercicio 4 — Verifica con código.** Implementa `tfidf(corpus)` con conteo crudo e idf
# `ln(N/df)` y comprueba tu vector del ejercicio 1.

# %%
# TODO: ejecuta run_lab("llm", seed=65)
# TODO: comprueba que el resultado incluya las claves 'kind' y 'evidence'
result = None

# %%
# TU RESPUESTA AQUÍ
# Ejercicio 4: TF-IDF con conteo crudo e idf = ln(N/df)
import math
from collections import Counter

corpus = ["ia genera texto", "ia clasifica texto", "el modelo genera codigo"]

def tfidf(corpus):
    docs = [d.split() for d in corpus]
    N = len(docs)
    df = None      # completa: en cuántos documentos aparece cada término
    idf = None     # completa: ln(N / df[t])
    return None    # lista de dicts término→peso por documento

# imprime el vector de d1

# %% [markdown]
# ## Reflexión
#
# 1. Tu clasificador de spam tiene accuracy 97 % pero recall de spam 40 %. ¿Qué pasó, qué
#    métrica debiste vigilar y qué costo de error hace grave este caso?
# 2. En NER clínico, ¿por qué "F1 por token 92 %" puede convivir con extracciones inservibles,
#    y qué exige la métrica por entidad que la hace más honesta?
# 3. Un modelo A tiene perplejidad 12 y un modelo B tiene 15 con tokenizadores distintos.
#    ¿Puedes concluir que A genera mejor? ¿Qué experimento sí lo permitiría?
