# %% [markdown]
# # 003 — Inviernos, resurgimientos y ciclos de expectativas
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %% [markdown]
# ## 📖 Resumen de la materia
#
# Un **invierno de IA** es un colapso de financiación y credibilidad tras expectativas
# infladas. El patrón histórico tiene seis pasos: avance real acotado → extrapolación pública
# → financiación atada a la promesa → muro técnico → informe/fracaso que cristaliza →
# recorte y éxodo.
#
# - **Primer invierno (~1974-1980):** detonado por el informe ALPAC (1966, traducción
#   automática), *Perceptrons* de Minsky y Papert (1969, límite XOR) y el **informe
#   Lighthill** (1973), que identificó la **explosión combinatoria** como muro de los métodos
#   de búsqueda general.
# - **Segundo invierno (~1987-1993):** los sistemas expertos (XCON, MYCIN) dieron valor real
#   pero colapsaron por costo de mantenimiento de reglas frágiles y el desplome del mercado
#   de máquinas Lisp.
# - **Resurgimiento (1995→):** métodos probabilísticos, evaluación en benchmarks y, desde
#   2012 (AlexNet), deep learning con GPU y datos masivos.
#
# Indicadores para separar avance real de burbuja: mejora en benchmarks independientes y
# fuera de distribución, costo por tarea descendente, despliegues reales con usuarios que
# pagan, y promesas con fecha y criterio falsable.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Solución de referencia
#
# **Ejercicio 1.** (1) Avance real: XCON ahorra millones a DEC configurando VAX (~1980).
# (2) Extrapolación: "conocimiento experto barato para toda tarea" (~1983). (3) Financiación:
# Quinta Generación (1982), DARPA/SCI, boom de startups Lisp. (4) Muro: cuello de botella de
# adquisición de conocimiento, fragilidad ante incertidumbre. (5) Cristalización: colapso del
# mercado de máquinas Lisp (~1987). (6) Recorte: fin de Quinta Generación sin objetivos
# cumplidos (~1992), "IA" vuelve a ser etiqueta tóxica.
#
# **Ejercicio 2.** Claim falsable: "para 1992 el proyecto entregará máquinas de inferencia en
# paralelo que resuelvan traducción y razonamiento experto a escala comercial". Resultado:
# refutado en lo comercial (el hardware/paradigma no se adoptó), corroborado parcialmente en
# lo técnico (avances en lógica y paralelismo). La lección: separar el veredicto por
# componente en lugar de un juicio global.
#
# **Ejercicio 3.** El titular vendedor típico extrapola ("la IA supera a los analistas");
# el honesto reporta condición y límite ("en un escenario sintético con semilla fija, el
# método X supera al baseline Y en la métrica M; sin validación externa"). La diferencia
# exacta entre ambos es el contenido de `limitations`.
#
# **Ejercicio 4.** Respuesta abierta; el criterio de corrección es que cada indicador cite
# una fuente verificable (informe de resultados, precios públicos, benchmark de terceros) y
# que lo no verificable se declare como tal en lugar de rellenarse con impresiones.

# %%
result = run_lab("evaluation", seed=3)
assert result["kind"] == "evaluation"
assert result["evidence"]
show(result)

# %%
# Ejercicio 3 — evidencia vs titular
result = run_lab("evaluation", seed=1)
show(result)
titular_vendedor = "La IA resuelve la evaluación: resultados espectaculares"
titular_honesto = (
    f"Lab '{result['kind']}' con seed=1: evidencia = {len(result['evidence'])} hechos "
    f"inspeccionables; limitaciones declaradas = {len(result['limitations'])}"
)
print(titular_vendedor)
print(titular_honesto)
# La regla: ningún titular puede afirmar más que el contenido de 'evidence'.

# %% [markdown]
# ## Reflexión
#
# 1. La predicción de Simon (1965: "en 20 años las máquinas harán cualquier trabajo humano")
#    era falsable y resultó falsa. ¿En qué sentido fue mejor ciencia que una promesa vaga sin
#    plazo, y peor gestión de expectativas?
# 2. Aplica los cuatro indicadores de la teoría (benchmarks independientes, costo por tarea,
#    despliegues pagados, promesas falsables) a la ola actual de IA generativa: ¿cuáles se
#    cumplen con evidencia pública y cuáles no puedes verificar?
# 3. El laboratorio `evaluation` compara un claim contra evidencia. ¿Qué elemento del patrón
#    de seis pasos ataca directamente ese hábito y por qué no fue suficiente en 1973?
