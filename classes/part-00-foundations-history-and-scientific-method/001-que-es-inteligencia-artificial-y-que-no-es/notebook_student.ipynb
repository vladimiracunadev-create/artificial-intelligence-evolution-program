# %% [markdown]
# # 001 — Qué es inteligencia artificial y qué no es
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %% [markdown]
# ## 📖 Resumen de la materia
#
# **Definición operativa (AIMA 4e, cap. 1):** la IA moderna se define por el **agente
# racional** — un sistema que percibe su entorno y actúa para maximizar el valor esperado de
# una medida de desempeño. No exige conciencia: exige desempeño medible.
#
# Distinciones clave de esta clase:
#
# - **IA estrecha:** competente en una tarea acotada (clasificar, traducir, jugar). Todo
#   sistema desplegado hoy es IA estrecha; su competencia no transfiere fuera de su
#   distribución de datos.
# - **IA general (AGI):** hipotética competencia transferible a la mayoría de dominios.
#   Es un objetivo de investigación, no un artefacto existente.
# - **Automatización:** ejecutar un procedimiento *especificado de antemano* (una macro, un
#   cron job). No es IA aunque no intervenga un humano.
# - **Autonomía:** seleccionar acciones ante situaciones *no enumeradas* por el diseñador,
#   siempre acotada por un dominio de operación (ODD).

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Clasificar con la prueba de demarcación.** Clasifica cada sistema como
# `automatización`, `IA estrecha` o `agente con autonomía acotada`, respondiendo las tres
# preguntas de la prueba para cada uno: (a) semáforo con temporizador fijo, (b) recomendador
# de películas entrenado con historiales, (c) dron de reparto que replanifica su ruta ante
# viento, (d) hoja de cálculo con macros.
#
# **Ejercicio 2 — Bayes a mano.** Con el corpus de la teoría (1 000 correos, 200 spam;
# "oferta" aparece en 90 spam y 80 legítimos), calcula P(spam|"oferta") paso a paso.
# Compara con el 0.75 de "gratis": ¿qué palabra es mejor evidencia y por qué?
#
# **Ejercicio 3 — Contrato del laboratorio.** Ejecuta `run_lab("frontier", seed=1)` y luego
# con `seed=2`. Anota qué campos cambian y cuáles no. ¿Qué te dice eso sobre qué parte del
# comportamiento es regla determinista y qué parte depende de la semilla?
#
# **Ejercicio 4 — El claim de AGI.** Reescribe la frase de marketing "nuestro asistente
# entiende a tus clientes" como un claim falsable (tarea, métrica, población de datos,
# umbral). ¿Qué evidencia mínima exigirías antes de aceptarlo?

# %%
# TODO: ejecuta run_lab("frontier", seed=1)
# TODO: comprueba que el resultado incluya las claves 'kind' y 'evidence'
result = None

# %%
# TU RESPUESTA AQUÍ
# Ejercicio 2: calcula P(spam | "oferta") con los conteos dados
p_spam = 200 / 1000
p_oferta_dado_spam = None      # completa: 90 / 200
p_oferta = None                # completa: (90 + 80) / 1000
p_spam_dado_oferta = None      # completa: regla de Bayes
print(p_spam_dado_oferta)

# Ejercicio 3: compara run_lab("frontier", seed=1) con seed=2

# %% [markdown]
# ## Reflexión
#
# 1. El laboratorio `frontier` produce el mismo JSON con la misma semilla. Según la prueba de
#    demarcación de la teoría, ¿ese determinismo lo acerca a la automatización clásica o a la
#    IA estrecha? ¿Qué componente tendría que inducirse desde datos para cambiar de categoría?
# 2. Da un ejemplo real de sistema que el marketing llame "IA" pero que la prueba de
#    demarcación clasifique como automatización, y justifica con las tres preguntas.
# 3. ¿Qué observación concreta te obligaría a admitir que un sistema actual es más que IA
#    estrecha? Formúlala de manera falsable (tarea, métrica, condición de datos no vistos).
