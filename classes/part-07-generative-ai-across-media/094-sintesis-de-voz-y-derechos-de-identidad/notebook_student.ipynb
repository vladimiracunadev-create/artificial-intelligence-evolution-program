# %% [markdown]
# # 094 — Síntesis de voz y derechos de identidad
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Dimensiones del mel a mano.** Un clip de 5 s muestreado a 24 000 Hz se
# procesa con hop de 300 muestras y 80 bandas mel. Calcula: (a) muestras totales;
# (b) número de frames; (c) valores del mel-espectrograma; (d) factor de compresión
# frente a la forma de onda.
#
# **Ejercicio 2 — Factor de tiempo real.** Un vocoder autorregresivo genera 1 000
# muestras por segundo de cómputo; uno paralelo procesa el clip completo en 0.08 s.
# Para el clip del ejercicio 1, calcula el RTF de cada uno y la razón entre ambos.
# ¿Cuál permite una aplicación conversacional?
#
# **Ejercicio 3 — Consentimiento por capas.** Una persona publicó un podcast con su voz.
# Enumera qué autorizaciones DISTINTAS harían falta para: (a) usar el audio para
# entrenar un TTS multi-hablante; (b) clonar su timbre y generar frases nuevas;
# (c) usar esa voz clonada en un anuncio comercial. ¿Cuál de las tres viola una
# clonación zero-shot hecha sin permiso a partir del podcast?
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("safety", seed=94)` y
# comprueba que el resultado incluye las claves `kind` y `evidence`.

# %%
# TU RESPUESTA AQUÍ
# Ejercicio 1: dimensiones del mel (5 s, 24 000 Hz, hop 300, 80 bandas).
duracion, sr, hop, n_mels = 5, 24_000, 300, 80
# muestras = ...
# frames = ...

# Ejercicio 2: RTF autorregresivo (1000 muestras/s) vs paralelo (0.08 s totales).
# ...

# Ejercicio 3: responde en texto (comentarios) las capas de consentimiento.

# Ejercicio 4:
# result = run_lab("safety", seed=94)
# assert "kind" in result and "evidence" in result
result = None

# %% [markdown]
# ## Reflexión
#
# 1. El mel-espectrograma descarta la fase: ¿por qué eso obliga a que el vocoder sea un
#    modelo generativo y qué pasaría si reconstruyeras la onda con fase cero?
# 2. Si SV2TTS clona un timbre con segundos de audio público, ¿qué control de
#    consentimiento es técnicamente viable: restringir los datos, marcar el audio
#    sintético (watermarking/C2PA), o verificar identidad antes de clonar? Justifica.
# 3. FastSpeech 2 elimina los fallos de atención de Tacotron 2 usando un predictor de
#    duración explícito: ¿qué gana y qué pierde en prosodia frente al modelo
#    autorregresivo?
