# %% [markdown]
# # 098 — Procedencia, marcas y autenticidad
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — z-score a mano.** Con γ = 0.5 y T = 100 tokens, calcula el z del
# detector para (a) k = 70 tokens verdes y (b) k = 55. Interpreta ambos resultados
# (¿marca presente?).
#
# **Ejercicio 2 — Predecir el umbral.** Con γ = 0.25 y T = 200: ¿cuántos tokens verdes
# se esperan bajo H₀? ¿Cuál es el k mínimo (entero) que produce z ≥ 4? Predícelo a mano
# con `k ≥ γT + 4·√(Tγ(1−γ))` y verifica en código.
#
# **Ejercicio 3 — Ataque de dilución.** Un parafraseador reescribe parte de un texto
# marcado (γ = 0.5, T = 100) y los verdes caen de 70 a 60. Recalcula z y explica por
# qué el atacante no necesita conocer la clave del hash para debilitar la marca.
# ¿Le pasaría lo mismo a un manifiesto C2PA?
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("safety", seed=98)` y
# comprueba que el resultado incluye las claves `kind` y `evidence`.

# %%
# TU RESPUESTA AQUÍ
import math

# Ejercicio 1: z = (k − γT) / sqrt(T·γ·(1−γ)) para k = 70 y k = 55 (γ=0.5, T=100).
gamma, T = 0.5, 100
# z70 = ...
# z55 = ...

# Ejercicio 2: k mínimo con z ≥ 4 para γ = 0.25, T = 200.
# k_min = ...

# Ejercicio 3: z tras la paráfrasis (k = 60, γ = 0.5, T = 100).
# z60 = ...

# Ejercicio 4:
# result = run_lab("safety", seed=98)
# assert "kind" in result and "evidence" in result
result = None

# %% [markdown]
# ## Reflexión
#
# 1. Con γ = 0.5, un 70 % de tokens verdes da z = 4.0 si T = 100, pero solo z ≈ 1.26 si T = 10. ¿Por qué la longitud del texto es decisiva para el detector y qué implica para fragmentos cortos (titulares, tuits)?
# 2. Una imagen generada por IA puede llevar un manifiesto C2PA perfectamente válido. ¿Qué acredita exactamente esa firma y por qué la ausencia de manifiesto no prueba origen humano?
# 3. La paráfrasis o el lavado con otro modelo eliminan la marca de agua sin conocer la clave. ¿Qué ataque análogo sufre C2PA (eliminar el manifiesto) y por qué la garantía de ambos esquemas es unidireccional?
