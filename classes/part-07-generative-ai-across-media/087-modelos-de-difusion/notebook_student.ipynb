# %% [markdown]
# # 087 — Modelos de difusión
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — Forward con alfas concretas
#
# Con el scheduler β = [0.1, 0.2, 0.3], calcula a mano α_t, ᾱ_t para t = 1, 2, 3.
# Luego, para x₀ = 2.0 y ε = −1.0, calcula x₃ con la forma cerrada
# x_t = √ᾱ_t·x₀ + √(1−ᾱ_t)·ε. Verifica con código.

# %%
import math

betas = [0.1, 0.2, 0.3]
x0, eps = 2.0, -1.0
# TU RESPUESTA AQUÍ: calcula alphas, alpha_bar y x3

# %% [markdown]
# ## Ejercicio 2 — Predecir la señal restante
#
# Sin calcular: si ᾱ_t = 0.04, ¿qué fracción de la varianza de x_t proviene de x₀ y qué
# fracción del ruido? ¿Estamos cerca del inicio o del final del proceso forward?
# Escribe tu predicción y luego compruébala.

# %%
alpha_bar_t = 0.04
# TU RESPUESTA AQUÍ: fracción de señal y de ruido

# %% [markdown]
# ## Ejercicio 3 — Reconstruir x₀ desde la predicción de ruido
#
# En inferencia, la red estima ε̂. Despeja x̂₀ de la forma cerrada:
# x̂₀ = (x_t − √(1−ᾱ_t)·ε̂) / √ᾱ_t. Con x_t = 1.114, ᾱ_t = 0.72 y una red perfecta
# (ε̂ = 0.5), verifica que recuperas x₀ = 1.0. ¿Qué pasa con el error de x̂₀ si ε̂ se
# desvía 0.1 cuando ᾱ_t es pequeño (p. ej. 0.04)?

# %%
import math

x_t, alpha_bar, eps_hat = 1.114, 0.72, 0.5
# TU RESPUESTA AQUÍ: calcula x0_hat y analiza la sensibilidad con alpha_bar=0.04

# %% [markdown]
# ## Ejercicio 4 — Contrato del laboratorio
#
# Ejecuta `run_lab("generation", seed=87)` y comprueba `kind` y `evidence`. Relaciona:
# ¿por qué en difusión real la reproducibilidad exige fijar semilla **y** número de
# pasos **y** scheduler, y no solo la semilla?

# %%
# TU RESPUESTA AQUÍ
result = None
