# %% [markdown]
# # 086 — GAN y entrenamiento adversarial
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — Pérdidas del juego a mano
#
# El discriminador asigna D = 0.8 a un dato real y D = 0.3 a uno generado.
# Calcula: (a) la pérdida de D, L_D = −log D(x) − log(1 − D(G(z)));
# (b) la pérdida non-saturating de G, L_G = −log D(G(z)).
# Verifica con código.

# %%
import math

d_real, d_fake = 0.8, 0.3
# TU RESPUESTA AQUÍ: calcula l_d y l_g
l_d = None
l_g = None
print(l_d, l_g)

# %% [markdown]
# ## Ejercicio 2 — Discriminador óptimo
#
# En un punto x, la densidad real vale p_data(x) = 0.6 y la del generador p_g(x) = 0.2.
# Calcula D*(x) = p_data / (p_data + p_g). ¿Qué valor toma D* cuando p_g = p_data en
# todo el espacio, y por qué ese valor caracteriza el equilibrio del juego?

# %%
p_data, p_g = 0.6, 0.2
# TU RESPUESTA AQUÍ
d_star = None
print(d_star)

# %% [markdown]
# ## Ejercicio 3 — Detectar colapso de modos
#
# Un generador entrenado sobre dígitos 0-9 produce 1000 muestras con esta distribución
# de clases: {1: 480, 7: 510, resto: 10}. La pérdida de G es baja y las muestras son
# nítidas. ¿Hay colapso de modos? ¿Qué métrica simple (p. ej. entropía de la
# distribución de clases) lo delataría? Calcula la entropía y compárala con la máxima.

# %%
import math

counts = {1: 480, 7: 510, "resto": 10}
# TU RESPUESTA AQUÍ: entropía de la distribución observada vs log2(10)

# %% [markdown]
# ## Ejercicio 4 — Contrato del laboratorio
#
# Ejecuta `run_lab("generation", seed=86)`, comprueba las claves `kind` y `evidence`,
# y responde: ¿qué papel juega aquí la semilla frente al papel del ruido z en una GAN
# real? ¿En qué se parecen y en qué no?

# %%
# TU RESPUESTA AQUÍ: ejecuta run_lab y comprueba el contrato
result = None
