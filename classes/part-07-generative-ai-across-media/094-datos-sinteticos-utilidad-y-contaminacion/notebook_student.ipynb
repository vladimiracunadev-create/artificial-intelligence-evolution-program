# %% [markdown]
# # 094 — Datos sintéticos: utilidad y contaminación
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Colapso a mano.** Con p_rara = 0.05 y N = 20 muestras por generación,
# calcula: (a) la probabilidad de que la clase rara NO aparezca en una generación;
# (b) la probabilidad aproximada de que sobreviva 3 generaciones seguidas
# (supón p̂ ≈ 0.05 mientras sobreviva). Hazlo a mano y verifica en código.
#
# **Ejercicio 2 — Predecir y simular.** Antes de ejecutar: ¿esperas que la clase rara
# sobreviva 3 generaciones con `random.seed(94)`? Simula 3 generaciones (muestrear N=20
# con la p̂ estimada de la generación anterior, partiendo de p = 0.05) e imprime la
# trayectoria de p̂. Repite con `random.seed(7)` y explica por qué el destino de la cola
# puede diferir entre semillas.
#
# **Ejercicio 3 — TSTR.** Un clasificador entrenado con datos reales logra accuracy 0.90
# sobre el test real; el entrenado solo con datos sintéticos logra 0.72 sobre el MISMO
# test. Calcula la utilidad TSTR y decide si pasa un umbral de aceptación de 0.9.
# ¿Qué NO te dice este número sobre la privacidad de los datos sintéticos?
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("evaluation", seed=94)` y
# comprueba que el resultado incluye las claves `kind` y `evidence`.

# %%
# TU RESPUESTA AQUÍ
import random

# Ejercicio 1: probabilidad de extinción en una generación y supervivencia en 3.
p, N = 0.05, 20
# p_ext = ...
# p_sobrevive_3 = ...

# Ejercicio 2: simula 3 generaciones de muestreo recursivo (semillas 94 y 7).
# random.seed(94)
# ...

# Ejercicio 3: utilidad TSTR con acc_real = 0.90 y acc_sintetico = 0.72.
# tstr = ...

# Ejercicio 4:
# result = run_lab("evaluation", seed=94)
# assert "kind" in result and "evidence" in result
result = None

# %% [markdown]
# ## Reflexión
#
# 1. Con p_rara = 0.05 y N = 20, el riesgo de perder la cola en una generación es 0.95²⁰ ≈ 0.36. ¿Cuánto vale con N = 200 y qué implica sobre el tamaño de muestra en pipelines recursivos?
# 2. ¿Por qué TSTR mide utilidad mejor que una métrica de fidelidad marginal (p. ej. parecido visual), y qué relación captura que la fidelidad no captura?
# 3. Si en un crawl web no puedes distinguir el contenido generado, ¿qué aporta la procedencia activa (clase 095) como mitigación del collapse y cuál es su límite (¿quién marca y quién no)?
