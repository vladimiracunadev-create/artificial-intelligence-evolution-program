# %% [markdown]
# # 093 — Generación musical y de audio
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Bitrate de un códec, a mano.** Un códec opera sobre audio de
# 32 kHz a 50 frames/s con 4 codebooks de 2048 entradas. Calcula: bits por índice,
# bits por frame, bitrate en kbps, y el factor de compresión frente a PCM de
# 32 kHz × 16 bits. Compara con el caso EnCodec del ejemplo (24 kHz, 75 fr/s,
# 8×1024 → 6 kbps).
#
# **Ejercicio 2 — Longitud de secuencia.** Para 60 segundos de música con el códec
# de 75 frames/s y 8 codebooks: ¿cuántos tokens habría que predecir si se aplanan
# los 8 streams? ¿Y cuántos pasos con delay pattern (~frames + Q − 1)? ¿Cuántos
# pasos costaría modelar la onda cruda a 24 kHz muestra a muestra?
#
# **Ejercicio 3 — Elegir la representación.** Para cada escenario elige entre
# (i) transformer AR sobre tokens de códec, (ii) difusión sobre espectrograma mel +
# vocoder, (iii) códec truncado sin modelo generativo, y justifica en una frase:
# (a) continuar en streaming una grabación que el usuario está tocando;
# (b) generar un loop de 5 s editable con las herramientas de imagen (img2img);
# (c) transmitir voz inteligible con el mínimo bitrate posible.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("generation",
# seed=93)` y comprueba que el resultado incluye las claves `kind` y `evidence`.

# %%
# TU RESPUESTA AQUÍ
import math

# Ejercicio 1: bitrate del codec 32 kHz / 50 fr/s / 4 codebooks de 2048
# bits_por_indice = math.log2(...)
# ...

# Ejercicio 2: tokens aplanados, pasos con delay pattern, muestras crudas (60 s)
# ...

# Ejercicio 4:
# result = run_lab("generation", seed=93)
# assert "kind" in result and "evidence" in result
result = None

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué la primera capa del RVQ concentra la información "gruesa" de la señal y qué implica truncar la cascada a menos codebooks para el bitrate y la calidad?
# 2. ¿Qué problema resuelve el delay pattern de MusicGen frente a aplanar los 8 codebooks en una sola secuencia, y cuál es su costo?
# 3. La difusión sobre espectrogramas mel necesita un vocoder para producir la onda: ¿por qué (qué información falta) y qué artefactos puede introducir esa etapa extra?
