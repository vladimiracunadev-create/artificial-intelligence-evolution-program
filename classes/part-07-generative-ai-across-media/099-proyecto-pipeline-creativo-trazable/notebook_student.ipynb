# %% [markdown]
# # 099 — Proyecto: pipeline creativo trazable
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Hash a mano.** Con `h(s) = (Σ ord(c)) mod 256`, calcula a mano
# h("faro") (códigos: f=102, a=97, r=114, o=111) y expresa el resultado en hexadecimal.
# Verifica en código.
#
# **Ejercicio 2 — Construir y verificar la cadena.** Implementa el pipeline de 3 etapas
# del ejemplo (s1 = "un faro al amanecer", s2 = "IMG[faro,amanecer,seed=7]",
# s3 = "IMG[faro,amanecer,seed=7]+recorte"): construye la lista de manifiestos con
# `input_hash`/`output_hash` y escribe un verificador que recorra la cadena y confirme
# que cierra (F4 → E6 → 05).
#
# **Ejercicio 3 — Cambiar la semilla y explicar.** Sustituye la etapa 2 por
# "IMG[faro,amanecer,seed=8]" SIN actualizar el manifiesto de la etapa 3. Ejecuta tu
# verificador, señala en qué eslabón rompe y explica qué detecta la cadena y qué NO
# detecta (¿sabe el verificador *qué* cambió o *por qué*?).
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("capstone", seed=99)` y
# comprueba que el resultado incluye las claves `kind` y `evidence`.

# %%
# TU RESPUESTA AQUÍ
def toy_hash(s):
    return sum(ord(c) for c in s) % 256

# Ejercicio 1: h("faro") a mano y en código (en hexadecimal).
# print(hex(toy_hash("faro")))

# Ejercicio 2: construye los manifiestos de las 3 etapas y verifica la cadena.
s1 = "un faro al amanecer"
s2 = "IMG[faro,amanecer,seed=7]"
s3 = "IMG[faro,amanecer,seed=7]+recorte"
# manifiestos = [...]
# def verificar(manifiestos, salidas): ...

# Ejercicio 3: altera la etapa 2 (seed=8) sin actualizar la etapa 3 y verifica.
# ...

# Ejercicio 4:
# result = run_lab("capstone", seed=99)
# assert "kind" in result and "evidence" in result
result = None

# %% [markdown]
# ## Reflexión
#
# 1. Con la misma semilla pero una versión nueva del modelo en la etapa 2, la salida cambia y la cadena de hashes rompe. ¿Qué campo del contrato explica la diferencia y por qué semilla sin versión no basta para auditar?
# 2. ¿Por qué un manifiesto reconstruido después de la publicación no constituye evidencia de procedencia aunque todos los hashes cuadren?
# 3. ¿Qué añade una firma criptográfica (C2PA) sobre la cadena de hashes simple de este proyecto, y qué problema operativo nuevo introduce?
