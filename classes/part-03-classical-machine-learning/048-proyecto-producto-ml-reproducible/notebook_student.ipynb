# %% [markdown]
# # 048 — Proyecto: producto ML reproducible
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %% [markdown]
# ## 📖 Resumen de la materia
#
# **Proyecto reproducible:** `datos + config + semilla → modelo + métricas`, con un solo
# punto de entrada. Datos crudos inmutables (con hash); todo lo derivado se regenera;
# configs y semillas versionadas; resultado publicado = commit que lo produjo.
#
# **Cinco fuentes de irreproducibilidad:** datos sin linaje, azar sin semilla, entorno sin
# versiones, fuga del protocolo (decidir mirando el test), proceso manual (celdas en orden
# mental). Cada una tiene su antídoto estructural.
#
# **Contrato del experimento:** métrica + baseline trivial + intervalo (varias semillas o
# bootstrap) + subgrupos + limitaciones. Mejora sin intervalo = fluctuación con buena
# prensa. Tests mínimos: features, esquema, determinismo, anti-fuga, humo end-to-end.
# La *model card* documenta uso previsto y límites.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Auditoría de reproducibilidad.** Un repositorio contiene:
# `final_model_v3.pkl`, `datos_limpios_DEFINITIVO.csv`, un notebook de 90 celdas y un
# README que dice "ejecutar las celdas relevantes". Identifica las cinco fuentes de
# irreproducibilidad presentes y escribe el antídoto concreto para cada una.
#
# **Ejercicio 2 — Determinismo del laboratorio.** Ejecuta `run_lab("capstone", seed=48)`
# dos veces y compara los resultados completos. ¿Son idénticos? ¿Qué propiedad del diseño
# lo garantiza y qué parte de un pipeline real suele romperla?
#
# **Ejercicio 3 — Decisión con intervalo.** El modelo A (5 semillas) da costo
# 15 800 ± 900; el modelo B da 14 200 ± 1 100. (a) ¿Se solapan los intervalos ±1 desviación?
# (b) Redacta la conclusión honesta en una frase. (c) Propón dos formas de reducir la
# incertidumbre sin tocar los modelos.
#
# **Ejercicio 4 — Model card mínima.** Para el pipeline del laboratorio capstone (o uno
# propio de esta parte), escribe una model card de 6 líneas: propósito, datos, protocolo,
# métrica + baseline, subgrupos evaluados (o su ausencia), limitaciones. Usa las claves
# `evidence` y `limitations` del JSON como insumo.

# %%
# TODO: ejecuta run_lab("capstone", seed=48)
# TODO: comprueba que el resultado incluya las claves 'kind' y 'evidence'
result = None

# %%
# TU RESPUESTA AQUÍ — Ejercicio 2: determinismo
r1 = None  # run_lab("capstone", seed=48)
r2 = None  # run_lab("capstone", seed=48) otra vez
# ¿r1 == r2? ¿qué claves compararías y por qué basta la igualdad del dict completo?

# %%
# TU RESPUESTA AQUÍ — Ejercicio 3: intervalos
media_a, desv_a = 15_800, 900
media_b, desv_b = 14_200, 1_100
solapan = None  # completa: ¿[media_b − desv_b, media_b + desv_b] toca [media_a − desv_a, ...]?

# %% [markdown]
# ## Reflexión
#
# 1. El laboratorio `capstone` integra recuperación, agente y política de permisos, y
#    termina en `release_gate: human_review_required`. ¿Qué equivalente tiene ese gate en un
#    proyecto ML clásico y qué evidencia debería revisar el humano antes de aprobar?
# 2. De las cinco fuentes de irreproducibilidad, ¿cuáles elimina el diseño
#    `run_lab(kind, seed)` de este repositorio y cuáles quedan fuera de su alcance?
# 3. Tu gradient boosting mejora a la logística en 1 600 unidades de costo, con intervalos
#    que se solapan. Defiende ambas decisiones posibles (desplegar / no desplegar) y señala
#    qué dato adicional zanjaría la discusión.
