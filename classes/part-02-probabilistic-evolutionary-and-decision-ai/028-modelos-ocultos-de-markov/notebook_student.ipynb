# %% [markdown]
# # 028 — Modelos ocultos de Markov
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# HMM del clima: `A = [[0.7, 0.3], [0.3, 0.7]]` (filas: lluvia→, sol→), emisiones `P(par|lluvia)=0.9`, `P(par|sol)=0.2`, creencia inicial `(0.5, 0.5)`.
#
# **E1 — Un paso de forward a mano.** Se observa paraguas en t=1. Calcula predicción, corrección y normalización. Reporta `P(lluvia₁ | par₁)` con 3 decimales.
#
# **E2 — Segundo paso.** En t=2 se observa paraguas otra vez. Repite la recurrencia partiendo del resultado de E1. ¿La creencia en lluvia sube o se satura?
#
# **E3 — Evidencia contradictoria.** En t=2 se observa NO paraguas (usa `P(¬par|·) = 1−P(par|·)`). Calcula la nueva creencia y compárala con E2.
#
# **E4 — Markov roto.** Explica en 2-3 frases qué recurrencia deja de ser válida si la emisión de hoy dependiera también del estado de ayer, y cómo cambiaría el costo.

# %%
# TU RESPUESTA AQUÍ
A = [[0.7, 0.3], [0.3, 0.7]]          # A[i][j] = P(x_t=j | x_{t-1}=i); 0=lluvia, 1=sol
B_par = [0.9, 0.2]                     # P(paraguas | estado)
b0 = [0.5, 0.5]

def forward_step(b, obs_par):
    # 1) prediccion: b'[j] = sum_i A[i][j]*b[i]
    # 2) correccion: b''[j] = P(e|j)*b'[j];  3) normaliza
    ...

# %% [markdown]
# ## Reflexión
#
# 1. ¿Qué par de supuestos de independencia hacen que el filtrado cueste `O(|S|²)` por paso en lugar de crecer con la historia completa?
# 2. ¿Por qué la secuencia de Viterbi puede diferir de la secuencia de estados individualmente más probables paso a paso?
# 3. Si el modelo de emisión fuera perfecto (`P(e|x)` determinista y distinto por estado), ¿qué queda del problema? ¿Y si la transición fuera la identidad?
