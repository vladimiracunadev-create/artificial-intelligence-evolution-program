# %% [markdown]
# # 033 — Algoritmos genéticos
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# Problema OneMax con 5 bits. Población inicial: `A=10110 (f=3)`, `B=00101 (f=2)`, `C=11100 (f=3)`, `D=00010 (f=1)`.
#
# **E1 — Ruleta a mano.** Calcula la probabilidad de selección de cada individuo. Si la ruleta gira 4 veces con valores uniformes `[0.10, 0.45, 0.70, 0.95]` (acumulando en orden A,B,C,D), ¿qué padres salen?
#
# **E2 — Una generación completa a mano.** Con los padres de E1 en pares (1º con 2º, 3º con 4º), aplica cruce de un punto tras la posición 2 (los 2 primeros bits del primer padre + resto del segundo, y viceversa). Sin mutación, calcula el fitness de los 4 hijos. ¿Mejoró el mejor? ¿Y el promedio?
#
# **E3 — Mutación.** Al mejor hijo de E2 aplícale mutación en el bit 4 (índice desde 1). ¿Sube o baja su fitness? ¿Qué dice esto del papel de la mutación cerca del óptimo?
#
# **E4 — Elitismo.** Repite conceptualmente E2 pero copiando al mejor de la población inicial en lugar del peor hijo. Demuestra en una frase por qué el máximo de fitness nunca puede retroceder con esta regla.

# %%
# TU RESPUESTA AQUÍ
pob = {"A": "10110", "B": "00101", "C": "11100", "D": "00010"}
f = lambda s: s.count("1")

# E1: acumuladas de la ruleta: A: [0, 3/9), B: [3/9, 5/9), C: [5/9, 8/9), D: [8/9, 1)
# E2: cruce en punto 2: hijo1 = p1[:2] + p2[2:]
# E3: voltea el bit 4 del mejor hijo

# %% [markdown]
# ## Reflexión
#
# 1. En la salida del laboratorio, ¿qué evidencia distingue "el GA convergió" de "el GA se estancó en un óptimo local"? ¿Puede distinguirse con una sola corrida?
# 2. ¿Por qué el cruce de un punto puede producir hijos mejores que ambos padres en OneMax pero rara vez en un problema donde los bits interactúan (epistasis)?
# 3. Si la mutación fuera `p_m = 0.5` por bit, ¿en qué se convierte el algoritmo? ¿Y con `p_m = 0`?
