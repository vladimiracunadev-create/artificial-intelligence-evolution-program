# %% [markdown]
# # 026 — Teorema de Bayes y actualización de creencias
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **E1 — Bayes a mano.** Prevalencia 2 %, sensibilidad 85 %, especificidad 90 %. Calcula `P(enfermo | test+)` con el teorema completo (numerador y normalizador explícitos).
#
# **E2 — Segunda prueba.** Al positivo de E1 se le aplica un segundo test independiente (mismas características) que también da positivo. Usa el posterior de E1 como nuevo prior y calcula el posterior final. ¿Cuánto subió?
#
# **E3 — Forma odds.** Repite E1 con odds: convierte el prior a odds (`0.02/0.98`), multiplica por `LR = 0.85/0.10`, y convierte de vuelta a probabilidad. Verifica que coincide.
#
# **E4 — Sensibilidad al prior.** ¿Con qué prevalencia el posterior de un solo positivo alcanza 0.5? Despeja de `LR · p/(1−p) = 1` y comenta qué significa para poblaciones de bajo riesgo.

# %%
# TU RESPUESTA AQUÍ
prior, sens, esp = 0.02, 0.85, 0.90

# E1: posterior = ...
# E2: usa el posterior de E1 como prior
# E3: odds = prior/(1-prior); LR = sens/(1-esp); ...
# E4: despeja el prior de equilibrio

# %% [markdown]
# ## Reflexión
#
# 1. En la salida del laboratorio, identifica prior, verosimilitud y posterior. ¿Cuál de los tres refleja el diseño del sensor/test y cuál el contexto poblacional?
# 2. ¿Por qué la actualización secuencial exige independencia condicional de las evidencias dado H? Da un ejemplo donde repetir *el mismo* test no aporta información nueva.
# 3. Si el prior fuera 0 o 1, ¿qué hace Bayes con cualquier evidencia posterior? ¿Qué implica eso para declarar certezas absolutas?
