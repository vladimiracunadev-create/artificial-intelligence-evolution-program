# %% [markdown]
# # 036 — Proyecto: sistema híbrido para decisiones
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# Sistema de triaje: prior `P(F) = 0.10`; sensor `P(V|F) = 0.9`, `P(V|¬F) = 0.2`. Utilidades (miles): `U(detener, ·) = −5`; `U(continuar, F) = −40`; `U(continuar, ¬F) = 0`.
#
# **E1 — Capa de creencias.** Se observa vibración. Calcula `P(F | V)` con Bayes (numerador y normalizador explícitos).
#
# **E2 — Capa de decisión.** Con el posterior de E1, calcula `EU(detener)` y `EU(continuar)` y elige. Repite para el caso SIN vibración (`P(F | ¬V)`): ¿cambia la acción?
#
# **E3 — Sensibilidad al prior.** Encuentra el prior de equilibrio: el valor de `P(F)` para el cual, tras observar vibración, `EU(detener) = EU(continuar)`. (Pista: primero halla el posterior de cruce `p* = 5/40`, luego despeja el prior con la forma odds: `odds_post = LR · odds_prior`.) ¿La decisión de E2 es robusta?
#
# **E4 — Capa evolutiva (diseño).** El umbral del sensor `θ` mueve el par (TPR, FPR): con θ bajo, `(0.95, 0.4)`; medio, `(0.9, 0.2)`; alto, `(0.7, 0.05)`. Define la función de fitness que le darías a un GA para elegir θ (qué promedia, sobre qué escenarios, con qué semillas) y calcula a mano la utilidad esperada *a priori* de cada θ (antes de ver el sensor, decidiendo óptimamente tras verlo) para el prior 0.10. ¿Qué umbral gana?

# %%
# TU RESPUESTA AQUÍ
prior = 0.10
U_det, U_cont_F, U_cont_ok = -5.0, -40.0, 0.0

def posterior(p, tpr, fpr, ver_vibracion=True):
    ...

# E1: posterior(0.10, 0.9, 0.2)
# E2: EU con y sin vibracion
# E3: p_cruce = 5/40; odds_prior = odds_post / LR
# E4: para cada (tpr, fpr): EU_total = P(V)*EU(mejor accion|V) + P(no V)*EU(mejor|no V)

# %% [markdown]
# ## Reflexión
#
# 1. En la traza del laboratorio, identifica qué campo pertenece a cada capa (creencia, decisión, optimización, trazabilidad). ¿Falta alguna capa? ¿Qué añadirías?
# 2. ¿Por qué "ajustar el prior para ser más precavidos" es peor diseño que "ajustar la utilidad del falso negativo"? ¿Qué se vuelve inauditable en el primer caso?
# 3. Propón el análisis de sensibilidad mínimo que exigirías antes de dejar que este sistema decida sin revisión humana, y el criterio cuantitativo de abstención.
