# %% [markdown]
# # 030 — Teoría de decisión y utilidad esperada
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **E1 — MEU a mano.** `P(lluvia) = 0.4`. Utilidades: llevar paraguas → 20 (llueva o no, con molestia ya descontada); no llevarlo → 100 si no llueve, −80 si llueve. Calcula ambas utilidades esperadas y decide.
#
# **E2 — Punto de indiferencia.** ¿Con qué `P(lluvia)` empatan las dos acciones de E1? Interpreta el umbral.
#
# **E3 — Aversión al riesgo.** Con `U(x) = √x`, compara la lotería 50/50 entre 0 y 10 000 contra 4 000 seguros. Calcula el equivalente cierto de la lotería y la prima de riesgo.
#
# **E4 — Valor de la información.** En E1, un pronóstico perfecto te dice si lloverá antes de decidir. Calcula `EU(con pronóstico)` y el VOI. ¿Pagarías 10 unidades de utilidad por él?

# %%
# TU RESPUESTA AQUÍ
p_lluvia = 0.4
U = {("con", "llueve"): 20, ("con", "seco"): 20,
     ("sin", "llueve"): -80, ("sin", "seco"): 100}

# E1: EU(con), EU(sin)
# E2: despeja p tal que 20 = p*(-80) + (1-p)*100
# E3: import math; EU_loteria = 0.5*math.sqrt(0)+0.5*math.sqrt(10000)
# E4: EU_perfecta = p*max(fila llueve) + (1-p)*max(fila seco)

# %% [markdown]
# ## Reflexión
#
# 1. ¿Qué axioma de vNM viola alguien que prefiere A a B, B a C y C a A? ¿Por qué esa persona es "explotable" como bomba de dinero?
# 2. En la salida del laboratorio, ¿dónde termina la estimación (probabilidad) y dónde empieza la preferencia (utilidad)? ¿Por qué es un error mezclar ambas?
# 3. Da un caso donde el valor de la información sea exactamente 0 a pesar de que la observación sea muy informativa sobre el estado del mundo.
