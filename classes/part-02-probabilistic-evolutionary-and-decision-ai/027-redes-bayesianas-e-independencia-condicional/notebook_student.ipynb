# %% [markdown]
# # 027 — Redes bayesianas e independencia condicional
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# Red de 5 nodos: `Robo (R) → Alarma (A) ← Terremoto (T)`, `A → Juan (J)`, `A → María (M)`.
#
# **E1 — d-separación.** Para cada par, responde sí/no y nombra el camino que decide: (a) `R ⊥ T`?  (b) `R ⊥ T | A`?  (c) `J ⊥ M | A`?  (d) `R ⊥ J | A`?  (e) `R ⊥ T | M`?
#
# **E2 — Conteo de parámetros.** Con todas las variables binarias, calcula los parámetros libres de la red factorizada y de la conjunta plena. ¿Y si `A` tuviera un tercer padre binario?
#
# **E3 — Inferencia con la factorización.** Con `P(R)=0.01`, `P(T)=0.02`, `P(A|R,T)=0.95`, `P(A|R,¬T)=0.94`, `P(A|¬R,T)=0.29`, `P(A|¬R,¬T)=0.001`, `P(J|A)=0.90`, `P(J|¬A)=0.05`: calcula `P(A)` (probabilidad total sobre los 4 casos de R,T) y luego `P(R | J=sí)` con Bayes.
#
# **E4 — Explaining away numérico.** Compara `P(R | A=sí)` con `P(R | A=sí, T=sí)`. ¿Sube o baja? Explica.

# %%
# TU RESPUESTA AQUÍ
pR, pT = 0.01, 0.02
pA = {(1,1):0.95, (1,0):0.94, (0,1):0.29, (0,0):0.001}
pJ = {1:0.90, 0:0.05}

# E1: razona sobre el grafo (sin código)
# E2: cuenta parámetros
# E3-E4: enumera los 8 mundos (R,T,A) y condiciona

# %% [markdown]
# ## Reflexión
#
# 1. En la red del laboratorio, ¿qué independencia condicional concreta reduce el número de parámetros? Escríbela en notación `X ⊥ Y | Z`.
# 2. ¿Por qué observar un colisionador *crea* dependencia entre sus padres? Explica *explaining away* con las variables de esta clase.
# 3. ¿Qué pasa con la factorización si añades un arco que forme un ciclo? ¿Por qué la definición exige un DAG?
