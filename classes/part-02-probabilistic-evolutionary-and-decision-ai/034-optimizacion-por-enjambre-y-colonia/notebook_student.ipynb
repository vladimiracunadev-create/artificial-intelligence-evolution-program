# %% [markdown]
# # 034 — Optimización por enjambre y colonia
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **E1 — Un paso de PSO a mano.** Partícula: `x = 5`, `v = 2`, `pbest = 4`, `gbest = 1`. Parámetros `w = 0.6`, `c₁ = c₂ = 1.5`, y tiradas `r₁ = 0.4`, `r₂ = 0.8`. Calcula `v'` y `x'` con la fórmula de actualización.
#
# **E2 — Segundo paso.** La función objetivo es `f(x) = x²` (minimizar). Evalúa la nueva posición de E1: ¿actualiza pbest? ¿Y gbest (que estaba en f(1)=1)? Da otro paso con `r₁ = 0.5, r₂ = 0.5`.
#
# **E3 — Feromona a mano.** Dos rutas con feromona inicial `τ_A = τ_B = 1`. En esta iteración la ruta A (costo 2) es recorrida por 2 hormigas y B (costo 4) por 1; cada hormiga deposita `Δτ = 1/costo`. Con evaporación `ρ = 0.5`, calcula `τ_A` y `τ_B` tras la actualización y la probabilidad de elegir A si `p ∝ τ` (α=1, sin heurística).
#
# **E4 — PSO vs GA.** Señala dos diferencias estructurales entre PSO y el GA de la clase 033 (qué se comparte entre individuos, qué operador introduce novedad) y un tipo de problema donde preferirías ACO sobre ambos.

# %%
# TU RESPUESTA AQUÍ
w, c1, c2 = 0.6, 1.5, 1.5
x, v, pbest, gbest = 5.0, 2.0, 4.0, 1.0

# E1: v = w*v + c1*r1*(pbest-x) + c2*r2*(gbest-x); x = x + v
# E2: f = lambda x: x*x ; compara f(x') con f(pbest), f(gbest)
# E3: tau = (1-rho)*tau + suma_de_depositos

# %% [markdown]
# ## Reflexión
#
# 1. En PSO, ¿qué comportamiento colectivo produce `c₂ ≫ c₁`? ¿Y el inverso? Conecta cada régimen con la convergencia prematura o la deriva.
# 2. ¿Por qué la evaporación de feromona en ACO cumple el mismo papel que la mutación en un GA? ¿Qué pasa con ρ = 0?
# 3. El laboratorio muestra mejora entre iteraciones. ¿Qué comparación mínima haría falta para afirmar que el enjambre supera a una búsqueda aleatoria con el mismo presupuesto de evaluaciones?
