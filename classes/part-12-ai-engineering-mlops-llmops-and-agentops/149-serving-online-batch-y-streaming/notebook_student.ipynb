# %% [markdown]
# # 149 — Serving online, batch y streaming
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Tabla de decisión.** Asigna patrón (online / batch / streaming / híbrido)
# a cada caso y justifica con las tres preguntas del README:
#
# a) Score de propensión a cancelar suscripción, usado por el equipo de retención cada lunes.
# b) Moderación de imágenes subidas por usuarios, que deben publicarse «al instante».
# c) Detección de fraude que debe bloquear la transacción antes de aprobarla (< 300 ms).
# d) Features de «gasto en los últimos 10 minutos» para el modelo del caso c).
#
# **Ejercicio 2 — Capacidad a mano.** Un endpoint recibe 90 rps en pico. Cada réplica
# procesa lotes de 6 peticiones en 120 ms. ¿Cuántas réplicas necesitas para el pico con un
# 40 % de margen? ¿Qué throughput máximo tendrías con 5 réplicas?
#
# **Ejercicio 3 — Percentiles.** Un servicio tiene p50 = 40 ms y p99 = 900 ms. El dashboard
# reporta «latencia media 55 ms, todo bien». Explica por qué el promedio engaña aquí y
# calcula la probabilidad de que una página que hace 10 llamadas independientes toque al
# menos una vez el peor 1 %.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("observability", seed=149)`
# e identifica qué elementos de `evidence` corresponden a métricas de latencia y cuáles a
# métricas de throughput o frescura.

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 2
rps_pico = 90
lote = 6
latencia_lote_s = 0.120
margen = 1.40
# throughput_por_replica = ...
# replicas_necesarias = ...
# throughput_5_replicas = ...

# Ejercicio 3
# p_toca_p99 = 1 - (0.99 ** 10)

# Ejercicio 4
# result = run_lab("observability", seed=149)
result = None

# %% [markdown]
# ## Reflexión
#
# 1. Una página compone 20 llamadas a servicios con p99 = 100 ms cada uno: ¿por qué la latencia de la página será mala aunque «solo» el 1 % de las llamadas sea lenta, y qué técnica del serving online lo mitiga?
# 2. ¿Qué requisito habría que cambiar en el ejemplo del e-commerce para que streaming fuera la elección correcta en lugar del híbrido batch+online?
# 3. Si duplicas el tamaño de lote del batching dinámico, ¿qué pasa con el throughput y con el p95, y cómo decidirías el punto de operación?
