# %% [markdown]
# # 153 — Observabilidad: logs, métricas y trazas
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Elegir la señal.** Para cada pregunta, di qué señal la responde mejor
# (log / métrica / traza) y por qué:
#
# a) ¿Cuántas peticiones por segundo sirvió el endpoint esta semana?
# b) ¿Por qué la petición `req-8842` del cliente enterprise tardó 9 s?
# c) ¿Qué excepción exacta ocurrió cuando falló el feature store a las 10:02?
# d) ¿El p99 de latencia cumple el SLO este mes?
#
# **Ejercicio 2 — Leer una traza.** Con esta traza, calcula el porcentaje del tiempo total
# de cada span y di cuál optimizarías primero y qué atributo mirarías para decidir cómo:
#
# ```text
# total /answer: 2 400 ms
#   retrieve_context: 400 ms
#   rerank:           150 ms
#   llm_call:       1 700 ms  (input_tokens=5200, output_tokens=180)
#   guardrail:        150 ms
# ```
#
# **Ejercicio 3 — Diseñar métricas sin romper cardinalidad.** Quieres poder responder
# «tasa de fallback por segmento de usuario (3 segmentos) y por versión de modelo». Diseña
# el nombre de la métrica, su tipo y sus etiquetas. Explica por qué `user_id` NO puede ser
# etiqueta y dónde vive ese detalle.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("observability", seed=153)`
# y clasifica cada elemento de `evidence` como log, métrica o traza según su naturaleza.

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 2
spans = {"retrieve_context": 400, "rerank": 150, "llm_call": 1700, "guardrail": 150}
total = 2400
# porcentajes = ...

# Ejercicio 3
metrica = {
    "nombre": None,      # p. ej. "fallback_total"
    "tipo": None,        # counter / gauge / histogram
    "etiquetas": [],
}

# Ejercicio 4
# result = run_lab("observability", seed=153)
result = None

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué «responde 200 OK» es un criterio de salud casi vacío para un endpoint de LLM, y qué tres señales añadirías para que «sano» signifique algo?
# 2. Con histogramas por span cuyo p95 conoces, ¿por qué NO puedes calcular el p95 del total, y qué señal sí te lo da?
# 3. ¿Qué atributos de un span `gen_ai` usarías para detectar que un cambio de prompt duplicó el costo, y qué riesgo de privacidad introduce exportar el prompt completo?
