# %% [markdown]
# # 156 — Proyecto: plataforma de IA observable
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Presupuesto de error a mano.** Un servicio tiene SLO de
# disponibilidad del 99.5 % en una ventana de 30 días. Calcula el presupuesto de
# error en minutos y en horas. Si en la primera semana se consumieron 150
# minutos, ¿qué fracción del presupuesto queda y qué decisión dispara?
#
# **Ejercicio 2 — Decidir la promoción.** SLO: p95 < 2 s; evals online ≥ 90 %;
# costo ≤ 12 USD/1k. Canary del challenger vs champion:
# p95 = 1.9 s vs 1.5 s; evals online = 92 % vs 90 %; costo = 12.8 vs 10.9
# USD/1k. Decide (promover / no promover / extender canary) y justifica con los
# tres SLO.
#
# **Ejercicio 3 — Mapear incidentes a la capa.** Asigna cada incidente a la
# capacidad de plataforma que falló (145-155) y di qué evidencia lo detectaría:
# a) dos ejecuciones del mismo commit dan métricas distintas;
# b) nadie sabe qué versión de prompt atendió una queja de un cliente;
# c) el costo mensual se triplicó sin cambio de tráfico;
# d) una caída del proveedor tumbó también las rutas que no usan LLM;
# e) el modelo nuevo se promovió «porque en la demo se veía mejor».
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("capstone",
# seed=156)` y comprueba `kind`, `evidence` y `limitations`. ¿Qué elemento del
# contrato corresponde a la idea «cada flecha del ciclo de release produce
# evidencia»?

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1
presupuesto_min = None
presupuesto_h = None
fraccion_restante = None

# Ejercicio 2: 'promover' | 'no promover' | 'extender'
decision = None

# Ejercicio 3: capa por incidente, p. ej. {'a': '146 trazabilidad', ...}
capas = {"a": None, "b": None, "c": None, "d": None, "e": None}

# Ejercicio 4
resultado = None  # run_lab("capstone", seed=156)

# %% [markdown]
# ## Reflexión
#
# 1. En el ejemplo, el rollback no recuperó la calidad: ¿qué evidencia concreta
#    distinguió «prompt malo» de «deriva de datos», y qué habrías concluido sin
#    ella?
# 2. ¿Por qué un SLO de disponibilidad y latencia es insuficiente para un
#    servicio de LLM, y qué dos SLO adicionales propone la materia con qué
#    riesgo de medirlos mal?
# 3. Si tu presupuesto de error mensual se agota en la primera semana, ¿qué
#    decisión organizacional dispara esa señal según el modelo SRE y por qué es
#    preferible a «intentar tener más cuidado»?
