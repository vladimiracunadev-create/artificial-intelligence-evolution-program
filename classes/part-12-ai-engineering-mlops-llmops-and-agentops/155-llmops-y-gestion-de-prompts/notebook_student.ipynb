# %% [markdown]
# # 155 — LLMOps y gestión de prompts
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Decidir la publicación.** Regla: bloqueantes sin regresión; blandos con
# tolerancia 0.05; presupuesto ≤ 500 tokens de entrada. Suite con k = 10:
#
# ```text
#                        v8 (actual)   v9 (candidata)
# JSON válido            580/600       600/600
# cláusula de seguridad  600/600       594/600
# exactitud (juez)       0.78          0.85
# concisión (juez)       0.80          0.77
# tokens de entrada      420           480
# ```
#
# ¿Se publica v9? Evalúa criterio a criterio.
#
# **Ejercicio 2 — Tasas, no booleanos.** El caso «reembolso parcial» aprueba 7/10 con v8 y
# 9/10 con v9. ¿Puedes afirmar que v9 lo mejoró? Calcula cuántas corridas totales
# necesitarías al menos para que una diferencia 0.7 vs 0.9 fuera creíble (razona con el
# error estándar de una proporción, sin fórmula exacta no hay problema: estima).
#
# **Ejercicio 3 — Diseño de suite.** Para un asistente que redacta respuestas a reclamos
# de clientes, propone: 2 casos normales, 2 límite, 2 adversarios, y para cada uno el tipo
# de grader (exacto / programático / juez con rúbrica). Señala cuál de los seis casos
# alimentarías desde incidentes reales.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("observability", seed=155)`
# y mapea sus elementos de `evidence` al ciclo editar → evaluar → publicar → observar.

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1
v8 = {"json": 580/600, "clausula": 600/600, "exactitud": 0.78, "concision": 0.80, "tokens": 420}
v9 = {"json": 600/600, "clausula": 594/600, "exactitud": 0.85, "concision": 0.77, "tokens": 480}
TOLERANCIA_BLANDOS = 0.05
# publicar = ...

# Ejercicio 2
# aprox: error estándar de una proporción ~ sqrt(p*(1-p)/n)

# Ejercicio 4
# result = run_lab("observability", seed=155)
result = None

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué las versiones de prompt deben ser inmutables, y qué se pierde si producción apunta a un texto editable en caliente?
# 2. Tu suite aprueba v13 con juez claude-X; el proveedor deprecia claude-X y el juez pasa a claude-Y: ¿qué pasa con la comparabilidad de tu serie histórica de scores y cómo lo mitigas?
# 3. Diseña dos proxies de producción que delatarían que el modelo del proveedor cambió bajo tu prompt sin que tú tocaras nada, y justifica por qué se moverían.
