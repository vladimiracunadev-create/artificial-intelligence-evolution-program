# %% [markdown]
# # 157 — Costo, latencia, caching y capacidad
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Costo mensual a mano.** Un asistente hace 50 000
# peticiones/mes con 1 200 tokens de entrada y 400 de salida; p_in = 3 USD/MTok,
# p_out = 15 USD/MTok. Calcula el costo por petición y el costo mensual.
#
# **Ejercicio 2 — Ahorro por prompt caching.** Del total de entrada, 800 tokens
# son un prefijo estable cacheable a 0.3 USD/MTok con tasa de acierto 0.8.
# Recalcula el costo por petición y el mensual, y expresa el ahorro en USD y %.
#
# **Ejercicio 3 — Percentiles contra promedio.** Latencias (ms) de 10
# peticiones: 420, 380, 450, 400, 3900, 410, 430, 390, 440, 4100. Calcula el
# promedio, la mediana (p50) y el p95 (regla del rango: el valor en la posición
# ⌈0.95·n⌉ de la lista ordenada). ¿Qué cuenta cada cifra y cuál usarías para un
# SLO?
#
# **Ejercicio 4 — Capacidad con ley de Little.** Pico de λ = 4 req/s, tiempo de
# servicio S = 3 s, cada réplica atiende 6 peticiones concurrentes. Calcula la
# concurrencia media L, el mínimo teórico de réplicas y las réplicas necesarias
# con margen ρ ≤ 0.6.

# %%
# TU RESPUESTA AQUÍ

MTOK = 1_000_000

# Ejercicio 1
costo_peticion = None
costo_mensual = None

# Ejercicio 2
costo_peticion_cache = None
ahorro_mensual = None

# Ejercicio 3
lat = [420, 380, 450, 400, 3900, 410, 430, 390, 440, 4100]
promedio = None
p50 = None
p95 = None

# Ejercicio 4
L = None
replicas_minimas = None
replicas_con_margen = None

# %% [markdown]
# ## Reflexión
#
# 1. Tu servicio reporta latencia promedio de 900 ms y los usuarios se quejan de
#    lentitud: ¿qué percentiles pedirías y por qué el promedio puede ocultar el
#    problema si cada sesión hace varias llamadas?
# 2. La caché semántica subió su tasa de aciertos del 20 % al 45 % tras bajar el
#    umbral de similitud: ¿qué métrica adicional necesitas antes de celebrar el
#    ahorro y cómo la medirías?
# 3. Si duplicas las réplicas para bajar la espera en cola, ¿qué parte del costo
#    por petición NO cambia y qué palanca tendrías que tocar para reducirla?
