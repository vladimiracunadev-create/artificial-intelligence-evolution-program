# %% [markdown]
# # 153 — AgentOps y análisis de trayectorias
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Métricas a mano.** Un agente ejecutó 8 tareas:
#
# ```text
# tarea  éxito(eval)  pasos  costo($)  intervención
# t1     sí           3      0.03      no
# t2     sí           5      0.05      no
# t3     no           12     0.14      sí (abortada)
# t4     sí           4      0.04      no
# t5     no           12     0.13      no
# t6     sí           6      0.06      no
# t7     sí           4      0.05      sí (aprobación)
# t8     sí           3      0.03      no
# ```
#
# Calcula: tasa de éxito, pasos p50, costo medio, tasa de intervención. ¿Qué patrón
# comparten las dos tareas fallidas y qué hipótesis investigarías primero?
#
# **Ejercicio 2 — Éxito declarado vs. verificado.** De 100 tareas, el agente declaró éxito
# en 92; la eval externa confirma 81 de esas 92 y encuentra 3 éxitos entre las 8 que el
# agente dio por fallidas. Calcula la tasa de éxito real y la tasa de falsos éxitos
# declarados. ¿Cuál de los dos errores (falso éxito / falso fallo) es más peligroso en
# producción y por qué?
#
# **Ejercicio 3 — Diseñar el span de herramienta.** Escribe (como dict) los atributos que
# registrarías en el span de una llamada a `crear_reembolso` para que el cluster A del
# README hubiera sido detectable con una consulta, y escribe esa consulta en pseudocódigo.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("observability", seed=153)`
# e identifica qué elementos de `evidence` corresponderían a spans de trayectoria y qué
# falta para calcular las cuatro métricas de agente.

# %%
# TU RESPUESTA AQUÍ
import statistics

tareas = [
    {"id": "t1", "exito": True,  "pasos": 3,  "costo": 0.03, "interv": False},
    {"id": "t2", "exito": True,  "pasos": 5,  "costo": 0.05, "interv": False},
    {"id": "t3", "exito": False, "pasos": 12, "costo": 0.14, "interv": True},
    {"id": "t4", "exito": True,  "pasos": 4,  "costo": 0.04, "interv": False},
    {"id": "t5", "exito": False, "pasos": 12, "costo": 0.13, "interv": False},
    {"id": "t6", "exito": True,  "pasos": 6,  "costo": 0.06, "interv": False},
    {"id": "t7", "exito": True,  "pasos": 4,  "costo": 0.05, "interv": True},
    {"id": "t8", "exito": True,  "pasos": 3,  "costo": 0.03, "interv": False},
]
# tasa_exito = ...
# pasos_p50 = ...
# costo_medio = ...
# tasa_intervencion = ...

# Ejercicio 3
span_herramienta = {
    # "tool.name": ...,
}

# Ejercicio 4
# result = run_lab("observability", seed=153)
result = None

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué el éxito auto-reportado por el agente sobreestima el éxito real, y qué tres formas de verificación externa podrías usar según el tipo de tarea?
# 2. En el ejemplo, el arreglo del cluster A fue mejorar el mensaje de error de la herramienta, no el prompt: ¿qué te dice eso sobre dónde vive el «comportamiento» de un agente?
# 3. ¿Qué condiciones debe cumplir un replay de trayectorias para que la comparación entre la configuración vieja y la nueva sea válida?
