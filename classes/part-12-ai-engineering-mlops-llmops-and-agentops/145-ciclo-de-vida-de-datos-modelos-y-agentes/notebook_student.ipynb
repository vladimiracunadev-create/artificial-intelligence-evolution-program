# %% [markdown]
# # 145 — Ciclo de vida de datos, modelos y agentes
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Clasificar incidentes por ciclo.** Asigna cada incidente al ciclo donde
# vive su causa raíz (datos / modelo / agente) y justifica en una línea:
#
# a) El proveedor del LLM actualizó el modelo base y el agente empezó a llamar una herramienta con argumentos mal formados.
# b) Una feature de entrenamiento quedó con 40 % de nulos tras un cambio en la app móvil.
# c) El AUC offline era 0.85 pero en producción el modelo ve una población distinta a la del split de validación.
# d) Nadie puede decir con qué semilla ni con qué snapshot de datos se entrenó el modelo en producción.
#
# **Ejercicio 2 — Linaje a mano.** Con la tabla del README (`ds-2025-12`, `churn-v7`,
# endpoint `prod`), escribe qué artefactos habría que regenerar (y cuáles no) si:
# (i) cambia el código de features, (ii) llega un mes nuevo de datos, (iii) solo cambia
# la configuración de serving (número de réplicas).
#
# **Ejercicio 3 — Ritmos de cambio.** Ordena los tres ciclos por frecuencia de cambio
# esperada en un sistema con agente LLM en producción y explica por qué el ciclo más
# rápido determina la frecuencia mínima de monitoreo.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("workflow", seed=145)` y
# verifica que el resultado incluye `kind`, `evidence` y `limitations`. Anota qué etapa
# del ciclo representa cada elemento de `evidence`.

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1: clasifica a), b), c), d) como 'datos' / 'modelo' / 'agente'
incidentes = {"a": None, "b": None, "c": None, "d": None}

# Ejercicio 2: para cada cambio, lista los artefactos a regenerar
regenerar = {
    "codigo_features": [],
    "mes_nuevo_datos": [],
    "config_serving": [],
}

# Ejercicio 4:
# result = run_lab("workflow", seed=145)
# assert result["kind"] == "workflow" and result["evidence"]
result = None

# %% [markdown]
# ## Reflexión
#
# 1. Si el mismo commit de código produce dos modelos con métricas distintas, ¿qué elementos del ciclo de modelo faltó fijar y en qué artefacto deberían quedar registrados?
# 2. ¿Por qué el ciclo de agentes tiene una fuente de cambio que ni el ciclo de datos ni el de modelos tienen, y qué prueba periódica agregarías por esa razón?
# 3. En el incidente de churn del ejemplo, ¿qué evidencia concreta te permitió descartar el ciclo de modelo como causa raíz, y qué habría pasado sin ella?
