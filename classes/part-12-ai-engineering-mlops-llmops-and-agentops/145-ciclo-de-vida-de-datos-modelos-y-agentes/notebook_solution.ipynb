# %% [markdown]
# # 145 — Ciclo de vida de datos, modelos y agentes
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Solución de referencia
#
# **Ejercicio 1.**
# a) **Agente**: el disparador es el modelo base + entorno de herramientas; ni tus datos ni
# tus pesos cambiaron. b) **Datos**: fallo de calidad/esquema aguas arriba. c) **Modelo**
# (con frontera hacia datos): el split de validación no representa la población servida —
# error de diseño de evaluación del ciclo de modelo. d) **Modelo**: linaje roto; el
# artefacto registrado carece de identidad (dataset + semilla + commit).
#
# **Ejercicio 2.** (i) Cambiar código de features invalida el dataset transformado y el
# modelo: regenerar `ds-2025-12` (transformado), reentrenar `churn-v7` → `v8`, re-evaluar y
# re-desplegar; el endpoint como recurso permanece, solo cambia la versión que sirve.
# (ii) Mes nuevo: nuevo `ds-2026-01`; el modelo actual **no** se invalida automáticamente —
# se reentrena solo si la política (deriva o calendario) lo indica. (iii) Config de
# serving: no se regenera ningún artefacto de datos ni de modelo; solo cambia la
# configuración del despliegue, que también se versiona.
#
# **Ejercicio 3.** datos ≥ agente > modelo. Los datos cambian con el mundo (continuo); la
# configuración del agente cambia con ajustes frecuentes de prompt/herramientas y además el
# proveedor puede cambiar el modelo base sin avisarte; el modelo propio cambia por decisión.
# El monitoreo debe muestrear al ritmo del ciclo más rápido: de nada sirve evaluar
# mensualmente un flujo cuyos datos derivan cada semana.
#
# **Ejercicio 4.** El contrato se valida en la celda siguiente: `kind` identifica el motor
# didáctico, `evidence` lista hechos inspeccionables (etapas ejecutadas del flujo) y
# `limitations` impide leer la demo como producción.

# %%
result = run_lab("workflow", seed=145)
assert result["kind"] == "workflow"
assert result["evidence"]
show(result)

# %% [markdown]
# ## Reflexión
#
# 1. Si el mismo commit de código produce dos modelos con métricas distintas, ¿qué elementos del ciclo de modelo faltó fijar y en qué artefacto deberían quedar registrados?
# 2. ¿Por qué el ciclo de agentes tiene una fuente de cambio que ni el ciclo de datos ni el de modelos tienen, y qué prueba periódica agregarías por esa razón?
# 3. En el incidente de churn del ejemplo, ¿qué evidencia concreta te permitió descartar el ciclo de modelo como causa raíz, y qué habría pasado sin ella?
