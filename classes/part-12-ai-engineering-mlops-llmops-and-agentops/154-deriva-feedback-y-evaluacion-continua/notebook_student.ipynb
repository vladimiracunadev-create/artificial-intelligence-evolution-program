# %% [markdown]
# # 154 — Deriva, feedback y evaluación continua
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — PSI a mano.** La feature `edad` se binó en cuartiles del baseline
# (p = 0.25 por bin). Este mes: `q = [0.30, 0.28, 0.24, 0.18]`. Calcula el PSI término a
# término (usa 3 decimales en los logaritmos) y clasifícalo con la convención
# 0.10 / 0.25. ¿Hacia dónde se movió la población?
#
# **Ejercicio 2 — Clasificar la deriva.** Para cada caso, di si es deriva de datos, de
# etiquetas o de concepto, y si el PSI sobre las features la detectaría:
#
# a) Una promoción atrae por primera vez a clientes de un país nuevo.
# b) Tras una subida de tipos de interés, clientes con el mismo perfil de siempre empiezan a impagar más.
# c) El equipo de producto cambia la definición de «churn» de 30 a 60 días sin avisar.
#
# **Ejercicio 3 — El bin vacío.** Con p = [0.5, 0.5, 0.0] y q = [0.4, 0.4, 0.2], el tercer
# término del PSI es imposible de calcular tal cual. Explica por qué y aplica el remedio
# estándar (suavizado: sustituir 0 por ε = 0.001 y renormalizar o no, según convención).
# ¿Qué te dice el resultado sobre la sensibilidad del PSI a bins nuevos?
#
# **Ejercicio 4 — Política de acción.** Ejecuta `run_lab("evaluation", seed=154)` y, con la
# convención del README, escribe una política de tres niveles (seguir / investigar /
# actuar) para el monitoreo de una feature crítica, indicando qué evidencia adicional exige
# cada nivel antes de reentrenar.

# %%
# TU RESPUESTA AQUÍ
import math

def psi(p, q):
    # TODO: implementa Σ (q_i - p_i) * ln(q_i / p_i)
    ...

# Ejercicio 1
p = [0.25, 0.25, 0.25, 0.25]
q = [0.30, 0.28, 0.24, 0.18]
# print(psi(p, q))

# Ejercicio 3
p3 = [0.5, 0.5, 0.0]
q3 = [0.4, 0.4, 0.2]
EPS = 1e-3
# ...

# Ejercicio 4
# result = run_lab("evaluation", seed=154)
result = None

# %% [markdown]
# ## Reflexión
#
# 1. Construye un ejemplo concreto de concept drift donde `P(X)` no cambie en absoluto: ¿qué señal lo detectaría y con cuánto retardo?
# 2. ¿Por qué cada término del PSI es no negativo, y qué implica eso sobre la posibilidad de que dos cambios «se cancelen» entre bins?
# 3. Tu PSI del score dio 0.30 pero la métrica con etiquetas diferidas (cohorte de hace 90 días) sigue estable: ¿qué tres hipótesis explican la discrepancia y cómo distinguirías entre ellas?
