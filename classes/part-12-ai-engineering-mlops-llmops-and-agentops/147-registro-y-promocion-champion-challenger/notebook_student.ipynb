# %% [markdown]
# # 147 — Registro y promoción champion-challenger
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Decidir la promoción a mano.** Regla: promover si Δaccuracy ≥ +0.01;
# guardas: p95 ≤ 200 ms y tasa de predicciones nulas ≤ 0.5 %. Datos de evaluación
# simultánea en sombra:
#
# ```text
#                champion   challenger
# accuracy       0.914      0.928
# p95            145 ms     198 ms
# pred. nulas    0.2 %      0.4 %
# ```
#
# ¿Se promueve? Evalúa cada condición por separado y da el veredicto.
#
# **Ejercicio 2 — La comparación trampa.** Un ingeniero propone promover porque «el
# challenger dio accuracy 0.93 en validación de enero y el champion tenía 0.90 cuando se
# desplegó en octubre». Señala los dos defectos metodológicos de esa comparación.
#
# **Ejercicio 3 — Máquina de estados.** Escribe la secuencia de estados por la que pasa una
# versión que: se registra, se evalúa, pierde contra el champion, y seis meses después se
# rescata como rollback de emergencia. ¿Es válida esa última transición en el diagrama del
# README? ¿Qué condición debería exigir?
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("workflow", seed=147)` y
# localiza en `evidence` qué elementos jugarían el papel de «evaluación» y de «decisión»
# en un flujo champion-challenger.

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1
champion = {"accuracy": 0.914, "p95_ms": 145, "nulas_pct": 0.2}
challenger = {"accuracy": 0.928, "p95_ms": 198, "nulas_pct": 0.4}
DELTA_MIN = 0.01
# promover = ...

# Ejercicio 4
# result = run_lab("workflow", seed=147)
# assert result["kind"] == "workflow" and result["evidence"]
result = None

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué `delta_min > 0` en la regla de promoción, si cualquier mejora del AUC parece deseable? ¿Qué costos ignora un delta_min = 0?
# 2. En el ejemplo, v8 mejora el AUC global pero empeora un segmento: ¿qué mecanismo de la regla lo detectó y qué habría pasado evaluando solo la métrica primaria?
# 3. ¿Qué preguntas puede responder el shadow mode y cuáles solo puede responder un canario con tráfico real? Da un ejemplo de cada una.
