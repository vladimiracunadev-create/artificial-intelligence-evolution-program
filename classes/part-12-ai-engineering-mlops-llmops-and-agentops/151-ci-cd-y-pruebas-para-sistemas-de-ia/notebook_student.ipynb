# %% [markdown]
# # 151 — CI/CD y pruebas para sistemas de IA
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Clasificar tests.** Para cada verificación, indica su eje (datos /
# modelo / comportamiento / infraestructura) y si debería **bloquear** o **alertar**:
#
# a) La columna `pais` trae un valor fuera del catálogo de 24 países.
# b) La media de `monto` subió 8 % respecto a la semana pasada.
# c) Accuracy del candidato: 0.88 vs. 0.91 del baseline (umbral de bloqueo: −0.02).
# d) Al parafrasear la reseña «me encantó» como «me gustó muchísimo», el sentimiento cambia de positivo a negativo.
# e) El pipeline de entrenamiento tarda 4× más que su promedio histórico.
#
# **Ejercicio 2 — Predecir el veredicto.** Con el pipeline del README (umbral de bloqueo de
# métrica −0.01, direccional 1 %), da el veredicto (pasa / alerta / bloquea) para:
# `Δaccuracy = −0.008`, `violaciones direccionales = 0.6 %`, `casos mínimos = 39/40`.
#
# **Ejercicio 3 — Skew offline/online.** La feature `dias_desde_ultima_compra` se calcula
# offline con `fecha_corte − ultima_compra` y online con `hoy − ultima_compra`. Explica por
# qué los tests unitarios de ambas implementaciones pueden pasar y aun así existir skew,
# y diseña la verificación que lo detectaría.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("evaluation", seed=151)` y
# clasifica cada elemento de `evidence` según el eje de prueba al que pertenecería en un
# CI real.

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1: eje y acción por cada caso
clasificacion = {
    "a": {"eje": None, "accion": None},
    "b": {"eje": None, "accion": None},
    "c": {"eje": None, "accion": None},
    "d": {"eje": None, "accion": None},
    "e": {"eje": None, "accion": None},
}

# Ejercicio 2
delta_accuracy = -0.008
violaciones_direccionales = 0.006
casos_minimos = (39, 40)
# veredicto = ...

# Ejercicio 4
# result = run_lab("evaluation", seed=151)
result = None

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué el smoke train con 5 % de los datos es un test valioso aunque su métrica no sirva para decidir promoción? ¿Qué clase de errores atrapa?
# 2. Da un ejemplo concreto (de tu dominio) de test de invariancia y uno direccional, y explica qué bug de pipeline detectaría cada uno.
# 3. ¿Qué criterio usarías para decidir si un test nuevo entra como bloqueo o como alerta, y qué señal te diría que está mal clasificado?
