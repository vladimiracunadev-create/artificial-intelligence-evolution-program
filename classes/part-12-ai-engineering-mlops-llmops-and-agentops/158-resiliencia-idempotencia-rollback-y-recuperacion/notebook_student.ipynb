# %% [markdown]
# # 158 — Resiliencia, idempotencia, rollback y recuperación
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Backoff a mano.** Con `base = 0.25 s`, `tope = 10 s`, máximo
# 5 intentos y full jitter, escribe la cota superior de cada espera, el peor
# caso de espera acumulada y la espera media acumulada (media de U(0,m) = m/2).
#
# **Ejercicio 2 — Predecir el breaker.** Umbral: 3 fallos en ventana;
# recuperación: 30 s. Estado inicial: cerrado. Secuencia: F, F, É, F, F, F,
# (pasan 30 s), llamada de prueba É. Indica el estado del breaker después de
# cada evento (la ventana no se reinicia con un éxito aislado).
#
# **Ejercicio 3 — ¿Idempotente o no?** Clasifica y justifica en una línea:
# a) `PUT saldo = 100`; b) `saldo += 10`; c) `crear_pedido(idempotency_key=K)`;
# d) `enviar_correo(destinatario, cuerpo)` sin clave; e) `DELETE recurso/42`.
#
# **Ejercicio 4 — Compensar una saga.** Saga de un agente:
# T₁ reservar sala / C₁ cancelar sala; T₂ crear evento / C₂ borrar evento;
# T₃ invitar asistentes / C₃ retirar invitaciones; T₄ pedir catering / C₄
# cancelar catering. T₄ falla de forma definitiva. Escribe la secuencia exacta
# de compensaciones y explica qué garantiza (y qué NO garantiza) la saga sobre
# los estados intermedios.

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1
cotas = []            # cota superior de cada espera, en segundos
peor_caso = None
media_acumulada = None

# Ejercicio 2: estados tras cada evento ('cerrado' | 'abierto' | 'semiabierto')
estados = []

# Ejercicio 3
idempotentes = {"a": None, "b": None, "c": None, "d": None, "e": None}

# Ejercicio 4
compensaciones = []   # en orden de ejecución

# %% [markdown]
# ## Reflexión
#
# 1. Un equipo añadió reintentos «para robustez» a una llamada que crea pedidos y
#    aparecieron pedidos duplicados: ¿qué faltó exactamente y en qué lado
#    (cliente o servidor) se implementa?
# 2. Durante una caída parcial del proveedor de LLM, la latencia p99 de TODO tu
#    sistema se multiplicó aunque la mayoría de peticiones no usaban el LLM:
#    ¿qué antipatrón de Nygard describe esto y qué patrón lo corta?
# 3. ¿Por qué el rollback del prompt a la versión anterior puede no recuperar la
#    calidad, y qué evidencia (clases 153-156) te permitiría distinguir la causa
#    en horas y no en semanas?
