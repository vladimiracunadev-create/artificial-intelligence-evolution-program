# %% [markdown]
# # 146 — Experimentos, semillas y trazabilidad
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Media y desviación a mano.** Config A obtuvo AUC = 0.790, 0.798, 0.794 y
# config B obtuvo AUC = 0.803, 0.775, 0.792 con semillas {1,2,3}. Calcula media y
# desviación estándar muestral de cada una. ¿Cuál elegirías y con qué justificación?
#
# **Ejercicio 2 — Detectar el run irreproducible.** De estos tres registros, indica cuál
# NO es relanzable y qué campo falta:
#
# ```text
# run_a: params={lr:0.1, seed:7, dataset:ds-11 (hash 4c…)}, commit=91ff, metrics={auc:0.81}
# run_b: params={lr:0.1, dataset:"tabla_clientes"}, commit=91ff, metrics={auc:0.84}
# run_c: params={lr:0.05, seed:7, dataset:ds-11 (hash 4c…)}, commit=91ff, metrics={auc:0.79}
# ```
#
# **Ejercicio 3 — Semilla y estabilidad.** Ejecuta `run_lab("observability", seed=146)` dos
# veces y compara los resultados. Luego ejecuta con `seed=147`. ¿Qué cambia, qué no, y qué
# propiedad del protocolo de experimentos ilustra?
#
# **Ejercicio 4 — Linaje.** Dibuja (como lista de aristas `origen -> destino`) el grafo de
# linaje del ejemplo del README (`datos_crudos`, `ds-2025-12`, `features_v3`, `run_0042`,
# `churn-v7`, `commit a1b2c3`, `seed 42`). Marca qué nodos quedan obsoletos si cambia
# `features_v3`.

# %%
# TU RESPUESTA AQUÍ
import statistics

# Ejercicio 1
A = [0.790, 0.798, 0.794]
B = [0.803, 0.775, 0.792]
# media_A, desv_A = ...
# media_B, desv_B = ...

# Ejercicio 3
# r1 = run_lab("observability", seed=146)
# r2 = run_lab("observability", seed=146)
# r3 = run_lab("observability", seed=147)
# compara r1 == r2 y r1 vs r3

# Ejercicio 4: lista de aristas
aristas = [
    # ("datos_crudos", "ds-2025-12"),
]
result = None

# %% [markdown]
# ## Reflexión
#
# 1. Fijaste `seed=146` y dos corridas en máquinas distintas dieron métricas diferentes: enumera al menos tres causas posibles y el control que neutraliza cada una.
# 2. ¿Por qué reportar el mejor run entre 10 semillas es metodológicamente equivalente a evaluar en el conjunto de entrenamiento? ¿Qué estadístico reportarías en su lugar?
# 3. Si el hash del snapshot de datos no se hubiera registrado en el run, ¿qué preguntas de linaje (procedencia e impacto) se vuelven incontestables?
