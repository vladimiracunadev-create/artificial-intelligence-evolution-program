# %% [markdown]
# # 169 — IA neuro-simbólica
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — Clasificar con la taxonomía de Kautz
#
# Clasifica cada sistema en uno de los seis tipos de Kautz y justifica en una línea:
#
# a) AlphaGo (búsqueda MCTS que consulta una red para evaluar posiciones).
# b) Un LLM que escribe código Python y un intérprete lo ejecuta (PAL / tool use).
# c) Una red entrenada con una pérdida extra que penaliza violar la regla
#    "un semáforo no puede estar en rojo y verde a la vez".
# d) Un chatbot puro: texto de entrada, texto de salida, sin herramientas.

# %%
# TU RESPUESTA AQUÍ (completa el diccionario con el tipo 1-6 y una justificación)
respuestas = {
    "a": ("", ""),
    "b": ("", ""),
    "c": ("", ""),
    "d": ("", ""),
}

# %% [markdown]
# ## Ejercicio 2 — Cálculo a mano: percepción + regla
#
# La red dice: imagen A: P(1)=0.6, P(7)=0.4; imagen B: P(4)=0.55, P(9)=0.45.
# La regla del dominio es: **la suma es par**.
#
# a) Calcula la probabilidad de los cuatro mundos posibles.
# b) ¿Qué mundos cumplen la regla? Renormaliza sobre ellos.
# c) ¿Cuál es ahora la lectura más probable de (A, B)? ¿Coincide con el argmax
#    sin restricción?

# %%
# TU RESPUESTA AQUÍ — puedes verificar tu cálculo manual con código
p_a = {1: 0.6, 7: 0.4}
p_b = {4: 0.55, 9: 0.45}
# mundos = ...
# validos = ...
# renormalizados = ...

# %% [markdown]
# ## Ejercicio 3 — La regla simbólica del laboratorio
#
# Ejecuta `run_lab("frontier", seed=169)`. La regla que decide qué afirmación entra
# al currículo es simbólica y dura.
#
# a) Escribe la regla en pseudocódigo (una línea).
# b) ¿Qué afirmación queda excluida y por qué?
# c) Explica por qué esta decisión es *verificable por construcción*, a diferencia
#    de una decisión tomada por una red entrenada.

# %%
# TU RESPUESTA AQUÍ
result = run_lab("frontier", seed=169)
show(result)
# regla = "..."

# %% [markdown]
# ## Ejercicio 4 — Cuándo NO conviene el híbrido
#
# Da un ejemplo de tarea donde añadir una regla simbólica dura *empeoraría* el
# sistema, y explica qué supuesto de la regla falla. (Pista: revisa el error
# conceptual 5 del README.)
