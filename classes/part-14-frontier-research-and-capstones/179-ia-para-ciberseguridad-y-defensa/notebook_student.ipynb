# %% [markdown]
# # 179 — IA para ciberseguridad y defensa
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — Falacia de la tasa base
#
# Un detector de malware en endpoints analiza 500,000 procesos/día; 50 son maliciosos.
# TPR = 0.98, FPR = 0.005.
#
# a) Calcula TP, FP y P(malicioso | alerta) a mano.
# b) El proveedor propone una mejora A (TPR→0.999) o una mejora B (FPR→0.0005), al
#    mismo precio. Calcula la precisión por alerta con cada una. ¿Cuál compras?
# c) Enuncia en una frase la lección general (falacia de la tasa base).

# %%
# TU RESPUESTA AQUÍ
N, malos = 500_000, 50
tpr, fpr = 0.98, 0.005
# tp = ...
# fp = ...
# precision = ...

# %% [markdown]
# ## Ejercicio 2 — Clasificar señales
#
# Para cada observación, indica si un sistema de FIRMAS o uno de ANOMALÍAS tiene más
# probabilidad de detectarla, y qué costo de error introduce ese enfoque:
#
# a) Un ransomware conocido, con hash ya publicado en feeds de inteligencia.
# b) Una variante nueva del mismo ransomware, recompilada para cambiar su hash.
# c) Un administrador legítimo copiando una base de datos completa a las 3 a.m.
#    por una migración planificada.
# d) Exfiltración lenta: 2 MB/día hacia un dominio nuevo durante meses.

# %%
# TU RESPUESTA AQUÍ
respuestas = {
    "a": ("", ""),  # (firmas/anomalías, costo de error)
    "b": ("", ""),
    "c": ("", ""),
    "d": ("", ""),
}

# %% [markdown]
# ## Ejercicio 3 — El laboratorio como pipeline de triaje
#
# Ejecuta `run_lab("frontier", seed=179)`.
#
# a) Mapea el contrato del resultado al triaje de un SOC: ¿qué juega el papel de la
#    "alerta", qué el de la "evidencia citable" y qué el de los "límites del veredicto"?
# b) Escribe una función `triar(resultado)` que devuelva "escalar" si hay evidencia y
#    "descartar documentando" si no — y explica por qué nunca devuelve "responder
#    automáticamente".

# %%
# TU RESPUESTA AQUÍ
r = run_lab("frontier", seed=179)
show(r)

def triar(resultado):
    # return ...
    pass

# %% [markdown]
# ## Ejercicio 4 — Doble uso y prompt injection
#
# Un equipo propone: "el LLM leerá cada correo entrante y, si detecta phishing,
# borrará el correo y revocará las sesiones del usuario automáticamente".
#
# Identifica: (1) el vector de prompt injection exacto en ese diseño, (2) el daño que
# causaría un falso positivo con la respuesta automática, (3) una versión del sistema
# que conserve el valor del LLM eliminando ambos riesgos. Justifica cada punto.
