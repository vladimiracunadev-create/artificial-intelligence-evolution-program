# %% [markdown]
# # 171 — World models y simulación interna
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — Roles V, M, C
#
# Para un coche autónomo simulando internamente antes de cambiar de carril,
# asigna cada función al módulo correcto (V, M o C) del esquema de Ha & Schmidhuber:
#
# a) Comprimir la imagen de las cámaras en un vector de estado.
# b) Predecir dónde estarán los otros coches en 2 segundos si aceleramos.
# c) Decidir accionar el intermitente y girar.
# d) Estimar la distribución (no un único valor) de posiciones futuras del camión.

# %%
# TU RESPUESTA AQUÍ
roles = {"a": "", "b": "", "c": "", "d": ""}

# %% [markdown]
# ## Ejercicio 2 — Imaginación a mano
#
# Usa la dinámica del README: `avanzar: A→B 0.9, A→A 0.1; B→C 0.8, B→B 0.2` y
# `saltar: A→C 0.4, A→A 0.6; B→C 0.5, B→B 0.5`. Recompensa 1 al entrar en C.
#
# a) Calcula el retorno esperado del plan mixto [avanzar, saltar] desde A,
#    horizonte 2.
# b) Compáralo con [avanzar, avanzar] (0.72) y [saltar, saltar] (0.64):
#    ¿cuál es ahora el mejor plan?
# c) Escribe código que evalúe los 4 planes de longitud 2 por enumeración.

# %%
# TU RESPUESTA AQUÍ
T = {
    "avanzar": {"A": {"B": 0.9, "A": 0.1}, "B": {"C": 0.8, "B": 0.2}, "C": {"C": 1.0}},
    "saltar":  {"A": {"C": 0.4, "A": 0.6}, "B": {"C": 0.5, "B": 0.5}, "C": {"C": 1.0}},
}
def retorno_esperado(plan, estado="A"):
    # recompensa 1 la PRIMERA vez que se entra en C
    ...  # TU CÓDIGO

# %% [markdown]
# ## Ejercicio 3 — Explotación del modelo
#
# El modelo estima B→C con avanzar en 0.8, pero la probabilidad real es 0.5.
#
# a) Recalcula el retorno REAL de [avanzar, avanzar] y compara con el imaginado.
# b) ¿Qué plan habría sido mejor en el mundo real?
# c) Nombra dos mitigaciones concretas (del README) y explica cómo habrían
#    ayudado exactamente en este caso.

# %% [markdown]
# ## Ejercicio 4 — Afirmaciones de frontera sobre world models
#
# Ejecuta `run_lab("frontier", seed=171)`. Redacta tres afirmaciones sobre world
# models (una `current` con evidencia citable, una `needs_replication`, una
# `unverified`) siguiendo el formato `claims` del resultado, y justifica la
# madurez que asignaste a cada una.

# %%
# TU RESPUESTA AQUÍ
result = run_lab("frontier", seed=171)
show(result)
mis_claims = [
    {"claim": "", "evidence": "", "maturity": "current"},
    {"claim": "", "evidence": "", "maturity": "needs_replication"},
    {"claim": "", "evidence": None, "maturity": "unverified"},
]
