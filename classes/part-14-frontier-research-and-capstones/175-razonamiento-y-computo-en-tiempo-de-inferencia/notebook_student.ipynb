# %% [markdown]
# # 175 — Razonamiento y cómputo en tiempo de inferencia
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — Voto por mayoría a mano
#
# Un modelo acierta cada muestra independiente con p = 0.7.
#
# a) Calcula P(mayoría correcta) con k = 3.
# b) Calcula P(mayoría correcta) con k = 5.
# c) ¿Cuánto ganó el paso de 3 a 5? ¿Qué dice esto del coste marginal de k?

# %%
# TU RESPUESTA AQUÍ — calcula a mano y verifica con código
from math import comb
p = 0.7
# maj3 = ...
# maj5 = ...

# %% [markdown]
# ## Ejercicio 2 — Cuándo votar empeora
#
# Con p = 0.45 y los errores concentrados en UNA misma respuesta errónea:
#
# a) Calcula P(mayoría de 5 correcta).
# b) Compara con una sola muestra (0.45): ¿mejoró o empeoró?
# c) Ahora supón que los errores se reparten uniformemente entre 4 respuestas
#    erróneas distintas. Explica cualitativamente por qué el voto vuelve a ser
#    útil aunque p < 0.5 (no hace falta calcularlo exacto).

# %%
# TU RESPUESTA AQUÍ

# %% [markdown]
# ## Ejercicio 3 — Presupuesto adaptativo
#
# Tienes 60 unidades de cómputo y 3 preguntas: FÁCIL (1 pasada acierta 95 %,
# votar no mejora), MEDIA (1 pasada 55 %; cada +2 muestras de voto suben ~5
# puntos hasta saturar en 80 %), IMPOSIBLE (el modelo no tiene el conocimiento;
# 0 % siempre). Cada muestra cuesta 4 unidades.
#
# a) Propón una asignación de muestras por pregunta y justifícala.
# b) ¿Qué asignación maximiza la precisión esperada total? Escríbela y calcula
#    la precisión media alcanzada.
# c) Relaciona tu respuesta con el hallazgo de Snell et al. (arXiv:2408.03314).

# %% [markdown]
# ## Ejercicio 4 — Auditar una claim de razonamiento
#
# Ejecuta `run_lab("frontier", seed=175)`. La claim "benchmark mejora" quedó como
# `needs_replication`. Aplica el mismo criterio a esta afirmación real:
# "nuestro modelo con 32 muestras de self-consistency supera al modelo grande en
# GSM8K". Lista tres piezas de evidencia que exigirías para subirla a `current`
# (pista: coste, comparación justa, generalización).

# %%
# TU RESPUESTA AQUÍ
result = run_lab("frontier", seed=175)
show(result)
evidencia_requerida = ["", "", ""]
