# %% [markdown]
# # 179 — Cómo vigilar la frontera sin perseguir modas
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — Clasificar por madurez
#
# Asigna `emerging`, `current`, `standard` o `deprecated` a cada tema y justifica con
# las señales observables (no con tu opinión sobre si es útil):
#
# a) Un protocolo con especificación pública versionada, implementaciones de al menos
#    tres proveedores distintos y documentación oficial.
# b) Una técnica de razonamiento publicada hace tres semanas por un laboratorio, con
#    resultados autoevaluados en un benchmark propio.
# c) Un framework de orquestación con miles de usuarios, varias evaluaciones de
#    terceros y APIs que aún cambian entre versiones menores.
# d) Una librería cuyo mantenedor archivó el repositorio recomendando una alternativa.

# %%
# TU RESPUESTA AQUÍ
clasificacion = {
    "a": ("", ""),  # (nivel, señal observable que lo justifica)
    "b": ("", ""),
    "c": ("", ""),
    "d": ("", ""),
}

# %% [markdown]
# ## Ejercicio 2 — Aplicar la rúbrica a mano
#
# Puntúa (0/1/2 por criterio: baseline, evaluador independiente, reproducibilidad,
# costo declarado) y decide la acción:
#
# Anuncio: *"Nuestro nuevo agente resuelve el 78 % de un benchmark de issues de
# GitHub, muy por encima del 55 % anterior. Evaluación realizada por nuestro equipo.
# El código no se publica. No se reportan tokens ni tiempo por issue."*
#
# a) Da la puntuación criterio por criterio con una frase de justificación.
# b) Calcula el total y asigna nivel de madurez.
# c) ¿Qué dato pedirías al proveedor para subir la puntuación en cada criterio de 0?
# d) ¿Cambia tu decisión si el benchmark es público y anterior al corte de
#    entrenamiento del modelo? ¿Por qué?

# %%
# TU RESPUESTA AQUÍ
rubrica = {"baseline": 0, "independiente": 0, "reproducible": 0, "costo": 0}
# total = sum(rubrica.values())
# nivel = ...

# %% [markdown]
# ## Ejercicio 3 — Leer el registro del repositorio
#
# Abre `frontier/current-topics.yaml` en la raíz del repositorio.
#
# a) Lista los temas y su `maturity`. ¿Cuántos hay en cada nivel?
# b) ¿Qué campos hacen que una entrada sea auditable (verificable por un tercero) y
#    cuáles la hacen caducable (detectable como obsoleta por un script)?
# c) Escribe una entrada nueva, con todos los campos, para un tema que consideres que
#    merece vigilancia. Justifica el `maturity` que le asignas con señales, no con
#    entusiasmo.

# %%
# TU RESPUESTA AQUÍ
from pathlib import Path
import yaml

ruta = Path.cwd()
while not (ruta / "frontier" / "current-topics.yaml").exists() and ruta != ruta.parent:
    ruta = ruta.parent
datos = yaml.safe_load((ruta / "frontier" / "current-topics.yaml").read_text(encoding="utf-8"))
# cuenta por maturity, inspecciona campos

# %% [markdown]
# ## Ejercicio 4 — Presupuesto de atención
#
# Tu equipo tiene 4 horas semanales para frontera. Llegan: (1) una spec estable de un
# protocolo que resolvería un problema de integración que ya tienen, (2) un modelo
# nuevo con +3 % autoevaluado, (3) un framework de agentes del que hablan todos en
# redes, (4) un aviso de deprecación de una librería que ustedes usan en producción.
#
# Reparte las 4 horas, justifica cada asignación con el criterio de madurez, y escribe
# el **criterio de salida** para el único prototipo que autorizarías.
