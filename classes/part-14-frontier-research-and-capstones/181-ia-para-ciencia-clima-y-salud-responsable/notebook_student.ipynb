# %% [markdown]
# # 181 — IA para ciencia, clima y salud responsable
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — VPP a mano
#
# Un modelo de detección de retinopatía diabética tiene sensibilidad 90 % y
# especificidad 95 %. Se aplica a 20,000 personas.
#
# a) Prevalencia 2 %: calcula TP, FP, FN, TN, VPP y VPN.
# b) Prevalencia 20 % (población derivada por un oftalmólogo): recalcula el VPP.
# c) El modelo es exactamente el mismo en (a) y (b). Explica en dos frases por qué su
#    utilidad clínica cambia radicalmente.

# %%
# TU RESPUESTA AQUÍ
N, sens, esp = 20_000, 0.90, 0.95
for prev in (0.02, 0.20):
    # enfermos = ...
    # tp = ...; fp = ...
    # vpp = ...
    pass

# %% [markdown]
# ## Ejercicio 2 — Diagnosticar el estudio
#
# Para cada hallazgo de un paper, nombra el modo de fallo (fuga/atajo, falta de
# validación externa, métrica equivocada, sin efecto en desenlaces, sesgo de subgrupo)
# y propón la corrección concreta:
#
# a) El modelo de neumonía en radiografías rinde AUC 0.94 en el hospital A y 0.72 en
#    el hospital B.
# b) Al inspeccionar los mapas de saliencia, el modelo atiende al marcador metálico de
#    "portátil" que aparece en radiografías de pacientes hospitalizados.
# c) El paper reporta AUC 0.97 sobre una condición con prevalencia 0.5 % y concluye
#    "listo para cribado poblacional".
# d) El modelo predice sepsis con buena discriminación, pero el ensayo no muestra
#    diferencia en mortalidad ni en días de UCI.

# %%
# TU RESPUESTA AQUÍ
diagnosticos = {
    "a": ("", ""),  # (modo de fallo, corrección)
    "b": ("", ""),
    "c": ("", ""),
    "d": ("", ""),
}

# %% [markdown]
# ## Ejercicio 3 — El laboratorio como registro científico
#
# Ejecuta `run_lab("frontier", seed=181)`.
#
# a) ¿Qué elementos del contrato JSON cumplen la función de un "reporte reproducible"
#    (semilla, evidencia, limitaciones) y cuáles faltarían para un reporte TRIPOD+AI?
# b) Escribe una función `revisar(resultado)` que devuelva la lista de afirmaciones
#    respaldadas por `evidence` y las limitaciones que impiden extrapolar. Comenta
#    por qué esa separación es el núcleo de la honestidad científica.

# %%
# TU RESPUESTA AQUÍ
r = run_lab("frontier", seed=181)
show(r)

def revisar(resultado):
    # return {"respaldado": ..., "no_extrapolable": ...}
    pass

# %% [markdown]
# ## Ejercicio 4 — Meteorología vs clima
#
# Un titular afirma: "una IA predice mejor el tiempo que los supercomputadores, así
# que ya podemos usar IA para las proyecciones climáticas de 2100".
#
# a) Identifica los dos problemas distintos que el titular confunde.
# b) Explica por qué el entrenamiento sobre 40 años de ERA5 es una limitación
#    específica para el segundo problema.
# c) Propón una afirmación honesta que un investigador sí podría hacer sobre
#    GraphCast, citando su alcance verificado.
