# %% [markdown]
# # 177 — IA para educación y aprendizaje adaptativo
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — BKT a mano
#
# Habilidad "fracciones equivalentes": P(L)=0.30, P(S)=0.05, P(G)=0.25, P(T)=0.10.
#
# a) El estudiante responde CORRECTAMENTE. Calcula P(L|correcto) y luego P(L') con la
#    transición.
# b) Partiendo del P(L') de (a), responde INCORRECTAMENTE el siguiente ítem. Calcula
#    el nuevo P(L).
# c) ¿Cuál de las dos observaciones movió más la estimación y por qué (mira S y G)?

# %%
# TU RESPUESTA AQUÍ — verifica tus cálculos
L, S, G, T = 0.30, 0.05, 0.25, 0.10
# paso a: correcto
# L_post = ...
# L_prime = ...
# paso b: incorrecto desde L_prime

# %% [markdown]
# ## Ejercicio 2 — ¿Cuántos aciertos hasta dominar?
#
# Con P(L0)=0.20, P(S)=0.10, P(G)=0.20, P(T)=0.15 y umbral de dominio 0.95:
#
# a) Predice (sin calcular exacto): ¿bastarán 2 aciertos seguidos? ¿5?
# b) Programa el bucle de actualización y encuentra el número mínimo de aciertos
#    consecutivos para cruzar 0.95.
# c) Repite con P(G)=0.45 (ítems muy adivinables). ¿Cuántos aciertos hacen falta
#    ahora? ¿Qué le dice esto al diseñador de ejercicios?

# %%
# TU RESPUESTA AQUÍ
def paso_correcto(L, S, G, T):
    # post = ...
    # return post + (1 - post) * T
    pass

# cuenta iteraciones hasta L > 0.95

# %% [markdown]
# ## Ejercicio 3 — Política ZPD
#
# Un estudiante tiene P(L)=0.55 en "ecuaciones lineales". Hay 4 ítems disponibles con
# probabilidad de éxito estimada para ese nivel: A=0.95, B=0.75, C=0.62, D=0.30.
#
# a) ¿Cuáles caen en la banda ZPD (0.6-0.8)? ¿Cuál elegirías y por qué?
# b) Explica qué aprende el sistema (no el estudiante) si asigna D y falla: ¿la
#    respuesta aporta evidencia útil sobre P(L)?
# c) El estudiante pide "dame la solución". Escribe la respuesta de un tutor que
#    andamia: primera pista y segunda pista para un ítem tipo `3x + 5 = 20`.

# %%
# TU RESPUESTA AQUÍ
items = {"A": 0.95, "B": 0.75, "C": 0.62, "D": 0.30}
# zpd = ...

# %% [markdown]
# ## Ejercicio 4 — Evaluar al tutor, no al estudiante
#
# Dos tutores LLM se prueban con 100 estudiantes cada uno durante un mes:
#
# | | Satisfacción (1-5) | Pre-test | Post-test |
# |---|---|---|---|
# | Tutor X | 4.8 | 52 % | 58 % |
# | Tutor Y | 3.9 | 51 % | 71 % |
#
# a) Calcula el learning gain de cada uno. ¿Cuál es mejor tutor?
# b) Propón una explicación conductual de por qué X tiene más satisfacción y menos
#    aprendizaje.
# c) ¿Qué control experimental falta en este diseño para atribuir el gain al tutor?
