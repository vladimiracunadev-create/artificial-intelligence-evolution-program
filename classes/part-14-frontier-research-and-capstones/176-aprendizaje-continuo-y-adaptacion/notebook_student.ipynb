# %% [markdown]
# # 176 — Aprendizaje continuo y adaptación
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — EWC a mano
#
# Modelo con dos pesos. Tras la tarea A: `θ*_A = (1.0, 2.0)`, Fisher `F = (4.0, 0.0)`.
# La tarea B tiene pérdida `L_B(θ) = (θ₁ − 3)² + (θ₂ − 0)²`. Usa `λ = 2`.
#
# a) Escribe la pérdida total de EWC y deriva las condiciones de óptimo.
# b) Calcula `θ₁` y `θ₂` óptimos a mano.
# c) ¿Qué peso quedó "anclado" a la tarea A y por qué?

# %%
# TU RESPUESTA AQUÍ — verifica tu cálculo manual
theta_A = (1.0, 2.0)
F = (4.0, 0.0)
lam = 2.0
# objetivo B: (3, 0)
# theta1 = ...
# theta2 = ...

# %% [markdown]
# ## Ejercicio 2 — Predecir el olvido
#
# Matriz de rendimiento `R[i][j]` (filas: hasta qué tarea se entrenó; columnas: tarea
# evaluada), método fine-tuning ingenuo:
#
# ```text
#         T1     T2     T3
# R[1]   0.95    —      —
# R[2]   0.60   0.93    —
# R[3]   0.35   0.55   0.94
# ```
#
# a) Calcula el olvido de T1 y de T2 al final del entrenamiento.
# b) Calcula la precisión media final y el backward transfer (BWT).
# c) ¿Qué patrón típico del fine-tuning ingenuo muestra la diagonal frente a la
#    última fila?

# %%
# TU RESPUESTA AQUÍ
R = {1: {1: 0.95}, 2: {1: 0.60, 2: 0.93}, 3: {1: 0.35, 2: 0.55, 3: 0.94}}
# olvido_T1 = ...
# olvido_T2 = ...
# media_final = ...
# bwt = ...

# %% [markdown]
# ## Ejercicio 3 — El laboratorio y la semilla
#
# Ejecuta `run_lab("frontier", seed=176)` y luego con `seed=174`.
#
# a) ¿Qué claves del contrato JSON permanecen idénticas y cuáles cambian?
# b) Relaciona la lista `limitations` con el aprendizaje continuo: ¿cuál de las
#    limitaciones declaradas equivale a "no hay consolidación entre ejecuciones"?

# %%
# TU RESPUESTA AQUÍ
r1 = run_lab("frontier", seed=176)
r2 = run_lab("frontier", seed=174)
show(r1)
# compara r1 y r2

# %% [markdown]
# ## Ejercicio 4 — Elegir método por escenario
#
# Para cada escenario, elige la familia (regularización / replay / arquitectura) y
# justifica en una frase con el trade-off decisivo:
#
# a) Hospital: modelo de triaje que debe adaptarse por temporada, prohibido retener
#    historias clínicas fuera de su sistema de origen.
# b) Asistente de código de una empresa: 40 clientes, cada uno con su estilo; en
#    inferencia siempre se sabe qué cliente es.
# c) Robot doméstico con hardware limitado que aprende 200 micro-tareas a lo largo
#    de años, sin etiqueta de tarea en inferencia.
