# %% [markdown]
# # 177 — Privacidad diferencial y aprendizaje federado
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — Mecanismo de Laplace a mano
#
# Una escuela quiere publicar cuántos estudiantes reprobaron (valor real: 17).
#
# a) ¿Cuál es la sensibilidad Δf de esta consulta de conteo?
# b) Con ε = 0.25, calcula la escala b del ruido de Laplace y el error absoluto
#    esperado E|Lap(b)| = b.
# c) Se decide publicar el conteo cada mes durante un año con ε = 0.25 cada vez.
#    ¿Cuánto presupuesto total se gasta? ¿Qué factor e^ε total de distinguibilidad
#    implica? Coméntalo.

# %%
# TU RESPUESTA AQUÍ — simula para verificar tu cálculo
import random
random.seed(177)
f_real = 17
epsilon = 0.25
# b = ...
# muestras = [f_real + random.expovariate(1/b) - random.expovariate(1/b) for _ in range(10000)]
# error_medio = ...

# %% [markdown]
# ## Ejercicio 2 — Una ronda de FedAvg a mano
#
# Modelo de un solo peso, global `w_t = 1.0`. Tres clientes entrenan localmente:
#
# | Cliente | n_k (ejemplos) | w local tras entrenar |
# |---|---|---|
# | A | 100 | 0.8 |
# | B | 300 | 1.4 |
# | C | 100 | 0.6 |
#
# a) Calcula `w_{t+1}` con la media ponderada de FedAvg.
# b) Calcula la media SIN ponderar y compárala. ¿Qué cliente domina en cada caso?
# c) Si el cliente B tuviera datos de una distribución atípica (no-IID), ¿qué problema
#    ilustra la diferencia entre ambas medias?

# %%
# TU RESPUESTA AQUÍ
clientes = {"A": (100, 0.8), "B": (300, 1.4), "C": (100, 0.6)}
# w_ponderada = ...
# w_simple = ...

# %% [markdown]
# ## Ejercicio 3 — ¿Dónde está la fuga?
#
# Para cada afirmación, indica VERDADERO o FALSO y corrige las falsas:
#
# a) "En FedAvg los datos crudos nunca llegan al servidor, por lo tanto el servidor
#    no puede aprender nada de los ejemplos individuales."
# b) "Cualquier post-procesamiento de una salida ε-DP sigue siendo ε-DP."
# c) "k-anonimato da la misma garantía que ε-DP si k es grande."
# d) "La agregación segura impide que el servidor vea actualizaciones individuales,
#    pero no añade por sí sola una garantía de privacidad diferencial."

# %%
# TU RESPUESTA AQUÍ
respuestas = {
    "a": ("", ""),  # (V/F, corrección si F)
    "b": ("", ""),
    "c": ("", ""),
    "d": ("", ""),
}

# %% [markdown]
# ## Ejercicio 4 — Diseño con presupuesto
#
# Un hospital te da presupuesto total ε = 1.0 para todo el año y necesita: (1) conteo
# mensual de casos (12 consultas) y (2) una media anual de edad. Propón un reparto del
# presupuesto, justifica qué consultas merecen menos ruido y señala una alternativa
# estructural (no criptográfica) para reducir el número de consultas.
