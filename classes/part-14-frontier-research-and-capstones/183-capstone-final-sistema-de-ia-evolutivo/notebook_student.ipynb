# %% [markdown]
# # 183 — Capstone final: sistema de IA evolutivo
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — Mapear tu capstone a las 15 partes
#
# Elige un caso de uso acotado (no "asistente de todo"). Para cada capa de la
# arquitectura de referencia, escribe qué componente concreto usarías o justifica por
# qué la omites:
#
# | Capa | Parte(s) | Tu decisión | Por qué |
# |---|---|---|---|
# | Guardias de entrada | 13 | | |
# | Orquestación / agente | 9-10 | | |
# | Recuperación y memoria | 8 | | |
# | Modelos | 4-7 | | |
# | Núcleo determinista | 1-3 | | |
# | Herramientas con efectos | 11-12 | | |
# | Guardias de salida | 13 | | |
# | Telemetría y evaluación | 12-13 | | |
#
# Marca además, para cada capa, si **propone** o **decide**.

# %%
# TU RESPUESTA AQUÍ
capstone = {
    "caso_de_uso": "",
    "desenlace_medible": "",
    "baseline_no_ia": "",
    "capas": {
        # "guardias_entrada": {"componente": "", "rol": "decide", "por_que": ""},
    },
}

# %% [markdown]
# ## Ejercicio 2 — Diseñar la suite de evaluación
#
# Para tu caso de uso, escribe **9 casos de prueba**: 3 de éxito esperado, 3 fuera de
# alcance (el sistema debe rechazar o decir "no sé") y 3 adversariales (inyección de
# prompt, entrada ambigua, dato que no debe filtrarse).
#
# Para cada uno indica: entrada, comportamiento correcto, y cómo se verifica de forma
# **programática** (no "parece bien").

# %%
# TU RESPUESTA AQUÍ
suite = {
    "exito": [],        # [{"entrada": ..., "esperado": ..., "verificacion": ...}, ...]
    "fuera_de_alcance": [],
    "adversarial": [],
}
# assert len(suite["exito"]) == 3 ...

# %% [markdown]
# ## Ejercicio 3 — El contrato de evidencia
#
# Ejecuta `run_lab("capstone", seed=183)` y compáralo con `run_lab("frontier",
# seed=183)`.
#
# a) ¿Qué claves comparten los dos contratos y qué significa que sean comunes a
#    laboratorios distintos?
# b) Escribe `validar_contrato(resultado)` que compruebe programáticamente que hay
#    `kind`, `evidence` no vacía y `limitations` no vacía — el mismo verificador que
#    pondrías en la CI de tu capstone.
# c) ¿Por qué `limitations` es parte del contrato y no una nota al pie del README?

# %%
# TU RESPUESTA AQUÍ
r_cap = run_lab("capstone", seed=183)
show(r_cap)

def validar_contrato(resultado):
    # return True/False
    pass

# %% [markdown]
# ## Ejercicio 4 — Declarar trade-offs y límites
#
# Escribe la sección final de tu capstone en dos partes:
#
# a) **Trade-offs**: para cada uno de los cuatro (autonomía↔control, capacidad↔costo,
#    recuerdo↔privacidad, novedad↔estabilidad), en qué punto te situaste y qué
#    consecuencia observable tiene esa elección.
#
# b) **Lo que faltaría para producción**: al menos 5 elementos concretos y verificables
#    (no "más pruebas"), cada uno con quién sería responsable de resolverlo.
