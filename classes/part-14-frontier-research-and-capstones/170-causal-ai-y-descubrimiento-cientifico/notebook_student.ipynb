# %% [markdown]
# # 170 — Causal AI y descubrimiento científico
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — Clasificar preguntas en la escalera
#
# Indica el peldaño (1, 2 o 3) de cada pregunta y justifica en una línea:
#
# a) ¿Los usuarios que ven el tutorial completan más compras?
# b) Si mostramos el tutorial a todos los usuarios nuevos, ¿subirán las compras?
# c) Este usuario no vio el tutorial y abandonó: ¿habría comprado si lo hubiera visto?
# d) ¿Cuál es la probabilidad de enfermedad dado un test positivo (el cálculo del laboratorio)?

# %%
# TU RESPUESTA AQUÍ
peldanos = {"a": None, "b": None, "c": None, "d": None}

# %% [markdown]
# ## Ejercicio 2 — Ajuste de puerta trasera a mano
#
# Grafo: Z → X, Z → Y, X → Y, con Z = "usuario experto" (P(Z=1) = 0.4).
#
# ```text
# P(X=1|Z=1) = 0.7    P(X=1|Z=0) = 0.3
# P(Y=1|X=1,Z=1) = 0.8    P(Y=1|X=0,Z=1) = 0.7
# P(Y=1|X=1,Z=0) = 0.5    P(Y=1|X=0,Z=0) = 0.3
# ```
#
# a) Calcula P(Y=1|do(X=1)) y P(Y=1|do(X=0)) con la fórmula de ajuste.
# b) Calcula la asociación P(Y=1|X=1) y P(Y=1|X=0) (necesitas P(Z|X) por Bayes).
# c) ¿Sobreestima o subestima la asociación el efecto causal? ¿Por qué?

# %%
# TU RESPUESTA AQUÍ — verifica tu cálculo manual
p_z1 = 0.4
# do_x1 = ...
# do_x0 = ...
# assoc_x1 = ...
# assoc_x0 = ...

# %% [markdown]
# ## Ejercicio 3 — El laboratorio es peldaño 1
#
# Ejecuta `run_lab("probability", seed=170)` y observa el posterior.
#
# a) Reconstruye el cálculo de Bayes a mano: ¿qué tasa de falsos positivos es
#    consistente con prior 0.05, likelihood 0.9 y posterior 0.3214?
# b) Explica por qué este posterior NO dice qué pasaría si interviniéramos sobre
#    la enfermedad o sobre el test.

# %%
# TU RESPUESTA AQUÍ
result = run_lab("probability", seed=170)
show(result)
# fpr = ...

# %% [markdown]
# ## Ejercicio 4 — Colisionador
#
# Grafo: Talento → Admisión ← Esfuerzo (la admisión es un colisionador; talento y
# esfuerzo son independientes en la población). Explica por qué, si solo analizas
# a los admitidos (condicionas en Admisión=1), aparecerá una correlación negativa
# espuria entre talento y esfuerzo, y qué regla del criterio de puerta trasera
# estás violando al "ajustar" por esa variable.
