# %% [markdown]
# # 175 — IA para programación y modernización
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — pass@k a mano
#
# Un modelo genera n = 6 soluciones a un problema; c = 3 pasan todos los tests.
#
# a) Calcula pass@1, pass@2 y pass@4 con la fórmula exacta `1 − C(n−c,k)/C(n,k)`.
# b) Calcula el estimador ingenuo `1 − (1 − c/n)^k` para k = 2 y k = 4.
# c) ¿El ingenuo sobreestima o subestima? ¿Por qué?

# %%
# TU RESPUESTA AQUÍ — verifica con math.comb
from math import comb
n, c = 6, 3
# pass_at = lambda k: ...

# %% [markdown]
# ## Ejercicio 2 — Predecir el veredicto del harness
#
# Un agente entrega un parche para un issue. Estado de los tests:
#
# ```text
# FAIL_TO_PASS (tests del fix real): test_parse_neg  PASA   test_parse_zero  PASA
# PASS_TO_PASS (suite previa):       test_render     PASA   test_cache       FALLA
# ```
#
# a) ¿SWE-bench acepta este parche? Justifica con la regla exacta.
# b) El agente propone "arreglar" `test_cache` modificando el test. ¿Por qué el
#    protocolo lo prohíbe y qué haría un revisor humano con ese diff?
# c) Da un ejemplo concreto de parche que pase ambos grupos de tests y aun así sea
#    incorrecto.

# %%
# TU RESPUESTA AQUÍ
fail_to_pass = {"test_parse_neg": True, "test_parse_zero": True}
pass_to_pass = {"test_render": True, "test_cache": False}
# aceptado = ...

# %% [markdown]
# ## Ejercicio 3 — Muestrear y filtrar con el laboratorio
#
# Ejecuta `run_lab("frontier", seed=175)`. Piensa el resultado como UN candidato de un
# proceso estocástico.
#
# a) Ejecuta también con semillas 275 y 375. ¿Qué juega aquí el papel de los "tests"
#    que filtrarían candidatos? (pista: mira `evidence` y el contrato de claves).
# b) Escribe un filtro programático: una función que reciba el resultado y devuelva
#    True solo si cumple el contrato mínimo (kind correcto, evidence no vacía,
#    limitations no vacía).

# %%
# TU RESPUESTA AQUÍ
def filtro(resultado):
    # return ...
    pass

for seed in (175, 275, 375):
    r = run_lab("frontier", seed=seed)
    print(seed, filtro(r))

# %% [markdown]
# ## Ejercicio 4 — Plan de modernización
#
# Heredas un sistema de facturación en Python 2 sin tests (8,000 líneas, maneja dinero
# y fechas). Ordena estos pasos en el orden correcto y justifica en una frase cada
# posición; marca cuál NO debe hacer la IA sin revisión humana:
#
# - Traducir módulo a módulo a Python 3 con un LLM
# - Generar tests de caracterización del comportamiento actual
# - Revisar manualmente todo lo que toque redondeo de dinero y zonas horarias
# - Congelar una versión de referencia ejecutable del sistema original
# - Comparar salidas del sistema nuevo contra la referencia con los mismos insumos
