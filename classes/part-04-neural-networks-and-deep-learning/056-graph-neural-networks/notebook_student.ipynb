# %% [markdown]
# # 056 — Graph Neural Networks
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Paso de mensajes a mano.** Grafo estrella: nodo central 0 conectado a
# 1, 2, 3, con features h = (0, 1, 2, 3) (índice = nodo). Con agregación media con
# self-loop y W = identidad, calcula las features de los 4 nodos tras una capa.
#
# **Ejercicio 2 — Segunda capa y over-smoothing.** Aplica una segunda capa sobre el
# resultado del ejercicio 1. Calcula el rango (máx−mín) de las features originales,
# tras 1 capa y tras 2 capas. ¿Qué tendencia observas?
#
# **Ejercicio 3 — Alcance.** En un grafo cadena 1—2—3—4—5—6, ¿cuántas capas GNN hacen
# falta para que el nodo 1 incorpore información del nodo 6? Justifica con el mecanismo.
#
# **Ejercicio 4 — Invarianza.** Renumera los nodos del ejercicio 1 (intercambia 1 y 3) y
# repite el cálculo. ¿Cambia el resultado para cada nodo físico? ¿Qué propiedad ilustra?

# %%
# TU RESPUESTA AQUÍ
# Ejercicio 1-2: grafo estrella con adyacencia como lista de vecinos (con self-loop)
vecinos = {0: [0, 1, 2, 3], 1: [1, 0], 2: [2, 0], 3: [3, 0]}
h = [0.0, 1.0, 2.0, 3.0]

def capa_media(h, vecinos):
    # return [...media de h[u] para u en vecinos[v]...]
    pass

# h1 = capa_media(h, vecinos)
# h2 = capa_media(h1, vecinos)
# rango = lambda v: max(v) - min(v)

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué la agregación debe ser invariante a permutaciones y qué descarta eso (p. ej. concatenar vecinos en orden)?
# 2. En el ejemplo del grafo línea, ¿cuántas capas necesita el nodo 1 para recibir información de un nodo a distancia 5, y qué le pasa mientras tanto al rango de los valores?
# 3. ¿En qué sentido preciso es la auto-atención del Transformer un caso particular de GNN, y qué aporta el grafo cuando sí existe?
