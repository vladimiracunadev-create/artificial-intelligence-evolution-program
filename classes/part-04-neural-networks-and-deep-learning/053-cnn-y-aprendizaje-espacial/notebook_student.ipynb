# %% [markdown]
# # 053 — CNN y aprendizaje espacial
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Tamaños de salida.** Calcula la dimensión de salida (alto×ancho×canales):
# (a) entrada 28×28×1, 8 filtros 3×3, stride 1, padding 1;
# (b) entrada 64×64×3, 16 filtros 5×5, stride 2, padding 0;
# (c) la salida de (a) tras un max pooling 2×2 con stride 2.
#
# **Ejercicio 2 — Parámetros.** ¿Cuántos parámetros (incluyendo sesgos) tiene cada capa
# del ejercicio 1(a) y 1(b)? Compara 1(b) con una capa densa que conectara todos los
# píxeles de entrada con todas las unidades de salida.
#
# **Ejercicio 3 — Convolución a mano.** Con I = [[1,0,2],[2,1,0],[0,3,1]] y
# K = [[1,−1],[0,2]] (stride 1, sin padding), calcula la salida 2×2 completa.
#
# **Ejercicio 4 — Campo receptivo.** ¿Qué campo receptivo (en la imagen original) tiene
# una neurona tras 3 capas conv 3×3 consecutivas con stride 1? ¿Y si la segunda capa
# tuviera stride 2?

# %%
# TU RESPUESTA AQUÍ
# Ejercicio 1: usa la fórmula (N - K + 2P)//S + 1
def out_size(n, k, p, s):
    return (n - k + 2 * p) // s + 1
# a = ...; b = ...; c = ...

# Ejercicio 3: implementa la correlación 2D y verifica tu cálculo manual
I = [[1, 0, 2], [2, 1, 0], [0, 3, 1]]
K = [[1, -1], [0, 2]]
# S = ...

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué dos capas 3×3 apiladas son preferibles a una 7×7 en parámetros y en no linealidad, y qué pierden a cambio?
# 2. Un bloque residual aprende F(x) = H(x) − x. ¿Por qué "aprender el residuo" es más fácil cuando la transformación óptima está cerca de la identidad?
# 3. ¿Qué evidencia distinguiría un fallo por campo receptivo insuficiente de un fallo por falta de datos de una clase?
