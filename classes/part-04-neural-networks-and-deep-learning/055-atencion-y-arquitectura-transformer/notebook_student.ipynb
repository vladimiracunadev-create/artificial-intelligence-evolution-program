# %% [markdown]
# # 055 — Atención y arquitectura Transformer
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Atención QKV 2×2 a mano.** Con Q = [[1,0],[0,1]], K = [[2,0],[0,2]],
# V = [[1,0],[0,2]] y d_k = 2: calcula las puntuaciones Q·Kᵀ/√2, aplica softmax por fila
# (e^1.4142 ≈ 4.1133) y obtén la salida A·V.
#
# **Ejercicio 2 — Efecto del escalado.** Repite las puntuaciones del ejercicio 1 sin
# dividir por √d_k y calcula los pesos softmax de la fila 1. ¿Cuánto más "dura" se
# vuelve la distribución? ¿Qué pasaría con d_k = 512 y puntuaciones ~√512 veces mayores?
#
# **Ejercicio 3 — Máscara causal.** Aplica la máscara causal a las puntuaciones del
# ejercicio 1 (posición 1 no ve la 2) y recalcula la salida de ambas posiciones.
#
# **Ejercicio 4 — Conteo de parámetros.** Un bloque con d_model = 512 y 8 cabezas:
# ¿cuántos parámetros tienen las proyecciones W_Q, W_K, W_V y W_O juntas
# (4 matrices 512×512, sin sesgos)? ¿Y la FFN de dos capas 512→2048→512 (sin sesgos)?

# %%
# TU RESPUESTA AQUÍ
import math

Q = [[1, 0], [0, 1]]
K = [[2, 0], [0, 2]]
V = [[1, 0], [0, 2]]

# Ejercicio 1: puntuaciones, softmax por fila, salida
# scores = ...
# A = ...
# out = ...

# Ejercicio 4
# params_atencion = ...; params_ffn = ...

# %% [markdown]
# ## Reflexión
#
# 1. ¿Qué problema concreto de la LSTM resuelve que el camino entre dos posiciones cualesquiera sea O(1), y qué precio computacional se paga (O(n²))?
# 2. Si eliminas la codificación posicional de un Transformer entrenado, ¿qué tareas seguirían funcionando y cuáles colapsarían?
# 3. ¿Por qué la máscara causal permite entrenar en paralelo un modelo que en inferencia es estrictamente secuencial?
