# %% [markdown]
# # 059 — Transferencia, fine-tuning y destilación
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Conteo LoRA.** Una matriz W de 1024×1024 se adapta con LoRA.
# Calcula los parámetros entrenables para r = 4, 16 y 64, y el porcentaje respecto al
# fine-tuning completo de esa matriz.
#
# **Ejercicio 2 — Temperatura a mano.** Logits del teacher z = (4, 2, 0). Calcula el
# softmax con T = 1 y con T = 2 (e² ≈ 7.389, e¹ ≈ 2.718). ¿Qué distribución informa
# más sobre la similitud entre clases?
#
# **Ejercicio 3 — Decisión de estrategia.** Tienes 300 imágenes etiquetadas de un
# dominio parecido a ImageNet y una GPU modesta. ¿Feature extraction, fine-tuning
# completo o LoRA? Justifica con los trade-offs de la tabla del README.
#
# **Ejercicio 4 — Olvido catastrófico.** Propón un experimento concreto (con qué
# conjuntos y qué métricas) para detectar si tu fine-tuning degradó las capacidades
# generales del modelo base.

# %%
# TU RESPUESTA AQUÍ
import math

# Ejercicio 1
d = k = 1024
# for r in (4, 16, 64): params = ...; pct = ...

# Ejercicio 2
z = [4.0, 2.0, 0.0]
def softmax_T(z, T):
    # ...
    pass

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué la corrección ΔW aprendida al adaptar una tarea suele tener rango bajo, y qué pasaría con LoRA si no lo tuviera?
# 2. ¿Qué información contiene la distribución suavizada del teacher que no contiene la etiqueta dura, y por qué T=1 la oculta?
# 3. Antes de hacer fine-tuning de un modelo base ajeno, ¿qué deberías medir de ese modelo además de su accuracy en tu tarea?
