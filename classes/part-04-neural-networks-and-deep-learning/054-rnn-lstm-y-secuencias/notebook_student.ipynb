# %% [markdown]
# # 054 — RNN, LSTM y secuencias
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Despliegue a mano.** RNN escalar con w_x = 1, w_h = 0.5, b = 0,
# h₀ = 0, activación tanh y entrada x = (1, 0, 0). Calcula h₁, h₂, h₃
# (tanh(1) ≈ 0.7616). ¿Qué patrón sigue la magnitud del estado?
#
# **Ejercicio 2 — Cota del gradiente.** Con |tanh'| ≤ 1, acota |∂h_t/∂h_{t−k}| para la
# RNN del ejercicio 1 y evalúa la cota en k = 5, 10, 20. ¿A partir de qué k la señal es
# menor que 10⁻³?
#
# **Ejercicio 3 — Celda LSTM a mano.** Con c₀ = 2, y en el paso 1: f = 0.9, i = 0.5,
# c̃ = 1, o = 1. Calcula c₁ y h₁ = o·tanh(c₁) (tanh(2.3) ≈ 0.9801). Después calcula
# c₅ si en los pasos 2-5 f = 0.9 e i·c̃ = 0. Compara con una RNN cuyo estado se
# multiplica por 0.5 en cada paso.
#
# **Ejercicio 4 — Conteo de parámetros.** Una LSTM con entrada de dimensión 10 y estado
# de dimensión 20 tiene 4 juegos de pesos [W_x (20×10), W_h (20×20), b (20)].
# ¿Cuántos parámetros en total? ¿Y una RNN simple equivalente?

# %%
# TU RESPUESTA AQUÍ
import math

# Ejercicio 1
w_x, w_h, h = 1.0, 0.5, 0.0
xs = [1.0, 0.0, 0.0]
# for x in xs: h = ...

# Ejercicio 2: cota w_h**k
# ...

# Ejercicio 3
c, f, i, c_tilde, o = 2.0, 0.9, 0.5, 1.0, 1.0
# c1 = ...; h1 = ...

# Ejercicio 4
# params_lstm = 4 * (...); params_rnn = ...

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué la actualización aditiva `c_t = f⊙c_{t−1} + i⊙c̃_t` preserva el gradiente donde `h_t = tanh(W_h·h_{t−1}+…)` lo destruye?
# 2. ¿Qué paralelismo hay entre la compuerta de olvido de la LSTM y el atajo residual de ResNet?
# 3. Para una serie temporal de sensores con 500 muestras y poco dato de entrenamiento, ¿qué argumentos darías a favor de una GRU frente a un Transformer?
