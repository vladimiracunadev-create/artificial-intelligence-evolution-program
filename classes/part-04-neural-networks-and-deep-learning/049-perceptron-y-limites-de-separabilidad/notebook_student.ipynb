# %% [markdown]
# # 049 — Perceptrón y límites de separabilidad
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Forward a mano.** Con w = (0.5, −1) y b = 0.25, calcula z = w·x + b y
# la predicción escalón (z ≥ 0 → 1) para: (a) x = (1, 1); (b) x = (2, 0); (c) x = (0, 1).
#
# **Ejercicio 2 — Una época de la regla del perceptrón.** Para la función OR con
# w = (0, 0), b = 0, η = 1, recorre los ejemplos en el orden (0,0), (0,1), (1,0), (1,1)
# y anota cada actualización. ¿Con qué w y b termina la primera época?
#
# **Ejercicio 3 — XOR no separable.** Escribe las cuatro desigualdades que debería
# cumplir un perceptrón para XOR y deriva la contradicción sumando las dos que
# corresponden a las entradas con y = 1.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("neural", seed=49)` y
# comprueba que el resultado incluye las claves `kind` y `evidence`.

# %%
# TU RESPUESTA AQUÍ
# Ejercicio 1: calcula z y ŷ para cada punto (a mano y luego verifica en código).
w = (0.5, -1.0); b = 0.25
# ...

# Ejercicio 2: implementa una época de la regla del perceptrón para OR.
# ...

# Ejercicio 4:
# result = run_lab("neural", seed=49)
# assert "kind" in result and "evidence" in result
result = None

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué la garantía de convergencia del perceptrón depende del margen γ y qué pasa con datos casi colineales (margen minúsculo)?
# 2. XOR se vuelve separable si añades la feature x₃ = x₁·x₂. ¿Qué te dice esto sobre la relación entre representación y separabilidad?
# 3. ¿En qué se diferencia la regla del perceptrón del descenso de gradiente sobre una pérdida logística, y por qué la segunda converge aunque los datos no sean separables?
