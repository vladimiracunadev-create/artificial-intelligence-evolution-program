# %% [markdown]
# # 060 — Proyecto: modelo trazable de extremo a extremo
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Métricas a mano.** Con la matriz de confusión TP=30, FP=15, FN=10,
# TN=45: calcula accuracy, precisión, recall y F1. Compara con el baseline mayoritario.
#
# **Ejercicio 2 — Detección de fuga.** Un compañero reporta 99.2 % de accuracy
# separando train/test *después* de aumentar los datos (cada imagen y sus copias
# rotadas). Explica el mecanismo exacto de la fuga y cómo re-partir correctamente.
#
# **Ejercicio 3 — Model card mínima.** Ejecuta `run_lab("capstone", seed=60)` y redacta
# una model card mínima del artefacto resultante con 5 campos: propósito, datos,
# métrica + valor, limitación principal, uso desaconsejado. Usa solo lo que el JSON
# evidencia.
#
# **Ejercicio 4 — Variabilidad entre semillas.** Cinco corridas dan accuracy
# (0.71, 0.69, 0.74, 0.70, 0.66). Calcula media y desviación estándar (poblacional).
# ¿Es honesto reportar "0.74"? ¿Qué reportarías?

# %%
# TU RESPUESTA AQUÍ
import math

# Ejercicio 1
TP, FP, FN, TN = 30, 15, 10, 45
# accuracy = ...; precision = ...; recall = ...; f1 = ...

# Ejercicio 3
# result = run_lab("capstone", seed=60)
# card = {"propósito": ..., "datos": ..., "métrica": ..., "limitación": ..., "no_usar_para": ...}

# Ejercicio 4
accs = [0.71, 0.69, 0.74, 0.70, 0.66]
# media = ...; desv = ...

# %% [markdown]
# ## Reflexión
#
# 1. De la cadena datos→splits→config→checkpoint→métrica, ¿qué eslabón registra este laboratorio y cuáles tendrías que añadir tú para un proyecto real?
# 2. ¿Por qué "elegir la mejor de 20 corridas" produce una estimación sesgada, y cómo la corrige el protocolo media ± σ?
# 3. Escribe dos afirmaciones sobre un modelo tuyo: una que tu evidencia actual soporta y otra que requeriría experimentos adicionales. ¿Qué las distingue?
