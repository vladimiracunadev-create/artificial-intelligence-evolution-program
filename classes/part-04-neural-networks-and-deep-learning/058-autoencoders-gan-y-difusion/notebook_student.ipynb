# %% [markdown]
# # 058 — Autoencoders, GAN y difusión
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Autoencoder lineal a mano.** Con encoder z = w·x, w = (0.8, 0.6) y
# decoder x̂ = z·w: calcula z, x̂ y el error cuadrático ‖x−x̂‖² para (a) x = (8, 6);
# (b) x = (6, 8). Explica la diferencia.
#
# **Ejercicio 2 — Forward de difusión.** Con x₀ = 2.0 y ε = −0.5, calcula x_t para
# ᾱ_t = 0.99, 0.5 y 0.01. ¿En qué régimen la red de denoising tiene la tarea más difícil
# y por qué?
#
# **Ejercicio 3 — Reparametrización.** El encoder de un VAE da μ = 1.0 y σ = 0.5 para
# un x. Con ε = (−1, 0, 2) genera las tres muestras z correspondientes. ¿Por qué
# muestrear "a través de" ε permite retropropagar hasta μ y σ?
#
# **Ejercicio 4 — Diagnóstico GAN.** Un generador de dígitos produce solo unos y
# sietes perfectamente nítidos, y la pérdida del discriminador ronda 0.69 (≈ log 2).
# ¿Qué patología es y por qué la pérdida no la delata?

# %%
# TU RESPUESTA AQUÍ
import math

# Ejercicio 1
w = (0.8, 0.6)
# z = ...; x_hat = ...; err = ...

# Ejercicio 2
x0, eps = 2.0, -0.5
# for abar in (0.99, 0.5, 0.01): x_t = ...

# Ejercicio 3
mu, sigma = 1.0, 0.5
# zs = [...]

# %% [markdown]
# ## Reflexión
#
# 1. ¿Qué aporta exactamente el término KL del VAE que hace muestreable su latente, y qué coste tiene sobre la fidelidad de reconstrucción?
# 2. ¿Por qué la pérdida de difusión (regresión de ruido) es estable donde el minimax de la GAN oscila?
# 3. Si necesitas generar 10 000 imágenes por segundo con calidad aceptable, ¿qué familia eliges y qué sacrificas?
