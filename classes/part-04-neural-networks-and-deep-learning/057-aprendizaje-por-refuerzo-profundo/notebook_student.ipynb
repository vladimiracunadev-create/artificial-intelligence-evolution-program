# %% [markdown]
# # 057 — Aprendizaje por refuerzo profundo
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Actualización Q-learning a mano.** α = 0.5, γ = 0.9,
# Q(s,a) = 2.0. Se observa r = −1 y max Q(s',·) = 3.0. Calcula el TD target, el error
# TD y el nuevo Q(s,a). Repite con la misma transición una segunda vez.
#
# **Ejercicio 2 — Efecto de γ.** Con recompensas futuras (1, 1, 1, 1, 1) desde t=0,
# calcula el retorno G = Σ γᵏ·r_k para γ = 0, 0.5 y 0.9. ¿Qué "horizonte efectivo"
# induce cada γ?
#
# **Ejercicio 3 — ε-greedy.** Con Q(s,·) = (1.0, 2.0, 0.5) y ε = 0.3, ¿con qué
# probabilidad se toma cada acción? (el empate aleatorio reparte ε uniformemente).
#
# **Ejercicio 4 — REINFORCE.** Política softmax con preferencias θ = (0, 0), se toma la
# acción 1 (de dos) y se recibe G = −1, α = 0.1. Con ∇log π(a₁) = (1−π₁, −π₂), calcula
# el nuevo θ y las nuevas probabilidades. ¿La acción castigada pierde probabilidad?

# %%
# TU RESPUESTA AQUÍ
import math

# Ejercicio 1
q, alpha, gamma, r, max_next = 2.0, 0.5, 0.9, -1.0, 3.0
# target = ...; td = ...; q_nuevo = ...

# Ejercicio 2
# G = sum(gamma**k for k in range(5)) para cada gamma

# Ejercicio 4
theta = [0.0, 0.0]
# softmax, gradiente y actualización...

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué el TD target usa la red congelada θ⁻ y qué patología aparece si se calcula con la misma red que se está actualizando?
# 2. ¿Qué hace exactamente el max en el objetivo de Q-learning que lo convierte en off-policy, y por qué eso habilita el replay buffer?
# 3. En RLHF se optimiza una recompensa aprendida de preferencias humanas con PPO: ¿qué riesgos de "reward hacking" de esta clase aplican directamente?
