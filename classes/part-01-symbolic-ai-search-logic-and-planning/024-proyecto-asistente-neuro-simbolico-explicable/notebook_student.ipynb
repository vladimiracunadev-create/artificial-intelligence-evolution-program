# %% [markdown]
# # 024 — Proyecto: asistente neuro-simbólico explicable
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio
#
# Ejecuta el laboratorio, inspecciona el contrato de salida y añade una comprobación.

# %%
# TODO: ejecuta run_lab("capstone", seed=24)
# TODO: comprueba que el resultado incluya las claves 'kind' y 'evidence'
result = None

# %% [markdown]
# ## Ejercicio 1 — Clasificar con la taxonomía de Kautz
#
# Asigna tipo (1-6) y justifica en una frase, atendiendo al flujo de datos
# (quién llama a quién, qué cruza la interfaz):
#
# a) AlphaGo (MCTS que consulta redes de valor/política).
# b) Un OCR neuronal cuya salida alimenta un motor de reglas fiscales.
# c) Un LLM usado solo, de pregunta a respuesta.
# d) Logic Tensor Networks (axiomas como restricciones diferenciables en la red).
# e) El capstone de esta clase.

# %% [markdown]
# ## Ejercicio 2 — Auditar la explicabilidad del capstone
#
# Ejecuta `run_lab("capstone", seed=24)` y responde señalando claves del JSON:
#
# a) ¿Qué evidencia entró? (componente y campo exacto)
# b) ¿Qué decisiones tienen explicación fiel (traza/razones) y cuáles solo score?
# c) ¿Qué afirman las `limitations` y por qué son parte del contrato y no un adorno?

# %%
# TU RESPUESTA AQUÍ (ejercicio 2)
result = run_lab("capstone", seed=24)
show(result["result"])

# %% [markdown]
# ## Ejercicio 3 — Añadir la capa de reglas explicable
#
# Escribe una función que tome el ranking del retrieval y aplique estas reglas,
# devolviendo decisión + explicación textual con la regla y los números usados:
#
# ```text
# R1: score ≥ 0,5             → evidencia_fuerte(doc)
# R2: evidencia_fuerte(doc)   → citar(doc)
# R3: sin evidencia_fuerte    → responder "no hay evidencia suficiente"
# ```

# %%
# TU RESPUESTA AQUÍ (ejercicio 3)
def decidir(ranking, umbral=0.5):
    # devuelve (decision, explicacion) donde explicacion cita regla y score
    ...

result = run_lab("capstone", seed=24)
print(decidir(result["result"]["retrieval"]["ranking"]))

# %% [markdown]
# ## Ejercicio 4 — Diseño del gate
#
# El capstone termina en `release_gate: human_review_required`.
#
# a) Propón los tres campos mínimos que debería registrar cada revisión humana
#    para que el gate sea auditable.
# b) Describe un fallo que la traza simbólica NO detectaría (pista: la frontera
#    neuro→simbólica) y cómo lo atraparía el revisor.

# %% [markdown]
# ## Reflexión
#
# 1. Recorre el JSON del capstone y clasifica cada decisión en 'explicación fiel' o 'evidencia puntuada sin explicación'. ¿Dónde está exactamente la frontera neuro→simbólica y por qué esa interfaz acota la calidad de todo el sistema?
# 2. Si sustituyeras el retrieval bag-of-words por embeddings neuronales, ¿qué parte de la explicabilidad se pierde, cuál se conserva y qué habría que añadir para poder confiar en los umbrales de las reglas?
# 3. El gate final exige revisión humana a pesar de toda la trazabilidad. Defiende (con un ejemplo concreto de fallo tipo 'símbolo mal extraído') por qué la explicación fiel hace posible la revisión pero no la reemplaza.
