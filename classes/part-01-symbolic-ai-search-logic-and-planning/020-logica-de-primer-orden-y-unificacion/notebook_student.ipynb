# %% [markdown]
# # 020 — Lógica de primer orden y unificación
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio
#
# Ejecuta el laboratorio, inspecciona el contrato de salida y añade una comprobación.

# %%
# TODO: ejecuta run_lab("logic", seed=20)
# TODO: comprueba que el resultado incluya las claves 'kind' y 'evidence'
result = None

# %% [markdown]
# ## Ejercicio 1 — Traducir a FOL
#
# Traduce, eligiendo cuantificador y conectiva correctos:
#
# a) "Todo estudiante que estudia aprueba."
# b) "Algún estudiante no aprueba."
# c) "Nadie conoce a todo el mundo."
# d) "Hay exactamente un rey." (pista: necesitas igualdad)

# %% [markdown]
# ## Ejercicio 2 — Unificación a mano
#
# Calcula la MGU o indica el fallo (y su causa) para cada par:
#
# a) `Conoce(Juan, x)` y `Conoce(y, Madre(y))`
# b) `Conoce(Juan, x)` y `Conoce(x, Elisa)`
# c) `P(x, f(x))` y `P(y, y)`
# d) `Q(f(a), g(x))` y `Q(y, y)`

# %%
# TU RESPUESTA AQUÍ (ejercicio 2)
mgu_a = {}
mgu_b = None  # o el paso previo que lo arregla
mgu_c = None
mgu_d = None

# %% [markdown]
# ## Ejercicio 3 — Modus ponens generalizado
#
# KB: `∀x (Rapido(x) ∧ Seguro(x) → Despliega(x))`, hechos `Rapido(pipeline1)`,
# `Seguro(pipeline1)`, `Rapido(pipeline2)`.
#
# a) ¿Qué sustitución permite disparar la regla y qué se concluye?
# b) ¿Por qué no se concluye nada sobre `pipeline2`?
# c) ¿Qué hecho adicional haría derivable `Despliega(pipeline2)`?

# %% [markdown]
# ## Ejercicio 4 — Del laboratorio proposicional al primer orden
#
# Ejecuta `run_lab("logic", seed=20)`. Reescribe sus tres reglas como UNA sola
# regla de primer orden sobre proyectos, p. ej. usando `TieneDatos(p)`,
# `TieneObjetivo(p)`, etc. ¿Cuántas reglas proposicionales sustituye tu regla si
# hubiera 100 proyectos?

# %%
# TU RESPUESTA AQUÍ (ejercicio 4)
result = run_lab("logic", seed=20)
show(result["result"])

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué ∀ se combina con → y ∃ con ∧? Escribe las dos combinaciones 'incorrectas' para 'todos los gatos duermen' y explica qué afirman realmente.
# 2. Sin occurs check, unificar P(x, x) con P(y, f(y)) 'tendría éxito' con un término infinito. ¿Por qué Prolog lo omite por defecto y qué riesgo acepta a cambio?
# 3. El laboratorio encadena reglas proposicionales (sin variables). ¿Qué gana exactamente una base de reglas al pasar a primer orden y qué nuevo costo computacional aparece con la unificación?
