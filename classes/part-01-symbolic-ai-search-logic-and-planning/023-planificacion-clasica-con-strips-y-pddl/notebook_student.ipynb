# %% [markdown]
# # 023 — Planificación clásica con STRIPS y PDDL
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio
#
# Ejecuta el laboratorio, inspecciona el contrato de salida y añade una comprobación.

# %%
# TODO: ejecuta run_lab("workflow", seed=23)
# TODO: comprueba que el resultado incluya las claves 'kind' y 'evidence'
result = None

# %% [markdown]
# ## Ejercicio 1 — Escribir un operador STRIPS
#
# Para el mundo de bloques, escribe el operador `desapilar(b, x)` (quitar el
# bloque `b` de encima de `x` y dejarlo en la mesa), con predicados
# `sobre(b,x)`, `sobreMesa(b)`, `libre(b)`. Da sus tres listas PRE/ADD/DEL y
# justifica cada literal de DEL.

# %% [markdown]
# ## Ejercicio 2 — Aplicar RESULT a mano
#
# Estado: `s = {sobre(C,A), sobreMesa(A), sobreMesa(B), libre(C), libre(B)}`.
#
# a) ¿Es aplicable `desapilar(C, A)` (tu operador del ejercicio 1)? Verifica PRE ⊆ s.
# b) Calcula `RESULT(s, desapilar(C,A)) = (s \ DEL) ∪ ADD` literal a literal.
# c) Desde el estado resultante, ¿es aplicable `apilar(B, C)`? ¿Y `apilar(B, B)`?
#    ¿Qué debería impedir lo segundo?

# %%
# TU RESPUESTA AQUÍ (ejercicio 2)
s = {"sobre(C,A)", "sobreMesa(A)", "sobreMesa(B)", "libre(C)", "libre(B)"}
PRE = set()   # completa
ADD = set()   # completa
DEL = set()   # completa
aplicable = PRE <= s
resultado = (s - DEL) | ADD

# %% [markdown]
# ## Ejercicio 3 — El workflow como dominio PDDL
#
# Escribe (en sintaxis PDDL o pseudocódigo) el *domain* y el *problem* del
# workflow del laboratorio (resumen 🧮): tres acciones, `:init {status_received}`,
# `:goal {status_completed}`. Después ejecuta el laboratorio y verifica que
# `events` coincide con tu plan, acción por acción.

# %%
# TU RESPUESTA AQUÍ (ejercicio 3)
result = run_lab("workflow", seed=23)
show(result["result"])
plan_previsto = []  # lista de pares (from, to) según tu modelo

# %% [markdown]
# ## Ejercicio 4 — Interacción de metas (anomalía de Sussman)
#
# Estado inicial: C sobre A; A y B en la mesa. Meta: `{sobre(A,B), sobre(B,C)}`.
#
# a) Intenta lograr `sobre(A,B)` PRIMERO (mueve A sobre B de inmediato):
#    escribe la secuencia y muestra dónde te obliga a deshacer trabajo.
# b) Escribe el plan óptimo (3 acciones) y explica qué orden de submetas funciona.
# c) ¿Qué lección da esto sobre planificar meta a meta?

# %% [markdown]
# ## Reflexión
#
# 1. El workflow del laboratorio tiene un único plan válido. ¿Qué propiedad de sus acciones (mira las listas PRE/DEL) elimina toda ramificación, y qué cambiaría si dos acciones fueran aplicables en el mismo estado?
# 2. La suposición STRIPS dice que lo no mencionado persiste. ¿Qué error concreto aparecería en el mundo de bloques si olvidas poner `libre(y)` en la lista DEL de `mover(b, x, y)`?
# 3. ¿Por qué 'el plan salió bien en el modelo' no garantiza nada sobre el mundo real, y qué componente (ausente en el laboratorio) convierte un planificador en un sistema utilizable?
