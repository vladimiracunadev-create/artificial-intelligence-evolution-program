# %% [markdown]
# # 015 — Costo uniforme, búsqueda voraz y A*
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio
#
# Ejecuta el laboratorio, inspecciona el contrato de salida y añade una comprobación.

# %%
# TODO: ejecuta run_lab("search", seed=15)
# TODO: comprueba que el resultado incluya las claves 'kind' y 'evidence'
result = None

# %% [markdown]
# ## Ejercicio 1 — UCS a mano
#
# Sobre el grafo de trabajo (ver resumen), simula costo uniforme desde `S` hasta `G`:
# en cada paso indica el nodo extraído de la cola de prioridad y su `g`.
#
# a) Orden de expansión con sus valores `g`.
# b) Camino y costo devueltos.

# %% [markdown]
# ## Ejercicio 2 — Voraz a mano
#
# Con `h(S)=5, h(A)=4, h(B)=2, h(G)=0`, simula la búsqueda voraz (`f = h`).
#
# a) ¿Qué camino devuelve y con qué costo real?
# b) ¿Es óptimo? ¿Qué decisión concreta lo estropea?

# %% [markdown]
# ## Ejercicio 3 — A* a mano
#
# Simula A* (`f = g + h`) sobre el mismo grafo.
#
# a) Tabla de expansión: nodo, `g`, `h`, `f` en cada paso.
# b) Camino y costo devueltos.
# c) Comprueba a mano que `h` es admisible comparando `h(n)` con el costo real restante `h*(n)`.

# %%
# TU RESPUESTA AQUÍ (ejercicio 3) — puedes verificar tu traza con código
grafo = {"S": [("A", 1), ("B", 4)], "A": [("B", 2), ("G", 12)], "B": [("G", 3)], "G": []}
h = {"S": 5, "A": 4, "B": 2, "G": 0}
# Implementa A* con heapq o verifica tu tabla manualmente.

# %% [markdown]
# ## Ejercicio 4 — Contraste con el laboratorio
#
# Ejecuta `run_lab("search", seed=15)`. El laboratorio usa BFS sobre un grafo sin
# pesos. Explica en 2-3 frases en qué caso BFS y UCS devuelven exactamente lo
# mismo, y por qué.

# %%
# TU RESPUESTA AQUÍ (ejercicio 4)
result = run_lab("search", seed=15)
show(result["result"])

# %% [markdown]
# ## Reflexión
#
# 1. En el grafo de trabajo, la búsqueda voraz devuelve S→B→G (costo 7) y A* devuelve S→A→B→G (costo 6). ¿Qué información ignora la voraz que le cuesta la optimalidad?
# 2. ¿Por qué UCS y A* con h admisible garantizan optimalidad pero BFS solo la garantiza con costos uniformes? Da un contraejemplo concreto para BFS.
# 3. Si multiplicaras h por 3 (haciéndola inadmisible), A* seguiría encontrando *una* solución. ¿Qué garantía pierde exactamente y qué se gana a cambio (weighted A*)?
