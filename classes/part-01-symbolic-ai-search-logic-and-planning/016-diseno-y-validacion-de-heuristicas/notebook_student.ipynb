# %% [markdown]
# # 016 — Diseño y validación de heurísticas
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio
#
# Ejecuta el laboratorio, inspecciona el contrato de salida y añade una comprobación.

# %%
# TODO: ejecuta run_lab("search", seed=16)
# TODO: comprueba que el resultado incluya las claves 'kind' y 'evidence'
result = None

# %% [markdown]
# ## Ejercicio 1 — Calcular h1 y h2 a mano
#
# Estado del 8-puzzle (0 = hueco), objetivo `1 2 3 / 4 5 6 / 7 8 0`:
#
# ```text
# 1 2 3
# 4 5 6
# 0 7 8
# ```
#
# a) Calcula `h1` (fichas mal colocadas, sin contar el hueco).
# b) Calcula `h2` (Manhattan, sin contar el hueco), ficha por ficha.
# c) Resuelve el puzzle a mano y compara el costo real con ambas estimaciones.

# %%
# TU RESPUESTA AQUÍ (ejercicio 1)
estado = [[1, 2, 3], [4, 5, 6], [0, 7, 8]]
objetivo = [[1, 2, 3], [4, 5, 6], [7, 8, 0]]
h1 = None
h2 = None

# %% [markdown]
# ## Ejercicio 2 — Verificar dominancia y admisibilidad
#
# a) Argumenta por qué `h2 ≥ h1` en **cualquier** estado del 8-puzzle.
# b) Propón la heurística `h3 = 3 × h2`. ¿Es admisible? Encuentra un estado
#    concreto donde sobreestime el costo real.
# c) ¿`max(h1, h2)` aporta algo sobre `h2` sola en este puzzle?

# %% [markdown]
# ## Ejercicio 3 — Diseñar por relajación
#
# El problema: un robot en una cuadrícula con muros debe llegar a una celda meta
# (movimientos N/S/E/O, costo 1).
#
# a) Escribe la relajación que produce la distancia Manhattan como heurística.
# b) Propón una segunda relajación distinta y su heurística.
# c) ¿Cuál de las dos domina, o son incomparables? Justifica.

# %% [markdown]
# ## Ejercicio 4 — Conectar con el laboratorio
#
# Ejecuta el laboratorio. Su BFS no usa heurística (equivale a `h = 0`).
#
# a) ¿Cuántos nodos expande (`expanded`)?
# b) Diseña una heurística admisible para ese grafo (usa la distancia en aristas
#    hasta G) y argumenta cuáles de los 7 nodos se ahorraría A* con ella.

# %%
# TU RESPUESTA AQUÍ (ejercicio 4)
result = run_lab("search", seed=16)
show(result["result"])
# h(n) = distancia mínima en aristas de n hasta G. Calcúlala para cada nodo.

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué la técnica de 'relajar el problema' garantiza admisibilidad por construcción, mientras que una heurística inventada 'a ojo' debe verificarse caso por caso?
# 2. Si una heurística inadmisible acelera la búsqueda pero pierde la garantía de optimalidad, ¿en qué tipo de aplicación aceptarías ese intercambio y en cuál no? Da un ejemplo concreto de cada una.
# 3. h=0 es admisible y h=h* es la heurística perfecta. ¿Qué le pasa a A* en cada extremo y qué te dice eso sobre el 'precio' de la información?
