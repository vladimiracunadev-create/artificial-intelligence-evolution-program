# %% [markdown]
# # 022 — Sistemas expertos y motores de reglas
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio
#
# Ejecuta el laboratorio, inspecciona el contrato de salida y añade una comprobación.

# %%
# TODO: ejecuta run_lab("logic", seed=22)
# TODO: comprueba que el resultado incluya las claves 'kind' y 'evidence'
result = None

# %% [markdown]
# ## Ejercicio 1 — Predecir el punto fijo
#
# Sin ejecutar el laboratorio, con los hechos `{tiene_datos, tiene_objetivo}` y
# las reglas R1-R3 del resumen:
#
# a) Escribe la traza match-resolve-act ciclo a ciclo.
# b) Predice el contenido exacto de `facts` (ordenado) y de `rules_fired`.
# c) Ejecuta y verifica.

# %%
# TU RESPUESTA AQUÍ (ejercicio 1)
prediccion_facts = []
result = run_lab("logic", seed=22)
show(result["result"])

# %% [markdown]
# ## Ejercicio 2 — Extender la base de reglas
#
# Copia el motor (bucle `while changed`) y añade la regla
# `R4: {requiere_evaluacion, tiene_riesgo} → requiere_supervision` y el hecho
# inicial `tiene_riesgo`.
#
# a) Predice el nuevo punto fijo ANTES de ejecutar.
# b) Implementa y comprueba.
# c) ¿Habría cambiado el resultado si R4 se evaluara antes que R1? ¿Por qué?

# %%
# TU RESPUESTA AQUÍ (ejercicio 2)
facts = {"tiene_datos", "tiene_objetivo", "tiene_riesgo"}
rules = [
    ({"tiene_datos", "tiene_objetivo"}, "puede_experimentar"),
    ({"puede_experimentar"}, "requiere_baseline"),
    ({"requiere_baseline"}, "requiere_evaluacion"),
    # añade R4 aquí
]
fired = []
# implementa el bucle while changed ...

# %% [markdown]
# ## Ejercicio 3 — Encadenamiento hacia atrás a mano
#
# Con la misma base R1-R4, demuestra el objetivo `requiere_supervision`
# hacia atrás: dibuja el árbol de subobjetivos (qué regla lo concluye, qué
# premisas se vuelven subobjetivos, dónde tocan hechos iniciales). ¿Cuántos
# hechos derivó backward que forward también deriva, y cuáles se ahorró?

# %% [markdown]
# ## Ejercicio 4 — Factores de certeza de MYCIN
#
# Una regla R_a (CF 0,7) tiene premisa creída con CF 0,6; otra regla
# independiente R_b (CF 0,5) tiene premisa creída con CF 1,0. Ambas concluyen
# `infeccion_x`.
#
# a) Calcula el CF de cada regla encadenada y el CF combinado.
# b) ¿El CF combinado puede llegar a 1,0 con evidencias < 1? ¿Por qué ese es el
#    comportamiento diseñado?

# %%
# TU RESPUESTA AQUÍ (ejercicio 4)
cf_a = None  # 0.7 × 0.6
cf_b = None  # 0.5 × 1.0
cf_comb = None  # cf_a + cf_b * (1 - cf_a)

# %% [markdown]
# ## Reflexión
#
# 1. El laboratorio responde '¿qué se deriva de estos datos?' (forward). Formula la consulta inversa ('¿se requiere evaluación?') y describe la traza de backward chaining: ¿qué subobjetivos genera y en qué orden?
# 2. Si la base tuviera 10 000 reglas y llegara un hecho nuevo por segundo, ¿por qué el MATCH ingenuo colapsa y qué hace exactamente Rete para que el costo dependa del cambio y no del total?
# 3. Dos reglas independientes concluyen lo mismo con CF 0,6 y 0,5. La combinación da 0,8. ¿Qué supuesto oculto hay en ese número y qué pasaría si ambas reglas se basaran en el mismo síntoma?
