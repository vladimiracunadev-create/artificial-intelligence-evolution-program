# %% [markdown]
# # 013 — Espacios de estados y formulación de problemas
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio
#
# Ejecuta el laboratorio, inspecciona el contrato de salida y añade una comprobación.

# %%
# TODO: ejecuta run_lab("search", seed=13)
# TODO: comprueba que el resultado incluya las claves 'kind' y 'evidence'
result = None

# %% [markdown]
# ## Ejercicio 1 — Formular un problema desde cero
#
# Jarras de **5 L** y **2 L**, grifo ilimitado. Objetivo: exactamente **1 L** en la jarra de 5.
#
# a) Define los cinco componentes (estado, `s0`, acciones, `IS-GOAL`, costo).
# b) ¿Cuántos estados tiene el espacio? Justifica con la definición del estado.
# c) Escribe a mano una solución (secuencia de acciones) y verifica cada paso con `RESULT`.

# %%
# TU RESPUESTA AQUÍ (ejercicio 1)
# Representa el estado como tupla (x, y) y escribe la secuencia de acciones.
solucion = []

# %% [markdown]
# ## Ejercicio 2 — Predecir la salida del laboratorio
#
# Sin ejecutar nada, usando el grafo `A→B,C; B→D,E; C→F; E→G; F→G` y sabiendo
# que el laboratorio hace BFS con cola FIFO:
#
# a) Predice el contenido exacto de `expanded` (orden de expansión).
# b) Predice `path` y `cost`.
# c) Ejecuta la celda siguiente y compara con tu predicción.

# %%
# TU RESPUESTA AQUÍ (ejercicio 2)
prediccion_expanded = []
prediccion_path = []
result = run_lab("search", seed=13)
show(result["result"])
# Compara: ¿coinciden tus listas?

# %% [markdown]
# ## Ejercicio 3 — Estado vs. nodo
#
# En el grafo del laboratorio existen dos caminos de `A` a `G`.
#
# a) Escríbelos.
# b) Explica por qué corresponden a **dos nodos de búsqueda distintos** pero a
#    **un único estado** `G`, y qué información extra guarda el nodo que el estado no tiene.

# %% [markdown]
# ## Ejercicio 4 — El papel de la semilla
#
# Ejecuta `run_lab("search", seed=99)` y compara con `seed=13`. Explica por qué
# el resultado no cambia y qué componente de la formulación tendría que ser
# aleatorio para que sí cambiara.

# %%
# TU RESPUESTA AQUÍ (ejercicio 4)
r13 = run_lab("search", seed=13)
r99 = run_lab("search", seed=99)
# ¿Qué difiere entre r13["result"] y r99["result"]? ¿Por qué?

# %% [markdown]
# ## Reflexión
#
# 1. ¿Qué papel juega cada componente de la formulación (`s0`, `ACTIONS`, `RESULT`, `IS-GOAL`, `c`) en el grafo del laboratorio? Señálalos en el JSON.
# 2. ¿Por qué `expanded` incluye nodos como `D` y `F` que no están en `path`? ¿Qué te dice eso sobre la diferencia entre explorar y resolver?
# 3. El 15-puzzle tiene ≈ 10¹³ estados. ¿Por qué la formulación con `ACTIONS`/`RESULT` sigue siendo práctica aunque el grafo completo no quepa en memoria?
