# %% [markdown]
# # 018 — Problemas de satisfacción de restricciones
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio
#
# Ejecuta el laboratorio, inspecciona el contrato de salida y añade una comprobación.

# %%
# TODO: ejecuta run_lab("logic", seed=18)
# TODO: comprueba que el resultado incluya las claves 'kind' y 'evidence'
result = None

# %% [markdown]
# ## Ejercicio 1 — AC-3 a mano
#
# `A, B ∈ {1, 2, 3}`, `C ∈ {2, 3}`, restricciones: `A > B` y `B = C`.
#
# a) Aplica AC-3: para cada arco revisado indica qué valores se eliminan y por qué.
# b) Escribe los dominios finales. ¿Queda resuelto el CSP o hace falta backtracking?

# %% [markdown]
# ## Ejercicio 2 — Colorear Australia
#
# Variables WA, NT, SA, Q, NSW, V (y T aislada), colores {rojo, verde, azul};
# adyacencias: SA toca WA, NT, Q, NSW, V; WA-NT, NT-Q, Q-NSW, NSW-V.
#
# a) ¿Qué variable elige MRV+grado como primera? Justifica.
# b) Asigna SA=rojo y aplica forward checking: escribe los dominios restantes.
# c) Completa una solución a mano.

# %%
# TU RESPUESTA AQUÍ (ejercicio 2)
dominios = {v: {"rojo", "verde", "azul"} for v in ["WA", "NT", "SA", "Q", "NSW", "V", "T"]}
adyacencias = [("SA", x) for x in ["WA", "NT", "Q", "NSW", "V"]] + [
    ("WA", "NT"), ("NT", "Q"), ("Q", "NSW"), ("NSW", "V")]
# Simula forward checking tras SA="rojo".

# %% [markdown]
# ## Ejercicio 3 — Contar el ahorro
#
# Para el mapa de Australia (7 variables, 3 colores):
#
# a) ¿Cuántas asignaciones completas existen sin ninguna poda (fuerza bruta)?
# b) Tras fijar SA, ¿cuántos colores quedan disponibles para cada vecino y qué
#    estructura adquiere el resto del problema (pista: los 5 vecinos de SA forman una cadena)?

# %% [markdown]
# ## Ejercicio 4 — El laboratorio como propagación
#
# Ejecuta `run_lab("logic", seed=18)`. La derivación de hechos hasta el punto
# fijo es análoga a AC-3. Identifica en el JSON: (a) el equivalente a la 'cola de
# arcos pendientes', (b) el equivalente al 'punto fijo', y (c) qué garantiza el
# resultado y qué no (¿encontró una 'solución' o solo consecuencias forzadas?).

# %%
# TU RESPUESTA AQUÍ (ejercicio 4)
result = run_lab("logic", seed=18)
show(result["result"])

# %% [markdown]
# ## Reflexión
#
# 1. En el mini-CSP X<Y<Z, AC-3 resolvió sin buscar. Construye un CSP de 3 variables donde AC-3 deje dominios de tamaño >1 y aún así no exista solución: ¿qué demuestra eso sobre la consistencia de arco?
# 2. ¿Por qué MRV ('fail first') elige la variable MÁS restringida pero la heurística de valor elige el MENOS restrictivo? ¿Qué optimiza cada una?
# 3. El laboratorio encadena reglas hasta un punto fijo, igual que AC-3 revisa arcos hasta un punto fijo. ¿Qué comparten ambos algoritmos y en qué se diferencia lo que garantizan?
