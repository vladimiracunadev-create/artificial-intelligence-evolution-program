# %% [markdown]
# # 014 — Búsqueda en anchura y profundidad
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio
#
# Ejecuta el laboratorio, inspecciona el contrato de salida y añade una comprobación.

# %%
# TODO: ejecuta run_lab("search", seed=14)
# TODO: comprueba que el resultado incluya las claves 'kind' y 'evidence'
result = None

# %% [markdown]
# ## Ejercicio 1 — DFS a mano
#
# Sobre el grafo del laboratorio (`A→B,C; B→D,E; C→F; E→G; F→G`), simula DFS
# con pila: los hijos se apilan en el orden listado y se extrae **el último**
# apilado. Objetivo `G`.
#
# a) Escribe el orden de expansión.
# b) Escribe el camino devuelto.
# c) ¿Coincide su longitud con la de BFS? ¿Es casualidad o garantía?

# %% [markdown]
# ## Ejercicio 2 — BFS a mano y verificación
#
# a) Simula BFS (cola FIFO) sobre el mismo grafo: orden de expansión y camino.
# b) Verifica con el laboratorio ejecutando la celda.

# %%
# TU RESPUESTA AQUÍ (ejercicio 2)
prediccion_expanded = []
result = run_lab("search", seed=14)
show(result["result"])

# %% [markdown]
# ## Ejercicio 3 — Memoria: números concretos
#
# Con factor de ramificación `b = 3` y solución a profundidad `d = 5`:
#
# a) ¿Cuántos nodos puede llegar a contener la frontera de BFS (orden de magnitud, `b^d`)?
# b) ¿Y la de DFS si la profundidad máxima es `m = 5` (orden `b·m`)?
# c) ¿Cuál elegirías si `m` fuera 10 veces mayor que `d`? ¿Y si el espacio tuviera ciclos?

# %%
# TU RESPUESTA AQUÍ (ejercicio 3)
b, d, m = 3, 5, 5
frontera_bfs = None  # calcula b**d
frontera_dfs = None  # calcula b*m

# %% [markdown]
# ## Ejercicio 4 — Romper a DFS
#
# Añade al grafo una arista que cree un ciclo (por ejemplo `D → A`). Explica qué
# le ocurriría a un DFS **sin** conjunto de visitados y por qué BFS con `visited`
# no sufre el mismo problema.

# %% [markdown]
# ## Reflexión
#
# 1. En el grafo del laboratorio BFS y DFS devuelven caminos de la misma longitud. Dibuja una modificación mínima del grafo donde DFS devuelva un camino estrictamente peor.
# 2. BFS necesita memoria O(b^d). Con b=10 y d=10, ¿cuántos nodos serían? ¿Qué implica para problemas reales y por qué IDS es el compromiso estándar?
# 3. El laboratorio marca los nodos visitados al expandirlos. ¿Qué pasaría con la traza (y con la terminación) si no existiera el conjunto `visited` en un grafo con ciclos?
