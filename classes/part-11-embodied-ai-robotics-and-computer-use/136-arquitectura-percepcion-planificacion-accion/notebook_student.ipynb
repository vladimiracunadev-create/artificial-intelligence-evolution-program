# %% [markdown]
# # 136 — Arquitectura percepción-planificación-acción
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — Traza a mano el aspirador 1D
#
# Rejilla `[A, B, C, D, E]`, robot en `C`, suciedad en `A` y `E`. Reglas
# subsumption: (0) si la celda actual está sucia, limpia; (1) si hay obstáculo o
# pared delante, invierte dirección; (2) avanza en la dirección actual (inicial:
# derecha). En el paso 3 aparece un obstáculo en `D` y desaparece en el paso 6.
#
# Escribe la secuencia de celdas visitadas hasta limpiar ambas suciedades y
# cuenta los movimientos. Compárala con el óptimo deliberativo sin obstáculo (6).

# %%
# TU RESPUESTA AQUÍ
# secuencia = ["C", ...]
# movimientos = ...

# %% [markdown]
# ## Ejercicio 2 — Clasifica las fallas por componente
#
# Para cada síntoma, indica si la falla está en percepción, planificación,
# acción o feedback: (a) el robot cree que hay pared donde no la hay;
# (b) la ruta calculada pasa por una escalera que el mapa sí marca como
# peligrosa; (c) el comando pide girar 90° pero el robot gira 80°;
# (d) el robot repite un choque porque nunca registra que chocó.

# %%
# TU RESPUESTA AQUÍ (escribe a/b/c/d y el componente)

# %% [markdown]
# ## Ejercicio 3 — Ejecuta el lab y cambia la semilla
#
# Ejecuta `run_lab("robotics", seed=136)` y luego con `seed=1234`. Anota qué
# campos del JSON cambian y cuáles no. Explica por qué el contrato (claves
# `kind`, `evidence`, `limitations`) debe ser estable aunque cambien los valores.

# %%
from ai_evolution.labs import run_lab

# TU RESPUESTA AQUÍ
r1 = None  # run_lab("robotics", seed=136)
r2 = None  # run_lab("robotics", seed=1234)

# %% [markdown]
# ## Ejercicio 4 — Asigna capas de la arquitectura híbrida
#
# Un robot de reparto tiene estos módulos: (a) parada de emergencia por bumper,
# (b) replanificación de ruta cuando una calle está cerrada, (c) seguimiento de
# carril a 200 Hz, (d) decidir el orden de los pedidos del día. Asigna cada uno a
# la capa deliberativa, ejecutiva o reactiva y justifica en una línea la
# frecuencia aproximada a la que debe correr.
