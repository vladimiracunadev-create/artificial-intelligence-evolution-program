# %% [markdown]
# # 143 — Robots colaborativos y seguridad física
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — Distancia protectora a mano
#
# Calcula S con: `v_h = 1.6 m/s`, `v_r = 0.5 m/s`, `t_r = 0.15 s`,
# `t_s = 0.2 s`, `d_frenado = v_r·t_s/2`, `C = 0.25 m`. Después recalcula con un
# sensor mejor (`t_r = 0.05 s`). ¿Cuántos centímetros de cercanía compra el
# sensor rápido?

# %%
# TU RESPUESTA AQUÍ
v_h, v_r, t_s, C = 1.6, 0.5, 0.2, 0.25
for t_r in (0.15, 0.05):
    S = ...

# %% [markdown]
# ## Ejercicio 2 — Clasifica el modo de colaboración
#
# Para cada escenario, indica el modo TS 15066 adecuado y por qué: (a) un
# operario entrega piezas al robot en una bandeja mientras ambos se mueven, sin
# contacto previsto; (b) el técnico enseña una nueva trayectoria moviendo el
# brazo con la mano; (c) robot y humano ensamblan la misma pieza y los roces
# leves son inevitables; (d) el humano solo entra a la célula una vez por hora a
# reponer material.

# %%
# TU RESPUESTA AQUÍ (a-d: modo y justificación)

# %% [markdown]
# ## Ejercicio 3 — Curva velocidad-distancia
#
# Programa la función `v_max(d)` que devuelve la velocidad máxima admisible del
# robot dada la distancia d al humano, invirtiendo la fórmula de S (usa
# `t_r=0.1, t_s=0.3·v/1.0` proporcional a v, `d_frenado=v·t_s/2, C=0.2,
# v_h=1.6`; resuelve numéricamente probando v de 0 a 1.5 en pasos de 0.01).
# Imprime v_max para d = 0.5, 0.8, 1.1 y 1.5 m y verifica que a 1.09 m permite
# ~1.0 m/s (el ejemplo del README).

# %%
# TU RESPUESTA AQUÍ
def S(v):
    ...

def v_max(d):
    ...

# %% [markdown]
# ## Ejercicio 4 — Traducción a agentes digitales
#
# Ejecuta `run_lab("safety", seed=143)` e inspecciona `evidence` y
# `limitations`. Construye una tabla de 4 filas que traduzca conceptos de
# seguridad física a un agente de computer use: (parada de emergencia,
# SSM, PFL, evaluación de riesgos) → ¿cuál es el análogo digital de cada uno?

# %%
from ai_evolution.labs import run_lab

# TU RESPUESTA AQUÍ
result = None
