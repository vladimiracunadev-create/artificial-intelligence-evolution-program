# %% [markdown]
# # 142 — Simulación, sim-to-real y digital twins
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — El precio de la robustez, a mano
#
# Una política especialista entrenada con μ fijo rinde 95 % si el μ real
# coincide (±0.02) y 40 % si no. Una robusta (randomizada) rinde 88 % en todo el
# rango. Si tu conocimiento de μ real es una distribución uniforme sobre un
# rango de ancho W y el "acierto" del especialista cubre 0.04 de ese ancho:
# (a) escribe el éxito esperado del especialista en función de W; (b) ¿para qué
# W conviene el especialista? (c) ¿qué representa W en términos de ingeniería?

# %%
# TU RESPUESTA AQUÍ
# E[exito_esp] = (0.04/W)*0.95 + (1 - 0.04/W)*0.40

# %% [markdown]
# ## Ejercicio 2 — Simula el gap y la randomización
#
# Modela el empuje como: éxito si `|f_aplicada − μ·10| < 1`, donde la política
# elige `f_aplicada`. La política especialista siempre aplica `f = 6.0`
# (óptima para μ=0.6). La robusta aplica `f = μ_percibido·10` donde
# `μ_percibido = μ + ruido N(0, 0.05)` (mira el resultado y corrige). Con
# `random.seed(142)`, evalúa ambas en 1000 episodios con `μ = 0.42` y luego con
# `μ` uniforme en (0.3, 0.8). Compara tasas de éxito.

# %%
import random
random.seed(142)
# TU RESPUESTA AQUÍ

# %% [markdown]
# ## Ejercicio 3 — Clasifica el componente del gap
#
# Para cada discrepancia sim-real, indica si es gap **dinámico**, **perceptivo**
# o **ninguno** (error de otra naturaleza): (a) la cámara real tiene reflejos
# que el render no produce; (b) el motor real tarda 30 ms en responder y el
# simulado 0 ms; (c) la política se entrenó con una recompensa mal diseñada;
# (d) la fricción de la mesa real varía con la humedad del día; (e) el gripper
# real tiene 2 mm de holgura mecánica.

# %%
# TU RESPUESTA AQUÍ (a-e)

# %% [markdown]
# ## Ejercicio 4 — Diseña el protocolo de transferencia
#
# Tienes una política con 92 % de éxito en simulación y 20 intentos permitidos
# en el robot real (más es demasiado caro). Diseña el protocolo: ¿cómo repartes
# los 20 intentos, qué criterio de parada por seguridad fijas, y qué concluyes
# si obtienes 14/20 éxitos? Calcula el intervalo aproximado en el que puede
# estar el éxito real con esa muestra (idea: ±1/√n como regla rápida).
