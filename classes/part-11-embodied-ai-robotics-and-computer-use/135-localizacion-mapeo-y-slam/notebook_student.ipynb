# %% [markdown]
# # 135 — Localización, mapeo y SLAM
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — Deriva del cuadrado, a mano
#
# Repite el ejemplo del README con un sesgo de **2°** por giro (cada 90° se
# ejecuta como 92°) en el mismo cuadrado de 10 m. Calcula el desvío lateral de
# cada tramo (`d·sin(error_acumulado)`) y estima la distancia final al origen.
# ¿Es el doble exacto que con 1°? ¿Por qué aproximadamente sí para ángulos
# pequeños?

# %%
import math
# TU RESPUESTA AQUÍ
# desvios = [10*math.sin(math.radians(k*2)) for k in ...]

# %% [markdown]
# ## Ejercicio 2 — Dimensión y coste de EKF-SLAM
#
# Un robot EKF-SLAM sigue 3 landmarks. (a) ¿Cuál es la dimensión del vector de
# estado y el tamaño de la matriz P? (b) ¿Y con 100 landmarks? (c) Si cada paso
# cuesta proporcional a N², ¿cuántas veces más caro es el paso con 100 landmarks
# que con 3? Responde con números concretos.

# %%
# TU RESPUESTA AQUÍ
# dim_3 = ..., P_3 = ...x...
# dim_100 = ..., P_100 = ...x...
# factor = ...

# %% [markdown]
# ## Ejercicio 3 — Simula la deriva y su corrección
#
# Simula 50 pasos de odometría 1D: posición real `x_real += 1`; posición
# estimada `x_est += 1 + ruido` con `ruido ~ N(0, 0.05)` usando
# `random.gauss(0, 0.05)` y semilla 135. Grafica (o imprime cada 10 pasos) el
# error `|x_est − x_real|`. Después simula que en el paso 50 el robot observa un
# landmark en la posición real con ruido σ=0.1 y corrige con
# `x_est = 0.2·x_est + 0.8·z`. ¿Cuánto error elimina la observación?

# %%
import random
random.seed(135)
# TU RESPUESTA AQUÍ

# %% [markdown]
# ## Ejercicio 4 — Asociación de datos incorrecta
#
# Dos landmarks reales están en `l1=(10, 0)` y `l2=(10.5, 0)` (muy próximos). El
# robot, en el origen con rumbo 0°, mide distancia 10.2 a "un landmark".
# (a) ¿Puede decidir con certeza cuál observó? (b) Si asocia mal y corrige el
# mapa con esa observación, ¿el error queda contenido en ese landmark o se
# propaga? Justifica usando el papel de la covarianza P en EKF-SLAM.
