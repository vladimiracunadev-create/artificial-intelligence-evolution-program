# %% [markdown]
# # 144 — Proyecto: agente que actúa con límites
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Clasificar acciones.** Un agente de escritorio opera con la
# política de la materia. Clasifica cada acción como `allowlist`, `denylist` o
# `intermedia` y justifica en una línea con el criterio reversibilidad × costo:
#
# a) `leer_pantalla()`
# b) `enviar_correo(borrador_revisado)`
# c) `vaciar_papelera()`
# d) `renombrar(informe.docx → informe_v2.docx)`
# e) `pagar_factura(proveedor_nuevo)`
#
# **Ejercicio 2 — Métricas de seguridad.** De una traza de 20 episodios:
# 18 tareas completadas, 41 acciones ejecutadas, 6 propuestas bloqueadas por
# denylist (en 4 episodios distintos), 9 escaladas a humano (8 aprobadas,
# 1 denegada). Calcula: (a) tasa de éxito de tarea, (b) tasa de episodios con
# propuesta peligrosa, (c) tasa de aprobación de escaladas. ¿Cuál de las tres
# cifras impide hoy relajar los límites y por qué?
#
# **Ejercicio 3 — Predecir la compuerta.** Con la política del pseudocódigo,
# predice la decisión (ejecutar / rechazar / escalar) para esta secuencia y el
# estado final del episodio: `listar()` → `mover(x→y)` → `eliminar_definitivo(x)`
# → `enviar_a_papelera(x)` con el humano DENEGANDO la escalada.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("capstone",
# seed=144)` y verifica que el resultado incluye `kind`, `evidence` y
# `limitations`. Explica por qué `limitations` es obligatorio en un capstone de
# agentes que actúan.

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1: clasifica cada acción
clasificacion = {"a": None, "b": None, "c": None, "d": None, "e": None}

# Ejercicio 2: calcula las tres tasas
tasa_exito = None
tasa_episodios_peligrosos = None
tasa_aprobacion = None

# Ejercicio 3: lista de decisiones en orden
decisiones = []

# Ejercicio 4:
resultado = None  # run_lab("capstone", seed=144)

# %% [markdown]
# ## Reflexión
#
# 1. Si la denylist bloqueó 2 acciones en un episodio exitoso, ¿por qué el agente
#    NO puede considerarse seguro, y qué componente hay que corregir primero?
# 2. ¿Qué diferencia operativa hay entre un permiso denegado por el orquestador y
#    un límite impuesto por el sandbox, y por qué la defensa en profundidad exige
#    ambos?
# 3. Si escalar todas las acciones intermedias a un humano produce fatiga de
#    aprobación, ¿con qué dos variables calibrarías el umbral de escalada y qué
#    métrica te avisaría de que el humano aprueba por hábito?
