# %% [markdown]
# # 137 — Sensores, actuadores y fusión
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — Filtro de Kalman a mano (paso 2)
#
# Con los valores del README (`a=1, b=1, Q=0.25, R=1`), el paso 1 terminó en
# `x̂=1.111, P=0.556`. Ejecuta a mano el paso 2 con `u=1` y medición `z=2.3`:
# calcula `x̂⁻, P⁻, K, x̂, P` con 3 decimales y verifica que coinciden con los del
# README. Después calcula el paso 3 con `z=3.1` (este no está resuelto).

# %%
# TU RESPUESTA AQUÍ — completa a mano y luego verifica con código
# paso 2: x_pred=?, P_pred=?, K=?, x=?, P=?
# paso 3 (z=3.1): ...

# %% [markdown]
# ## Ejercicio 2 — Fusión de dos sensores estáticos
#
# Un LiDAR mide la distancia a una pared: `z₁=4.8 m` con `σ₁²=0.04`. Un
# ultrasonido mide `z₂=5.2 m` con `σ₂²=0.16`. Calcula la estimación fusionada y
# su varianza con la fórmula de pesos inversos a la varianza. ¿Por qué la
# varianza resultante es menor que 0.04?

# %%
# TU RESPUESTA AQUÍ
# x_fusion = ...
# var_fusion = ...

# %% [markdown]
# ## Ejercicio 3 — Predice el efecto de Q y R
#
# Sin ejecutar nada, predice: (a) si `Q=0` y el modelo es perfecto, ¿hacia qué
# valor tiende K con el paso de las iteraciones?; (b) si `R→∞` (sensor
# desconectado), ¿en qué se convierte el filtro?; (c) ¿cuál de los dos casos
# corresponde a "odometría pura" y qué le ocurre a P con el tiempo en ese caso?
# Después verifica (a) y (b) simulando 20 pasos en código.

# %%
# TU RESPUESTA AQUÍ — primero escribe tu predicción como comentario,
# luego simula 20 pasos del filtro para verificar

# %% [markdown]
# ## Ejercicio 4 — Contrato del lab con dos semillas
#
# Ejecuta `run_lab("robotics", seed=137)` y con otra semilla a tu elección.
# Identifica en `evidence` qué elementos podrías interpretar como "lecturas de
# sensor" del episodio y verifica que `limitations` no está vacío. ¿Por qué un
# lab educativo debe declarar sus limitaciones igual que un filtro declara P?

# %%
from ai_evolution.labs import run_lab

# TU RESPUESTA AQUÍ
result = None
