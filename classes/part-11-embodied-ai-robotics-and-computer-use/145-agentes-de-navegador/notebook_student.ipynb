# %% [markdown]
# # 145 — Agentes de navegador
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — Elige el canal correcto
#
# Para cada subtarea, elige DOM/AX, visión, o híbrido, y justifica en una
# línea: (a) rellenar un formulario de registro estándar; (b) leer el precio
# en un gráfico de velas interactivo (canvas); (c) comprobar si un botón está
# deshabilitado; (d) resolver un layout roto donde dos botones se superponen;
# (e) extraer 200 filas de una tabla HTML paginada.

# %%
# TU RESPUESTA AQUÍ (a-e: canal y por qué)

# %% [markdown]
# ## Ejercicio 2 — La cuenta del ejemplo, generalizada
#
# Con los números del README (visión: 4 acciones fáciles a 0.99 + 2 difíciles a
# 0.9; DOM: 3 acciones a 0.99): (a) verifica ambos cálculos; (b) ¿cuánto tendría
# que mejorar el grounding difícil (0.9 → ¿p?) para que la visión igualara al
# DOM?; (c) si añades verificación con un reintento a los 2 pasos difíciles
# (`p' = p + (1−p)·p`), ¿quién gana?

# %%
# TU RESPUESTA AQUÍ
# vision = 0.99**4 * 0.9**2 = ...

# %% [markdown]
# ## Ejercicio 3 — Postcondiciones programáticas
#
# Escribe (en pseudocódigo o Python) la verificación programática de estas
# tareas, al estilo WebArena: (a) "cambia el idioma del perfil a español";
# (b) "borra el comentario spam del post"; (c) "descarga el CSV del informe
# mensual". Indica para cada una qué NO detectaría un juez que solo mirara el
# último screenshot.

# %%
# TU RESPUESTA AQUÍ
# (a) assert get_profile().language == "es"

# %% [markdown]
# ## Ejercicio 4 — El lab como agente de navegador
#
# Ejecuta `run_lab("agent", seed=145)` e inspecciona el resultado. Mapea cada
# elemento del contrato (`kind`, decisiones/evidencia, `limitations`) a las
# piezas del bucle del agente de navegador (observación, acción, verificación,
# condiciones de salida). ¿Qué pieza del bucle real NO está representada en el
# lab y qué riesgo cubre esa pieza?

# %%
from ai_evolution.labs import run_lab

# TU RESPUESTA AQUÍ
result = None
