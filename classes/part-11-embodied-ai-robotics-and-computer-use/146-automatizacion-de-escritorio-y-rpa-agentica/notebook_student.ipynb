# %% [markdown]
# # 146 — Automatización de escritorio y RPA agéntica
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — La cuenta del ejemplo, con tus números
#
# Rehaz el cálculo del README con: 1200 facturas/mes, 75 % formatos conocidos,
# extracción agéntica correcta al 92 %, 5 min/factura de trabajo humano por
# excepción. Calcula horas humanas/mes en (a) RPA clásica pura y (b) híbrido
# agéntico. (c) ¿Cuántos errores del extractor entran al mes si las
# validaciones duras atrapan el 70 % de sus fallos?

# %%
# TU RESPUESTA AQUÍ
total, conocidas = 1200, 0.75

# %% [markdown]
# ## Ejercicio 2 — Diagnóstico de selectores
#
# Un robot RPA falla tras una actualización del ERP. El selector grabado era
# `wnd[title='Facturas - v2.3'] → ctrl[name='btnGuardar', idx=2]`. Enumera al
# menos 3 razones plausibles del fallo relacionadas con ese selector concreto y
# propón para cada una la versión robusta (o el nodo agéntico) que la evitaría.

# %%
# TU RESPUESTA AQUÍ

# %% [markdown]
# ## Ejercicio 3 — ¿Dónde va el agente?
#
# Para cada paso del proceso "alta de empleado" indica determinista o agéntico,
# y por qué: (a) crear el usuario en el directorio con nombre y apellido;
# (b) interpretar el contrato PDF (formatos variados) para extraer fecha y
# puesto; (c) asignar permisos según el puesto usando la matriz oficial;
# (d) redactar el correo de bienvenida personalizado; (e) registrar la
# operación en el log de auditoría.

# %%
# TU RESPUESTA AQUÍ (a-e)

# %% [markdown]
# ## Ejercicio 4 — El lab como workflow auditable
#
# Ejecuta `run_lab("workflow", seed=146)` y examina la estructura. (a) ¿Qué
# elementos del JSON funcionarían como evidencia de auditoría y qué les falta
# para un proceso de negocio real (pista: antes/después, confianza)?
# (b) Escribe un validador `assert` que rechace el resultado si careciera de
# `evidence` o `limitations` — el equivalente a una validación dura.

# %%
from ai_evolution.labs import run_lab

# TU RESPUESTA AQUÍ
result = None
