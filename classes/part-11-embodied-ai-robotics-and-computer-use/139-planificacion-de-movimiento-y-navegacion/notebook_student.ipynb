# %% [markdown]
# # 139 — Planificación de movimiento y navegación
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — A* a mano en la rejilla del README
#
# Usa la rejilla 5×5 del README (obstáculos en `(1,1),(2,1),(3,1),(1,3),(2,3)`),
# inicio `(0,0)`, meta `(4,4)`, 4 vecinos, heurística Manhattan. (a) Calcula
# `f = g + h` para los dos vecinos de S. (b) Encuentra un camino de coste 8 que
# pase por el hueco `x=4` del muro inferior (no el de la izquierda) o demuestra
# que no existe con coste 8. (c) ¿Cuántos caminos óptimos distintos hay como
# mínimo?

# %%
# TU RESPUESTA AQUÍ
# (a) f(1,0)=?, f(0,1)=?
# (b) camino = [...]
# (c) ...

# %% [markdown]
# ## Ejercicio 2 — ¿Heurística admisible?
#
# Para la misma rejilla con movimiento en 8 direcciones (diagonales de coste
# 1.414), indica cuáles de estas heurísticas son admisibles y por qué:
# (a) Manhattan; (b) euclídea; (c) Chebyshev (máx de |dx|,|dy|);
# (d) 2×euclídea. Para las no admisibles, describe qué síntoma produciría A*.

# %%
# TU RESPUESTA AQUÍ

# %% [markdown]
# ## Ejercicio 3 — Implementa A* y compáralo con Dijkstra
#
# Implementa A* sobre la rejilla del ejercicio 1 (4 vecinos) y cuenta los nodos
# expandidos con heurística Manhattan y con `h=0` (Dijkstra). Verifica que ambos
# devuelven coste 8 y compara las expansiones. Ejecuta también
# `run_lab("search", seed=139)` y relaciona los campos del JSON con tu
# implementación.

# %%
import heapq
from ai_evolution.labs import run_lab

# TU RESPUESTA AQUÍ
OBST = {(1,1),(2,1),(3,1),(1,3),(2,3)}

def astar(h_weight=1.0):
    ...

# %% [markdown]
# ## Ejercicio 4 — Ventana dinámica con números
#
# Un robot va a `v=0.5 m/s` con aceleración máxima `±0.5 m/s²` y ciclo de
# control de 0.2 s. (a) ¿Qué rango de velocidades lineales puede tener en el
# próximo ciclo? (b) Un obstáculo está a 0.3 m por delante: con desaceleración
# máxima, ¿qué velocidad máxima actual permitiría aún frenar a tiempo
# (`d_frenado = v²/(2a)`)? (c) ¿Debe DWA descartar la velocidad actual de 0.5?

# %%
# TU RESPUESTA AQUÍ
# (a) rango = [?, ?]
# (b) v_max = ...
# (c) ...
