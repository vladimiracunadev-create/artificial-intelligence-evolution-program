# %% [markdown]
# # 144 — Computer use basado en visión
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicio 1 — Mapeo de coordenadas a mano
#
# El modelo ve screenshots de 1366×768; la pantalla real es 2560×1440.
# (a) Calcula los factores de escala en x e y. (b) El modelo pide clic en
# (683, 384) del screenshot: ¿a qué píxel real corresponde? (c) Si el agente
# clicara sin mapear, ¿a cuántos píxeles reales de distancia caería el clic del
# objetivo? (d) ¿Por qué conviene que el reescalado conserve la relación de
# aspecto?

# %%
# TU RESPUESTA AQUÍ
# sx = ..., sy = ...

# %% [markdown]
# ## Ejercicio 2 — La aritmética del horizonte
#
# (a) Calcula la probabilidad de completar tareas de 5, 15 y 40 acciones con
# acierto por acción de 0.95 y 0.99. (b) Con verificación por paso que detecta
# el 100 % de los errores y un reintento con el mismo acierto, la probabilidad
# de superar cada paso pasa a `p + (1−p)·p`: recalcula la tarea de 40 acciones
# con p=0.95. (c) Concluye qué compra exactamente la verificación.

# %%
# TU RESPUESTA AQUÍ
# (b) p_paso = 0.95 + 0.05*0.95 = ...

# %% [markdown]
# ## Ejercicio 3 — Postcondiciones bien escritas
#
# Para cada acción, escribe una postcondición verificable con el siguiente
# screenshot (concreta, no "funcionó"): (a) `type("informe.pdf")` en un cuadro
# de búsqueda; (b) `click` en "Agregar al carrito"; (c) `key("ctrl+s")` en un
# editor; (d) `scroll` hacia abajo en una lista de resultados. Señala cuál de
# las cuatro es la más difícil de verificar solo con píxeles y por qué.

# %%
# TU RESPUESTA AQUÍ (a-d)

# %% [markdown]
# ## Ejercicio 4 — Clasifica acciones por riesgo
#
# Ejecuta `run_lab("robotics", seed=144)` y revisa el contrato. Después clasifica
# estas acciones de un agente de escritorio en tres niveles (libre / verificar
# después / confirmación humana previa) y justifica: abrir una pestaña, cerrar
# sin guardar, enviar un formulario de contacto, borrar un archivo a la
# papelera, vaciar la papelera, copiar texto al portapapeles, ejecutar un
# instalador descargado.

# %%
from ai_evolution.labs import run_lab

# TU RESPUESTA AQUÍ
result = None
