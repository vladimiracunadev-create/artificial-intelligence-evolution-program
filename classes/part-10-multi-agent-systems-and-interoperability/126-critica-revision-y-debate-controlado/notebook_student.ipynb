# %% [markdown]
# # 126 — Crítica, revisión y debate controlado
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Condorcet a mano.** Con p = 0.6 e independencia, calcula P(mayoría
# acierta) para n = 3 y n = 5 (usa la binomial). ¿Cuántas llamadas extra pagas por cada
# punto porcentual ganado al pasar de 3 a 5?
#
# **Ejercicio 2 — Votantes correlacionados.** Simula 10 000 preguntas con 3 votantes de
# p = 0.7 en dos escenarios: (a) independientes; (b) con sesgo común: en el 30 % de las
# preguntas ("difíciles") los tres fallan siempre, y en el resto aciertan siempre.
# Calcula P(mayoría) empírica en ambos y compárala con 0.784.
#
# **Ejercicio 3 — Rúbrica de crítico.** Escribe la rúbrica (4 criterios con severidad)
# y el formato de veredicto JSON que usarías para que un crítico revise los `finding`
# de los workers del laboratorio. Aplica tu rúbrica a mano al finding
# "falta threat model": ¿aprobar o revisar?
#
# **Ejercicio 4 — Debate de una ronda.** Implementa `debate(respuestas)` donde
# `respuestas = ["12", "12", "15"]`: devuelve la respuesta mayoritaria y el registro de
# disenso `{respuesta: votos}`. ¿Qué devolverías si hubiera empate 1-1-1 y por qué
# "escalar" es mejor que "elegir al azar"?

# %%
# TU RESPUESTA AQUÍ
from math import comb

# Ejercicio 1
def p_mayoria(p, n):
    # TODO: suma binomial de k = ceil(n/2) .. n
    ...

# Ejercicio 2
import random
def simula(correlacionado, trials=10_000):
    # TODO: devuelve fracción de mayorías correctas
    ...

# Ejercicio 3: rúbrica (texto) + veredicto de ejemplo
rubrica = """
TODO
"""

# Ejercicio 4
def debate(respuestas):
    # TODO: mayoritaria + conteo; None si empate
    ...

# %% [markdown]
# ## Reflexión
#
# 1. Los 3 workers del laboratorio *evalúan aspectos distintos* y no votan. ¿Qué cambiaría en el diseño para convertirlos en un debate al estilo Du et al., y qué pregunta del laboratorio admitiría voto mayoritario?
# 2. Si duplicas los votantes de 3 a 6 usando el mismo modelo y prompt, ¿por qué la mejora observada será menor que la que predice Condorcet? ¿Cómo diversificarías?
# 3. ¿En qué tareas esperarías que un solo agente con herramienta (calculadora, retrieval) supere a un debate de 5 agentes sin herramientas, y por qué?
