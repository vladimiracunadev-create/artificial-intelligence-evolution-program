# %% [markdown]
# # 121 — Workflow, subagente y sistema multiagente
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Clasificar arquitecturas.** Clasifica cada sistema como *workflow*,
# *agente + subagentes* o *multiagente*, y justifica en una frase con el criterio
# "¿quién decide el siguiente paso?": (a) pipeline fijo `extraer → traducir → resumir`
# con 3 prompts; (b) agente de investigación que lanza búsquedas en paralelo con
# contextos aislados y consolida resúmenes; (c) dos agentes que negocian precio
# intercambiando ofertas hasta converger.
#
# **Ejercicio 2 — Consolidación a mano.** Con workers `quality=0.8`, `security=0.6`,
# `documentation=0.9`, calcula: el promedio, el mínimo, y la decisión bajo la regla
# "si algún score < 0.7, la decisión es mejorar ese aspecto". ¿Coincide con lo que
# devuelve `run_lab("multiagent", seed=121)`?
#
# **Ejercicio 3 — Coste de la arquitectura.** Un agente único resuelve la tarea con
# 20 000 tokens. Estima el multiagente con: 1 supervisor (5 000 entrada + 2 000 salida)
# y 3 workers (25 000 + 3 000 cada uno). ¿Cuál es el factor de coste frente al agente
# único? ¿Qué debería aportar el multiagente para justificarlo?
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("multiagent", seed=121)`
# y verifica: `kind == "multiagent"`, hay exactamente 3 workers, todos con las claves
# `agent`, `score`, `finding`, y `supervisor.overall` es el promedio redondeado de los
# scores.

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 2: consolidación a mano
scores = {"quality": 0.8, "security": 0.6, "documentation": 0.9}
promedio = None   # TODO
minimo = None     # TODO
decision = None   # TODO: regla "si algún score < 0.7 → mejorar ese aspecto"

# Ejercicio 3: factor de coste
tokens_agente_unico = 20_000
tokens_multiagente = None  # TODO: supervisor + 3 workers
factor = None              # TODO

# Ejercicio 4: contrato
# result = run_lab("multiagent", seed=121)
# TODO: asserts de kind, 3 workers, claves y overall
result = None

# %% [markdown]
# ## Reflexión
#
# 1. La decisión "mejorar seguridad" sale del *mínimo* (0.6), no del promedio (0.7667). ¿Qué política de consolidación usarías si un worker pudiera fallar y devolver score 0 por un error técnico y no por un hallazgo real?
# 2. Este laboratorio es técnicamente un workflow (el código fija supervisor → workers → consolidación). ¿Qué tendría que cambiar exactamente para que fuera un sistema multiagente según la definición de Anthropic/Wooldridge?
# 3. Si el valor de la tarea no cubre ~15× el coste en tokens de un agente único, ¿cuál de las tres arquitecturas elegirías para este mismo caso y qué perderías?
