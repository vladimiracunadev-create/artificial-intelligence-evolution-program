# %% [markdown]
# # 126 — Handoffs y transferencia de contexto
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Diseñar el payload.** Un agente de análisis de datos descubre a mitad
# de tarea que el dataset contiene datos personales y debe pasar la tarea a un agente de
# cumplimiento. Escribe el payload JSON del handoff con los campos `from_agent`,
# `to_agent`, `reason`, `goal`, `state.verified_facts`, `state.work_done`,
# `state.work_remaining` y `state.constraints` (valores concretos, no plantilla).
#
# **Ejercicio 2 — Compresión de contexto.** El historial de A tiene 4 200 tokens y el
# payload destilado 260. Calcula el ratio de compresión. Si cada token cuesta
# 0.000003 USD en la entrada de B y la cadena tiene 5 handoffs, ¿cuánto se ahorra frente
# a copiar el historial completo en cada salto (asume que el historial no crece)?
#
# **Ejercicio 3 — Detectar el ciclo.** Dada la secuencia de handoffs
# `[("triage","infra"), ("infra","security"), ("security","infra"), ("infra","security")]`,
# escribe una función que detecte si algún par (from, to) se repite y devuelva el primer
# par repetido — la señal para cortar y escalar a humano.
#
# **Ejercicio 4 — Ownership en el laboratorio.** Ejecuta `run_lab("multiagent",
# seed=126)` y responde: ¿quién es el "dueño" de la tarea en este diseño? ¿Los workers
# reciben ownership o solo una delegación tipo subagente? Justifica con dos claves del
# JSON de salida.

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1: payload del handoff
payload = {
    # TODO: completa todos los campos con valores concretos
}

# Ejercicio 2: compresión y ahorro
ratio = None        # TODO: 260 / 4200
ahorro_usd = None   # TODO: 5 saltos × (4200 − 260) tokens × 3e-6 USD

# Ejercicio 3: detección de ciclo
def primer_par_repetido(handoffs):
    # TODO
    ...

# Ejercicio 4
# result = run_lab("multiagent", seed=126)
result = None

# %% [markdown]
# ## Reflexión
#
# 1. En el payload de ejemplo, ¿qué pasaría si `verified_facts` y las hipótesis viajaran mezcladas en un solo campo `notes`? Describe un fallo concreto que B podría cometer.
# 2. El laboratorio consolida workers que nunca se traspasan la tarea. ¿En qué punto del flujo supervisor→workers tendría sentido un handoff worker→worker y qué campos del payload serían críticos?
# 3. ¿Qué métrica registrarías para detectar que los handoffs de tu sistema están destruyendo contexto (el clásico "teléfono roto")?
