# %% [markdown]
# # 129 — MCP: tools, resources y prompts
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Clasificar primitivas.** Para un servidor MCP de un gestor de
# incidencias, clasifica cada capacidad como tool, resource o prompt, y justifica con
# "quién controla": (a) `crear_incidencia(titulo, severidad)`; (b) el tablero actual en
# `board://sprint-42`; (c) plantilla `/postmortem(incidente_id)`; (d)
# `cerrar_incidencia(id)`; (e) historial de una incidencia por URI.
#
# **Ejercicio 2 — Escribir el inputSchema.** Escribe la definición completa de la tool
# `crear_incidencia`: name, description útil para el modelo, e inputSchema JSON Schema
# con `titulo` (string, requerido), `severidad` (enum: baja/media/alta/critica,
# requerido) y `etiquetas` (array de strings, opcional).
#
# **Ejercicio 3 — Simular el ciclo de mensajes.** Implementa un mini-servidor como
# diccionario de tools y una función `handle(request)` que soporte `tools/list` y
# `tools/call` con las dos capas de error: método/tool inexistente → error JSON-RPC
# `{"error": {"code": -32601, ...}}`; argumentos inválidos según el schema → result con
# `isError: true`. Pruébalo con 3 requests: list, call válido, call con severidad
# inválida.
#
# **Ejercicio 4 — El host del laboratorio.** Ejecuta `run_lab("workflow", seed=129)` y
# mapea sus estados (`received → validated → waiting_approval → completed`) al flujo de
# un host MCP que recibe una petición del usuario, valida el `tools/call` propuesto,
# espera consentimiento y ejecuta. ¿Qué transición corresponde al consentimiento?

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1: clasifica en comentarios (a)-(e) con su justificación

# Ejercicio 2
tool_def = {
    # TODO: name, description, inputSchema
}

# Ejercicio 3
TOOLS = {}  # TODO: registra crear_incidencia con su schema y su handler

def handle(request):
    # TODO: tools/list y tools/call con error JSON-RPC vs isError
    ...

# Ejercicio 4
# result = run_lab("workflow", seed=129)
result = None

# %% [markdown]
# ## Reflexión
#
# 1. El laboratorio registra una aprobación antes de completar el workflow. ¿A cuál requisito de la spec de MCP (consentimiento en el host para tools sensibles) corresponde ese paso, y qué tool del ejemplo lo necesitaría?
# 2. ¿Por qué "archivo no encontrado" debe viajar como `isError: true` dentro de un result y no como error JSON-RPC? ¿Qué puede hacer el modelo en el primer caso que no puede en el segundo?
# 3. Si conviertes un resource (`file:///repo/README.md`) en una tool `read_readme()`, ¿qué decisión transferiste de la aplicación al modelo y qué riesgo nuevo aparece?
