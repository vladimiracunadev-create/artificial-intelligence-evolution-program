# %% [markdown]
# # 124 — Supervisor-workers
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Políticas de consolidación a mano.** Con scores
# `{quality: 0.8, security: 0.6, documentation: 0.9}` calcula: (a) promedio; (b) decisión
# por mínimo con umbral 0.7; (c) media ponderada con pesos `{quality: 0.3,
# security: 0.5, documentation: 0.2}`; (d) decisión con veto de security si < 0.65.
# ¿Qué política cambia la decisión final respecto al laboratorio?
#
# **Ejercicio 2 — Redactar la asignación.** Escribe la instrucción completa que el
# supervisor daría al worker `security` siguiendo la lección de Anthropic: objetivo,
# formato de salida exacto (el contrato JSON), herramientas permitidas y límite de
# esfuerzo. Máximo 6 líneas.
#
# **Ejercicio 3 — Fallo parcial.** Implementa `consolidar(workers, umbral=0.7)` que:
# ignore workers con `score is None` (caídos), calcule `overall` con los vivos, decida
# por mínimo, y añada a `limitations` una nota por cada worker caído. Pruébala con
# security caído.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("multiagent", seed=124)`
# y verifica programáticamente que la decisión del supervisor corresponde al worker de
# score mínimo (no al promedio).

# %%
# TU RESPUESTA AQUÍ

scores = {"quality": 0.8, "security": 0.6, "documentation": 0.9}
pesos = {"quality": 0.3, "security": 0.5, "documentation": 0.2}

# Ejercicio 1
promedio = None      # TODO
decision_min = None  # TODO: umbral 0.7
ponderada = None     # TODO
decision_veto = None # TODO: veto si security < 0.65

# Ejercicio 2 (markdown o string):
instruccion_security = """
TODO
"""

# Ejercicio 3
def consolidar(workers, umbral=0.7):
    # workers: lista de {"agent": str, "score": float | None, "finding": str}
    # TODO
    ...

# Ejercicio 4
# result = run_lab("multiagent", seed=124)
result = None

# %% [markdown]
# ## Reflexión
#
# 1. Si `security` devolviera timeout en vez de 0.6, ¿qué política aplicarías (reintento, degradación, aborto) y por qué el promedio con los 2 restantes (0.85) sería una conclusión engañosa?
# 2. El supervisor de este laboratorio es una función determinista. Con un supervisor LLM, ¿qué parte del ciclo (descomponer, asignar, consolidar) esperas que falle primero y qué evidencia recogerías para demostrarlo?
# 3. ¿Cuándo preferirías veto puro de seguridad ("cualquier score < 0.7 bloquea") frente a la regla del mínimo, y qué coste operativo tiene un veto con falsos positivos?
