# %% [markdown]
# # 130 — Blackboard y memoria compartida
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Traza a mano.** Con KS `A` (condición: blackboard vacío → escribe
# síntoma s1, conf 0.8), `B` (condición: existe algún síntoma → escribe síntoma s2,
# conf 0.7, una sola vez) y `C` (condición: ≥2 síntomas → escribe hipótesis h1 con
# conf = media de los síntomas), y un control que prioriza C > B > A: escribe la
# secuencia de activaciones ciclo a ciclo y la confianza final de h1.
#
# **Ejercicio 2 — Política de conflicto.** Dos KS escriben hipótesis incompatibles
# `h_pool` (conf 0.6) y `h_deploy` (conf 0.4); luego llega evidencia que sube `h_pool`
# a 0.9. Compara qué queda en el medio bajo (a) "última escritura gana" y (b)
# "coexistencia con confianza", si después `h_pool` resulta refutada (conf → 0.1).
# ¿Con cuál política el sistema puede recuperarse y por qué?
#
# **Ejercicio 3 — Implementar el ciclo.** Implementa un mini-blackboard: lista de
# hipótesis `{id, nivel, conf, autor}`, tres KS como funciones con condición y acción
# (las del ejercicio 1), y un bucle de control con máximo 6 ciclos y umbral de fin
# conf ≥ 0.7 en nivel "hipotesis". Imprime la traza.
#
# **Ejercicio 4 — Del laboratorio al blackboard.** Ejecuta `run_lab("multiagent",
# seed=130)` y rediseña su salida como estado inicial de un blackboard: convierte cada
# finding de worker en una hipótesis `{nivel: "sintoma", conf: score, autor: agent}` y
# escribe (en texto) la condición de activación de una KS `sintesis` que produciría la
# decisión del supervisor.

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1: escribe la traza como comentarios
# ciclo 1: ...
# ciclo 2: ...

# Ejercicio 3: mini-blackboard
bb = []  # hipótesis: {"id": str, "nivel": str, "conf": float, "autor": str}

def ks_A(bb):
    # TODO: condición y acción
    ...

def ks_B(bb):
    ...

def ks_C(bb):
    ...

def control(bb, max_ciclos=6):
    # TODO: prioridad C > B > A, umbral conf >= 0.7 en nivel "hipotesis"
    ...

# Ejercicio 4
# result = run_lab("multiagent", seed=130)
# hipotesis_iniciales = [...]  # TODO
result = None

# %% [markdown]
# ## Reflexión
#
# 1. En el laboratorio los workers entregan sus hallazgos al supervisor y no los ven entre sí. ¿Qué hallazgo concreto de un worker podría cambiar la evaluación de otro si compartieran blackboard (p. ej. security ↔ documentation)?
# 2. ¿Por qué "las hipótesis incompatibles coexisten con confianza" es mejor política que "gana la última escritura", y qué coste tiene en el tamaño del medio?
# 3. ¿Qué señal cuantitativa usarías para detectar deadlock epistémico (el sistema itera sin acercarse a la solución) y qué acción dispararías?
