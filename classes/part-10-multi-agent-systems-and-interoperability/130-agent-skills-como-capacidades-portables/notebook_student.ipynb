# %% [markdown]
# # 130 — Agent Skills como capacidades portables
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Presupuesto de contexto.** Un agente tiene 60 skills (metadatos de
# 35 tokens cada uno). En una sesión activa 2 skills (cuerpos de 400 y 700 tokens) y
# lee un archivo de referencia de 1 200 tokens de uno de ellos. Calcula los tokens de
# contexto pagados por el sistema de skills en esa sesión, y compáralo con la
# alternativa "todo en el prompt de sistema" (60 cuerpos de 500 tokens de media).
#
# **Ejercicio 2 — Escribir el SKILL.md.** Redacta el frontmatter y el cuerpo (máx. 15
# líneas) de un skill `csv-sanity-check` que valide archivos CSV antes de analizarlos:
# qué hace, cuándo se activa, qué paso es script (`scripts/check.py`) y qué contrato
# devuelve. Cuida la description: debe permitir decidir la activación sin leer el cuerpo.
#
# **Ejercicio 3 — Instrucción o script.** Para cada paso del skill del ejercicio 2,
# decide si va a instrucciones o a script y justifica en una frase: (a) contar filas y
# columnas; (b) detectar si la primera fila es cabecera; (c) redactar un resumen de
# problemas para el usuario; (d) validar que las fechas cumplen ISO-8601; (e) decidir
# si un 3 % de nulos es aceptable para el análisis pedido.
#
# **Ejercicio 4 — El agente del laboratorio.** Ejecuta `run_lab("agent", seed=130)` y
# examina la traza. Escribe la description (2-3 líneas) del skill que empaquetaría este
# procedimiento (verificar estado y computar una suma), de modo que un agente con 50
# skills lo activara exactamente cuando corresponde.

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1
tokens_metadatos = None    # TODO: 60 × 35
tokens_activados = None    # TODO: 400 + 700 + 1200
total_skills = None
total_prompt_sistema = None  # TODO: 60 × 500
print(total_skills, "vs", total_prompt_sistema)

# Ejercicio 2: escribe el SKILL.md como string
skill_md = """
TODO
"""

# Ejercicio 3: responde en comentarios (a)-(e)

# Ejercicio 4
# result = run_lab("agent", seed=130)
description = """
TODO
"""
result = None

# %% [markdown]
# ## Reflexión
#
# 1. El laboratorio (`run_lab("agent")`) muestra un agente con tools `status` y `sum`. Si empaquetaras su objetivo como skill, ¿qué irías a instrucciones, qué a script y qué quedaría como tool MCP?
# 2. ¿Por qué la description del skill importa más que el cuerpo para el comportamiento del sistema completo, si es la parte más corta?
# 3. Un skill de terceros incluye `scripts/limpiar.sh` que pide permisos de red. ¿Qué preguntas harías antes de instalarlo y qué principio de la clase 128 (contratos) estás aplicando?
