# %% [markdown]
# # 125 — Router y especialistas
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Matriz de confusión a mano.** Un router clasifica 100 consultas en
# `código` (real: 50), `datos` (real: 30) y `docs` (real: 20). Aciertos: 45, 24 y 14;
# los errores de cada clase van a parar a `docs`, `código` y `datos` respectivamente.
# Construye la matriz de confusión, calcula la exactitud global y la cobertura
# (recall) por clase.
#
# **Ejercicio 2 — Techo del sistema.** Con la exactitud del ejercicio 1 y especialistas
# que resuelven el 95 % de lo que reciben correctamente ruteado, calcula el techo de
# éxito global. ¿Cuánto sube si el router llega a 0.95?
#
# **Ejercicio 3 — Router por reglas.** Implementa `route(texto)` que devuelva
# `"security"` si contiene "vulnerabilidad", "CVE" o "exploit"; `"documentation"` si
# contiene "README" o "guía"; `"quality"` si contiene "test" o "cobertura"; y
# `"fallback"` en otro caso. Pruébalo con 4 frases, una por rama.
#
# **Ejercicio 4 — Del ruteo a la consolidación.** Ejecuta `run_lab("multiagent",
# seed=125)` y explica en 2-3 frases qué cambiaría del resultado si en lugar de ejecutar
# los 3 workers un router eligiera solo el pertinente: qué se gana (coste) y qué se
# pierde (hallazgos cruzados).

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1: matriz de confusión y métricas
# filas = real, columnas = predicho, orden: codigo, datos, docs
matriz = None      # TODO: lista de listas 3x3
exactitud = None   # TODO
recalls = None     # TODO: dict por clase

# Ejercicio 2
techo = None       # TODO: exactitud * 0.95
techo_mejorado = None

# Ejercicio 3
def route(texto):
    # TODO: reglas por palabras clave, con fallback
    ...

# Ejercicio 4
# result = run_lab("multiagent", seed=125)
result = None

# %% [markdown]
# ## Reflexión
#
# 1. El laboratorio consolida tres workers fijos; un router elegiría *uno*. ¿Qué información de la entrada necesitarías para decidir entre `quality`, `security` y `documentation`, y qué harías con confianza < umbral?
# 2. Si la exactitud del router es 0.90 y la del especialista 0.92, el techo es ≈0.828. ¿En cuál de los dos invertirías el siguiente esfuerzo de mejora y con qué evidencia lo decidirías?
# 3. ¿Por qué "añadir un especialista nuevo" puede *bajar* la exactitud global aunque ese especialista sea excelente?
