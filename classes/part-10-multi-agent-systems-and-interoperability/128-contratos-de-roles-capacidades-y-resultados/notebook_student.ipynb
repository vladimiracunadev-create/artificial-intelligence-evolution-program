# %% [markdown]
# # 128 — Contratos de roles, capacidades y resultados
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Detectar violaciones a mano.** Contra el contrato
# `{agent: const "security", score: number [0,1], finding: string minLength 1}`,
# clasifica cada salida como válida o indica el tipo de violación (const, rango,
# requerido, tipo): (a) `{"agent":"security","score":0.0,"finding":"sin secretos"}`;
# (b) `{"agent":"security","score":"0.6","finding":"ok"}`;
# (c) `{"agent":"security","score":0.6,"finding":""}`;
# (d) `{"agent":"seguridad","score":0.6,"finding":"ok"}`.
#
# **Ejercicio 2 — Escribir el validador.** Implementa `valida(worker_out)` que devuelva
# `(True, [])` o `(False, [lista de violaciones])` para ese contrato, sin librerías
# externas. Pruébala con los 4 casos del ejercicio 1.
#
# **Ejercicio 3 — Política de reintento.** Implementa `invocar_con_contrato(fn, k=3)`
# que llame a `fn(intento, feedback)`, valide con tu validador y reintente pasando las
# violaciones como feedback; tras k fallos devuelve un error tipado
# `{"error": "contract_violation", "attempts": k, "last": [...]}`. Simula un worker que
# falla 2 veces (score fuera de rango) y acierta a la tercera.
#
# **Ejercicio 4 — El contrato del laboratorio.** Ejecuta `run_lab("multiagent",
# seed=128)` y valida los 3 workers con tu validador (parametriza el `const` por
# worker). ¿Pasan todos? ¿Qué campo del JSON global actúa como "contrato de resultados"
# del sistema completo?

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1: clasifica en comentarios
# (a) ...
# (b) ...
# (c) ...
# (d) ...

# Ejercicio 2
def valida(out, agente="security"):
    # TODO: devuelve (ok: bool, violaciones: list[str])
    ...

# Ejercicio 3
def invocar_con_contrato(fn, k=3, agente="security"):
    # TODO
    ...

# Ejercicio 4
# result = run_lab("multiagent", seed=128)
result = None

# %% [markdown]
# ## Reflexión
#
# 1. El laboratorio devuelve siempre resultados válidos porque los workers son deterministas. ¿En qué punto exacto del flujo insertarías el validador si fueran LLM, y qué harías con la evidencia de los intentos fallidos?
# 2. ¿Por qué "score 1.4 → recortar a 1.0 en silencio" es peor que "score 1.4 → reintento visible", si el segundo cuesta una llamada extra?
# 3. Diseña una garantía de SLA de *calidad* para el worker documentation que puedas medir de verdad esta semana. ¿Qué muestra, qué juez, qué umbral?
