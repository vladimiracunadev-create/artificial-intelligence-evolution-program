# %% [markdown]
# # 131 — A2A, descubrimiento e interoperabilidad
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Escribir la Agent Card.** Redacta la Agent Card JSON del worker
# `security` del laboratorio como si fuera un agente A2A independiente: name,
# description, url, version, capabilities, un skill `repo-security-review` con
# inputModes/outputModes, y securitySchemes bearer.
#
# **Ejercicio 2 — Máquina de estados de la tarea.** Dibuja (en texto) todas las
# transiciones válidas del ciclo de vida de una task A2A e indica cuáles son estados
# terminales. ¿Desde qué estados puede el cliente cancelar? ¿Qué transición modela la
# pregunta de vuelta del remoto?
#
# **Ejercicio 3 — Seleccionar agente por card.** Implementa `elegir_agente(cards,
# requisitos)` que filtre una lista de Agent Cards por: skill con id requerido,
# outputMode `application/json` y auth `bearer`; y devuelva la de mayor `version`
# entre las aptas. Pruébala con 3 cards donde solo una cumpla todo.
#
# **Ejercicio 4 — Del laboratorio a A2A.** Ejecuta `run_lab("multiagent", seed=131)` y
# reescribe el resultado del worker security como un **Artifact** A2A (name, parts con
# kind "data") dentro de una Task completada. ¿Qué campo del laboratorio corresponde a
# `history` y cuál a `artifacts`?

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1
agent_card = {
    # TODO
}

# Ejercicio 2: transiciones en comentarios
# submitted -> ...

# Ejercicio 3
def elegir_agente(cards, requisitos):
    # requisitos: {"skill_id": str, "output": str, "auth": str}
    # TODO
    ...

# Ejercicio 4
# result = run_lab("multiagent", seed=131)
task_a2a = {
    # TODO
}
result = None

# %% [markdown]
# ## Reflexión
#
# 1. Los workers del laboratorio son funciones locales del mismo proceso. Si `security` fuera un agente A2A de otra empresa, ¿qué elementos nuevos aparecen en el flujo (descubrimiento, auth, estados, validación del artefacto) y cuál te parece el más frágil?
# 2. ¿Por qué el estado `input-required` es imprescindible entre organizaciones, y qué patrón de la clase 123 (handoffs) generaliza?
# 3. La Agent Card declara capacidades pero no calidad. ¿Cómo decidirías entre dos agentes remotos con cards casi idénticas?
