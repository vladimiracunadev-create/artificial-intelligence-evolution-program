# %% [markdown]
# # 128 — Paralelismo, fan-out y map-reduce
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Coste de un fan-out a mano.** 12 documentos; cada worker: 8 000 tokens
# de entrada y 600 de salida; reduce: prompt de 500 + las 12 salidas, produce 1 500.
# Con `p_in = 3 USD/MTok` y `p_out = 15 USD/MTok`, calcula coste de map, de reduce y
# total. Hazlo primero a mano y comprueba con código.
#
# **Ejercicio 2 — Latencia del rezagado.** Latencias de 8 workers (s):
# `[12, 9, 15, 11, 48, 10, 13, 9]` y reduce = 20 s. Calcula la latencia total del
# fan-out, la del secuencial (suma + reduce) y el speedup. Repite quitando al rezagado
# de 48 s con timeout=20 s (degradación 7/8). ¿Cuánto mejora?
#
# **Ejercicio 3 — ¿Cuándo se rompe el reduce?** Con ventana de 200 000 tokens para el
# reduce y salidas de worker de 600 tokens (+500 de prompt), ¿cuál es el n máximo de un
# reduce plano? ¿Cuántos niveles tendría un reduce jerárquico binario para n = 2 000?
#
# **Ejercicio 4 — Fan-out del laboratorio.** Ejecuta `run_lab("multiagent", seed=128)`.
# Los 3 workers son independientes (ningún finding referencia a otro): verifica que sus
# contratos tienen las mismas claves y escribe la fase "reduce" del laboratorio en una
# frase.

# %%
# TU RESPUESTA AQUÍ
P_IN, P_OUT = 3 / 1e6, 15 / 1e6

# Ejercicio 1
coste_map = None     # TODO: 12 workers × (8000 in + 600 out)
coste_reduce = None  # TODO: entrada 500 + 12×600, salida 1500
coste_total = None

# Ejercicio 2
lats = [12, 9, 15, 11, 48, 10, 13, 9]
lat_fanout = None      # TODO: max + 20
lat_secuencial = None  # TODO: sum + 20
speedup = None
lat_con_timeout = None # TODO: timeout 20 s, degradación 7/8

# Ejercicio 3
n_max_plano = None     # TODO
niveles_arbol = None   # TODO: para n = 2000

# Ejercicio 4
# result = run_lab("multiagent", seed=128)
result = None

# %% [markdown]
# ## Reflexión
#
# 1. En el ejemplo, map cuesta 0.204 USD y reduce 0.031 USD. ¿Con qué crecimiento de n (o de t_out por worker) el reduce pasa a dominar el coste y qué harías entonces?
# 2. Los tres workers del laboratorio corren lógicamente en paralelo porque no comparten estado. ¿Qué cambio en la tarea (no en el código) rompería esa independencia y obligaría a abandonar map-reduce?
# 3. Si duplicar n reduce la latencia a la mitad pero duplica el coste, ¿qué dato de negocio necesitas para elegir n? Formula la decisión como una desigualdad.
