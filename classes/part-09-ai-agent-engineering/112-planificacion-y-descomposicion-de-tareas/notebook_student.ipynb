# %% [markdown]
# # 112 — Planificación y descomposición de tareas
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %% [markdown]
# ## 📖 Materia resumida
#
# **Plan:** secuencia o grafo de sub-tareas propuesto ANTES de actuar. **Descomposición**
# correcta = cada sub-tarea es verificable por sí misma, las dependencias son explícitas y
# la composición implica el objetivo. **Hito:** predicado observable sobre el entorno que
# confirma progreso real. **Parada:** predicado de éxito global + presupuesto máximo.
#
# Dos estrategias: **plan-then-execute** (plan completo revisable antes de tocar el
# entorno; rígido ante imprevistos) y **planificación entrelazada** (revisar tras cada
# observación, estilo ReAct; riesgo de perder el rumbo global). La práctica combina
# ambas: plan inicial + replanteo SOLO cuando una observación contradice un supuesto
# (replan-on-failure), y solo en la rama afectada.

# %% [markdown]
# ### 🛑 Tres finales legítimos
#
# - **Éxito:** el predicado global se verificó contra observaciones.
# - **Agotamiento:** presupuesto consumido → reportar estado parcial y qué falta.
# - **Bloqueo:** dependencia externa (p. ej. aprobación humana) impide avanzar → escalar.
#
# El laboratorio `workflow` ejecuta la versión mínima de un plan con hito bloqueante:
# transiciones `received → validated → waiting_approval → completed`, donde `completed`
# es inalcanzable sin la aprobación registrada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Contrato del workflow.** Ejecuta `run_lab("workflow", seed=112)` y
# verifica `kind` y `evidence`. Reconstruye desde `result["events"]` la máquina de
# estados: ¿cuántas transiciones hay, cuál es el estado inicial y cuál es el hito
# bloqueante?
#
# **Ejercicio 2 — Descompón con hitos.** Descompón la tarea "migrar la documentación del
# proyecto de Word a Markdown en el repositorio" en 4-6 sub-tareas con: dependencia(s),
# hito verificable (predicado observable, no una frase) y presupuesto en pasos. Marca cuál
# sería un hito bloqueante y por qué.
#
# **Ejercicio 3 — Detecta la mala descomposición.** Este "plan" tiene al menos tres
# defectos: `1) entender el código, 2) mejorarlo, 3) probar que todo funciona, 4) dejarlo
# bonito`. Identifica los defectos usando los criterios de la clase (verificabilidad,
# dependencias, granularidad presupuestable, fallo contenible) y reescríbelo.
#
# **Ejercicio 4 — Replanteo local.** En tu plan del Ejercicio 2, supón que el hito de una
# sub-tarea intermedia falla (elige cuál). Indica: qué rama se replantea, qué sub-tareas
# conservan su progreso verificado y qué sub-tarea nueva insertas. Justifica que el plan
# global sobrevive.

# %%
# TODO: ejecuta run_lab("workflow", seed=112)
# TODO: comprueba que el resultado incluya las claves 'kind' y 'evidence'
result = None

# %%
# TU RESPUESTA AQUÍ — Ejercicio 1: reconstruye la máquina de estados
result = run_lab("workflow", seed=112)
events = result["result"]["events"]
estados = []  # ordena los estados a partir de las transiciones from -> to
# ¿cuál es el estado inicial? ¿cuál es el hito bloqueante?
print(events)

# %%
# TU RESPUESTA AQUÍ — Ejercicio 2: plan con hitos verificables
plan = [
    # {"id": 1, "subtarea": "...", "depende_de": [], "hito": "...", "presupuesto_pasos": 0},
]
hito_bloqueante = None  # id de la sub-tarea bloqueante y por qué

# %% [markdown]
# ## Reflexión
#
# 1. En el laboratorio, `waiting_approval` está ANTES de `completed` por diseño. ¿Qué
#    propiedad de la descomposición (hito bloqueante) representa y qué pasaría si el
#    replanteo pudiera reordenar esa transición?
# 2. ¿Por qué "replantear en cada paso" destruye la ventaja del plan y cuál es el
#    disparador correcto de un replanteo?
# 3. Da un ejemplo real donde la parada por agotamiento de presupuesto sea el resultado
#    CORRECTO. ¿Qué debe contener el reporte de estado parcial para que otro agente (u
#    humano) retome el trabajo sin repetirlo?
