# %% [markdown]
# # 106 — Transformación y descomposición de consultas
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Descomposición a mano.** Descompón en sub-preguntas secuenciales:
# "¿Cuántos años pasaron entre la fundación de la universidad donde estudió el autor de
# 'Cien años de soledad' y la publicación de esa novela?" Indica qué recupera cada paso
# y qué paso depende de cuál.
#
# **Ejercicio 2 — Propagación de errores.** Si cada sub-pregunta de una cadena de n = 3
# pasos se responde bien con probabilidad p = 0.9 (independientes), calcula la
# probabilidad de éxito de la cadena. Repite con n = 5. ¿Qué implica para la longitud de
# las descomposiciones?
#
# **Ejercicio 3 — ¿Qué técnica?** Para cada consulta, elige la técnica más adecuada
# (directa, rewriting, multi-query, HyDE, descomposición) y justifica en una línea:
# a) "¿y el año anterior?" (turno 3 de una conversación sobre ventas de 2022),
# b) "efectos secundarios del tratamiento X" en un corpus médico técnico consultado
#    por pacientes,
# c) "¿capital de Francia?",
# d) "¿qué películas dirigió el ganador del Óscar a mejor director de 2020?".
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("workflow", seed=106)` y
# comprueba que el resultado incluye `kind == "workflow"` y una lista `evidence` no vacía.

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1: escribe la lista de sub-preguntas en orden y sus dependencias
subpreguntas = [
    # "1. ...",
]

# Ejercicio 2:
p = 0.9
# prob_cadena_3 = ...
# prob_cadena_5 = ...

# Ejercicio 3: dict consulta -> técnica elegida + justificación
eleccion = {
    "a": None,
    "b": None,
    "c": None,
    "d": None,
}

# Ejercicio 4:
# result = run_lab("workflow", seed=106)
# assert result["kind"] == "workflow" and result["evidence"]
result = None

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué HyDE puede mejorar la recuperación incluso cuando el documento hipotético contiene datos falsos, y en qué caso concreto empeora el resultado?
# 2. En una descomposición de 4 pasos donde cada paso acierta con probabilidad 0.9, ¿cuál es la probabilidad aproximada de que la cadena completa sea correcta, y qué mecanismo la mejoraría?
# 3. ¿Qué evidencia necesitarías para justificar añadir multi-query (3 variantes) a un pipeline que ya funciona: qué métrica debería subir y qué costes deberías reportar junto a ella?
