# %% [markdown]
# # 100 — Búsqueda híbrida y fusión de rankings
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — RRF a mano.** Fusiona con `k = 60` los rankings
# `R1 = [P, Q, R]` y `R2 = [Q, S, P]`. Da el puntaje RRF de cada documento (4 decimales)
# y el ranking final.
#
# **Ejercicio 2 — El papel de k.** Repite el ejercicio 1 con `k = 0` y con `k = 1000`.
# ¿Cambia el ganador? Explica qué hace `k` con el equilibrio entre "ser primero en una
# rama" y "aparecer bien en ambas".
#
# **Ejercicio 3 — Score fusion frágil.** BM25 devuelve scores {P: 12.4, Q: 11.9, R: 3.1}
# y el denso {Q: 0.91, S: 0.88, P: 0.85}. Normaliza cada lista con min-max a [0,1] y
# combina con α = 0.5. Compara el ranking resultante con el RRF del ejercicio 1 y señala
# qué documento resulta más sensible al método elegido.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("retrieval", seed=100)` y
# verifica `kind == "retrieval"` y `evidence` no vacía.

# %%
# TU RESPUESTA AQUÍ
from collections import defaultdict

def rrf(rankings, k=60):
    # TODO: devuelve dict doc -> Σ 1/(k + puesto), puestos desde 1
    ...

R1 = ["P", "Q", "R"]
R2 = ["Q", "S", "P"]

# Ejercicio 1: rrf([R1, R2], k=60)
# Ejercicio 2: rrf([R1, R2], k=0) y k=1000
# Ejercicio 3: min-max + combinación α=0.5 sobre los scores dados

# Ejercicio 4:
# result = run_lab("retrieval", seed=100)
# assert result["kind"] == "retrieval" and result["evidence"]
result = None

# %% [markdown]
# ## Reflexión
#
# 1. En el ejemplo, A gana sin ser primero en ningún ranking. ¿Qué propiedad de RRF produce eso y por qué suele ser deseable en recuperación?
# 2. ¿Qué pasaría con RRF si usaras k = 0? Calcula RRF(C) y RRF(A) del ejemplo con k = 0 y comprueba si el ganador cambia y por qué.
# 3. ¿En qué situación una fusión híbrida rendiría peor que la mejor rama sola, y qué experimento lo detectaría antes de desplegarla?
