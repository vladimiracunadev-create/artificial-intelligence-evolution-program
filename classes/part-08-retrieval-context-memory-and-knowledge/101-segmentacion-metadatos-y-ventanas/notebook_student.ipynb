# %% [markdown]
# # 101 — Segmentación, metadatos y ventanas
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Chunking a mano.** Un documento tiene 1200 tokens. Con `N = 400` y
# `S = 100`, lista los intervalos `[inicio, fin)` de cada chunk, cuenta cuántos hay y
# calcula el sobrecoste de almacenamiento (tokens almacenados / tokens del documento).
#
# **Ejercicio 2 — Idea cortada.** Con los chunks del ejercicio 1, una definición ocupa
# los tokens `[280, 420)`. ¿Existe algún chunk que la contenga completa? ¿Y si `S = 200`?
# Concluye qué relación debe cumplir `S` con la longitud de la idea para garantizarlo.
#
# **Ejercicio 3 — Elegir estrategia.** Para cada corpus, elige estrategia (fijo, recursiva,
# estructural, semántica o parent-document) y justifica en una frase: (a) manual técnico en
# Markdown con tablas; (b) transcripciones de llamadas sin puntuación fiable; (c) contratos
# donde el LLM debe citar la cláusula exacta pero entender la sección completa.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("retrieval", seed=101)` y
# verifica `kind == "retrieval"` y `evidence` no vacía.

# %%
# TU RESPUESTA AQUÍ
def chunks(total, n, s):
    # TODO: devuelve la lista de intervalos [inicio, fin) con solape s
    paso = n - s
    ...

# Ejercicio 1: chunks(1200, 400, 100), número y sobrecoste
# Ejercicio 2: ¿algún intervalo contiene [280, 420)? repite con s=200
# Ejercicio 3: respuesta en texto (comentarios)

# Ejercicio 4:
# result = run_lab("retrieval", seed=101)
# assert result["kind"] == "retrieval" and result["evidence"]
result = None

# %% [markdown]
# ## Reflexión
#
# 1. Si duplicas el solape `S` manteniendo `N`, ¿qué mejora, qué empeora y cómo lo medirías con consultas etiquetadas?
# 2. ¿Por qué sentence-window puede recuperar mejor que chunks de 512 tokens y a la vez darle al LLM más contexto que ellos? ¿Dónde está la trampa en coste?
# 3. ¿Qué metadatos son imprescindibles para que la clase 105 pueda citar "documento X, sección Y" sin reprocesar el corpus?
