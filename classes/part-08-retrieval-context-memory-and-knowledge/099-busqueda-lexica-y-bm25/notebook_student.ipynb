# %% [markdown]
# # 099 — Búsqueda léxica y BM25
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — IDF a mano.** En una colección de `N = 100` documentos, calcula
# `IDF(t) = ln(1 + (N − df + 0.5)/(df + 0.5))` para términos con `df = 1`, `df = 10` y
# `df = 90`. ¿Qué patrón observas?
#
# **Ejercicio 2 — BM25 completo.** Con `k₁ = 1.2`, `b = 0.75` y la colección
# `D1 = "red neuronal profunda"` (3 tokens), `D2 = "la red social conecta la red"`
# (6 tokens), `D3 = "aprendizaje profundo con red neuronal convolucional"` (6 tokens),
# calcula el score BM25 de la consulta `Q = {red, profunda}` para los tres documentos y
# da el ranking. (`avgdl = 5`; cuenta tú `f`, `df` e IDF; trata "profunda"/"profundo"
# como términos distintos, sin stemming.)
#
# **Ejercicio 3 — Efecto de la saturación.** Repite el score de D2 del ejercicio 2 con
# `k₁ = 0.1` y con `k₁ = 10`. ¿Cuándo se acerca la contribución de "red" a contar
# apariciones linealmente y cuándo a un indicador binario de presencia?
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("retrieval", seed=99)` y
# verifica `kind == "retrieval"` y `evidence` no vacía.

# %%
# TU RESPUESTA AQUÍ
import math

def idf(N, df):
    return math.log(1 + (N - df + 0.5) / (df + 0.5))

def bm25_term(f, dl, avgdl, N, df, k1=1.2, b=0.75):
    # TODO: implementa IDF(t) · f·(k1+1) / (f + k1·(1−b+b·dl/avgdl))
    ...

# Ejercicio 1: idf(100, 1), idf(100, 10), idf(100, 90)
# Ejercicio 2: scores de D1, D2, D3 para Q = {red, profunda}
# Ejercicio 3: repite D2 con k1=0.1 y k1=10

# Ejercicio 4:
# result = run_lab("retrieval", seed=99)
# assert result["kind"] == "retrieval" and result["evidence"]
result = None

# %% [markdown]
# ## Reflexión
#
# 1. En el ejemplo, D2 repite "gato" y aun así pierde contra D1. ¿Qué dos componentes de la fórmula producen ese resultado y qué pasaría con k₁ = 100?
# 2. ¿Por qué los scores BM25 de dos consultas distintas no son comparables entre sí, y qué problema causa eso al fusionar rankings (anticipa la clase 100)?
# 3. Da dos ejemplos de consultas de tu dominio donde BM25 debería ganar a los embeddings, y dos donde debería perder. ¿Cómo lo comprobarías?
