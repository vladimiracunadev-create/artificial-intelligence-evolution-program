# %% [markdown]
# # 100 — Embeddings y búsqueda vectorial
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Coseno a mano.** Con `q = (2, 1, 2)` calcula la similitud coseno con
# `a = (4, 2, 4)`, `b = (0, 3, 0)` y `c = (2, −2, 1)`. Da el ranking resultante.
#
# **Ejercicio 2 — Normalización.** Normaliza `q` y `a` (divide cada uno por su norma) y
# comprueba numéricamente que el producto punto de los normalizados coincide con el
# coseno del ejercicio 1, y que `‖q̂ − â‖² = 2 − 2·cos(q,a)`.
#
# **Ejercicio 3 — Escala vs. métrica.** Multiplica `b` por 10. ¿Cambia `cos(q, 10b)`?
# ¿Cambia la distancia euclídea `‖q − 10b‖`? Explica en una frase qué métrica usarías si
# tus embeddings no están normalizados y por qué.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("retrieval", seed=100)` y
# comprueba que el resultado incluye `kind == "retrieval"` y una lista `evidence` no vacía.

# %%
# TU RESPUESTA AQUÍ
import math

q = (2, 1, 2)
a = (4, 2, 4); b = (0, 3, 0); c = (2, -2, 1)

def cos(u, v):
    # TODO: implementa (u·v) / (‖u‖·‖v‖)
    ...

# Ejercicio 1: cos(q,a), cos(q,b), cos(q,c) y ranking
# Ejercicio 2: normaliza y verifica ‖q̂ − â‖² == 2 − 2·cos(q,a)
# Ejercicio 3: compara cos(q, 10·b) y euclídea(q, 10·b)

# Ejercicio 4:
# result = run_lab("retrieval", seed=100)
# assert result["kind"] == "retrieval" and result["evidence"]
result = None

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué `cos(q, 2q) = 1` pero `‖q − 2q‖ ≠ 0`, y qué implica eso para elegir métrica en un índice que no normaliza vectores?
# 2. Si HNSW devuelve recall@10 = 0.92 frente al baseline flat, ¿qué decisiones del sistema (efSearch, M, tamaño de colección) revisarías antes de aceptar esa pérdida?
# 3. ¿Qué evidencia necesitarías para afirmar que un modelo de embeddings "funciona" en tu dominio, más allá de su puntuación en un benchmark público?
