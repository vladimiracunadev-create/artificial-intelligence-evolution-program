# %% [markdown]
# # 106 — Compresión de contexto y cachés semánticos
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Decisiones de caché.** Con `τ = 0.90` y el caché conteniendo
# "¿cuál es el horario de atención?", decide HIT/MISS para: a) "¿a qué hora abren?"
# (sim 0.94), b) "¿cuál es el horario de atención en festivos?" (sim 0.91),
# c) "¿dónde están ubicados?" (sim 0.62). Señala cuál de los HIT es peligroso y por qué.
#
# **Ejercicio 2 — Economía del caché.** Un servicio recibe 50 000 consultas/día; cada
# llamada LLM cuesta $0.006 y el lookup del caché $0.0002. Con hit-rate del 35 %,
# calcula el ahorro neto diario. ¿Con qué hit-rate el caché deja de ser rentable?
#
# **Ejercicio 3 — Orden del prompt.** Ordena estos bloques para maximizar el prefijo
# cacheable entre llamadas y justifica: [pregunta del usuario] [instrucciones del
# sistema] [fecha y hora actual] [definiciones de herramientas] [documentos top-k].
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("retrieval", seed=106)` y
# comprueba que el resultado incluye `kind == "retrieval"` y una lista `evidence` no vacía.

# %%
# TU RESPUESTA AQUÍ

tau = 0.90
consultas = [("a", 0.94), ("b", 0.91), ("c", 0.62)]
# Ejercicio 1: decide HIT/MISS y marca el HIT peligroso

# Ejercicio 2:
n = 50_000
costo_llm = 0.006
costo_lookup = 0.0002
hit_rate = 0.35
# ahorro_neto = ...
# hit_rate_equilibrio = ...

# Ejercicio 3: lista con el orden elegido
orden = []

# Ejercicio 4:
# result = run_lab("retrieval", seed=106)
# assert result["kind"] == "retrieval" and result["evidence"]
result = None

# %% [markdown]
# ## Reflexión
#
# 1. Prompt caching y caché semántico ahorran cosas distintas. ¿Cuál elimina la llamada al LLM y cuál solo abarata el prefill, y por qué pueden (y suelen) convivir?
# 2. Si subes τ de 0.92 a 0.97, ¿qué pasa con el hit-rate, con los falsos aciertos y con el ahorro neto? ¿Qué datos necesitas para elegir τ de forma defendible?
# 3. ¿Por qué colocar la fecha actual en la primera línea del system prompt es un error caro con prompt caching, y dónde la colocarías?
