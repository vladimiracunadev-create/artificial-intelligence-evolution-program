# %% [markdown]
# # 107 — Knowledge graphs y GraphRAG
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Tripletas a mano.** Extrae las tripletas (con propiedades de año si
# aplica) del párrafo: "Alan Turing propuso la máquina de Turing en 1936. Durante la
# guerra trabajó en Bletchley Park, donde descifró Enigma junto a Gordon Welchman."
# Señala qué correferencia tuviste que resolver.
#
# **Ejercicio 2 — Leer Cypher.** Explica en una frase qué responde:
# `MATCH (a:Cientifico)-[:TRABAJÓ_EN]->(l:Lugar)<-[:TRABAJÓ_EN]-(b:Cientifico)
# WHERE a <> b RETURN a.nombre, b.nombre` — ¿cuántos "saltos" tiene el patrón?
#
# **Ejercicio 3 — ¿Vectorial o grafo?** Para cada pregunta decide si basta RAG vectorial
# o se justifica el grafo/GraphRAG: a) "¿qué dice el manual sobre el reinicio del
# router?", b) "¿qué empleados trabajaron en los tres proyectos cancelados?",
# c) "¿cuáles son los temas recurrentes en las 5 000 reclamaciones de este año?".
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("logic", seed=107)` y
# comprueba que el resultado incluye `kind == "logic"` y una lista `evidence` no vacía.

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1: lista de tuplas (sujeto, predicado, objeto, propiedades)
tripletas = [
    # ("Alan Turing", "PROPUSO", "máquina de Turing", {"año": 1936}),
]

# Ejercicio 2: escribe la interpretación como string
interpretacion_cypher = None

# Ejercicio 3: dict pregunta -> "vectorial" | "grafo" + justificación
eleccion = {"a": None, "b": None, "c": None}

# Ejercicio 4:
# result = run_lab("logic", seed=107)
# assert result["kind"] == "logic" and result["evidence"]
result = None

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué la pregunta "¿cuáles son los tres temas dominantes de este corpus?" es inalcanzable para un RAG vectorial top-k, y qué componente de GraphRAG la hace posible?
# 2. Si la resolución de entidades falla y "Meta" y "Facebook Inc." quedan como nodos separados, ¿qué tipo de consultas devuelven resultados incompletos sin dar ningún error?
# 3. El grafo extraído por LLM tiene apariencia de base de datos pero hereda alucinaciones del modelo. ¿Qué proceso de verificación propondrías antes de tratar una tripleta como hecho?
