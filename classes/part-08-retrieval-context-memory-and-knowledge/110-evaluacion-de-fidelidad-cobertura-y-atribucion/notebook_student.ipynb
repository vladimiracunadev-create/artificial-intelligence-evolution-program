# %% [markdown]
# # 110 — Evaluación de fidelidad, cobertura y atribución
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Métricas a mano.** Con
# `C = [1] "El fármaco fue aprobado en 2015." [2] "La dosis máxima es 40 mg diarios."`,
# `g = "Aprobado en 2015; dosis máxima 40 mg/día"` y
# `a = "El fármaco se aprobó en 2015 [1], la dosis máxima es 40 mg [2] y no tiene
# efectos secundarios [2]"` — calcula faithfulness, citation recall y citation
# precision. ¿Cuál es la afirmación más peligrosa y por qué su cita agrava el problema?
#
# **Ejercicio 2 — Diagnóstico.** Un sistema da faithfulness 0.95 y context recall 0.55.
# ¿Qué componente falla? ¿Y con faithfulness 0.60 y context recall 0.95? Indica en cada
# caso una intervención concreta (de las clases 100-106) que probarías primero.
#
# **Ejercicio 3 — Diseño del eval set.** Enumera 4 tipos de preguntas que debe contener
# un conjunto de evaluación RAG para un corpus de políticas internas, incluyendo al menos
# un tipo cuya respuesta correcta sea el rechazo.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("evaluation", seed=110)` y
# comprueba que el resultado incluye `kind == "evaluation"` y una lista `evidence` no vacía.

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1: (afirmación, ¿implicada por C?, cita, ¿la cita la respalda?)
claims = [
    # ("aprobado en 2015", True, 1, True),
]
# faithfulness = ...
# citation_recall = ...
# citation_precision = ...

# Ejercicio 2: escribe el diagnóstico de cada escenario
diagnostico_a = None  # faithfulness 0.95, context recall 0.55
diagnostico_b = None  # faithfulness 0.60, context recall 0.95

# Ejercicio 3: lista de 4 tipos de pregunta
tipos_eval = []

# Ejercicio 4:
# result = run_lab("evaluation", seed=110)
# assert result["kind"] == "evaluation" and result["evidence"]
result = None

# %% [markdown]
# ## Reflexión
#
# 1. Construye (mentalmente) un caso con faithfulness = 1.0 y respuesta factualmente falsa. ¿Qué componente del pipeline falló y qué métrica lo habría detectado?
# 2. ¿Por qué faithfulness puede monitorearse sobre tráfico real de producción pero context recall no? ¿Qué se necesita para cada una?
# 3. Si tu juez LLM concuerda con humanos en el 78 % de los veredictos de entailment, ¿qué significa un cambio de faithfulness de 0.85 a 0.88 entre dos versiones del sistema?
