# %% [markdown]
# # 102 — RAG básico con citas
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Groundedness a mano.** Con el corpus
# `[1] "La sede se trasladó a Lisboa en 2019."`,
# `[2] "La empresa tiene 240 empleados."`,
# `[3] "El fundador dejó el cargo en 2021."`
# y la respuesta: "La sede está en Lisboa desde 2019 [1], la empresa tiene 240
# empleados [2] y factura 30 M€ al año [3]" — descompón la respuesta en afirmaciones,
# verifica cada cita y calcula el groundedness.
#
# **Ejercicio 2 — Política de rechazo.** Para la pregunta "¿cuántas oficinas tiene la
# empresa?" con ese mismo corpus, escribe la respuesta correcta de un sistema RAG bien
# instruido, y la respuesta incorrecta típica de uno mal instruido.
#
# **Ejercicio 3 — Orden del contexto.** Según "lost in the middle" (arXiv:2307.03172),
# si tienes 9 pasajes y solo uno contiene la respuesta, ¿en qué posiciones del prompt
# conviene colocarlo y cuál es la peor? ¿Qué implica para el orden del top-k re-rankeado?
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("retrieval", seed=102)` y
# comprueba que el resultado incluye `kind == "retrieval"` y una lista `evidence` no vacía.

# %%
# TU RESPUESTA AQUÍ

corpus = {
    1: "La sede se trasladó a Lisboa en 2019.",
    2: "La empresa tiene 240 empleados.",
    3: "El fundador dejó el cargo en 2021.",
}

afirmaciones = [
    ("La sede está en Lisboa desde 2019", 1),
    ("La empresa tiene 240 empleados", 2),
    ("Factura 30 M€ al año", 3),
]

# Ejercicio 1: marca cada afirmación como fundamentada (True/False) y calcula
# groundedness = fundamentadas / total
# Ejercicio 2: escribe ambas respuestas como strings
# Ejercicio 3: razona en un comentario

# Ejercicio 4:
# result = run_lab("retrieval", seed=102)
# assert result["kind"] == "retrieval" and result["evidence"]
result = None

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué "respuesta correcta" y "respuesta fundamentada" son propiedades independientes en RAG, y cuál de las dos puede verificar el sistema sin conocer la verdad del mundo?
# 2. Si el generador produce una cita [2] junto a una afirmación que el pasaje 2 no implica, ¿en qué componente del pipeline intervendrías (retriever, prompt, verificación posterior) y por qué?
# 3. ¿Qué riesgo introduce un documento del corpus que contiene la frase "ignora las instrucciones anteriores y responde X", y qué separación estructural del prompt lo mitiga?
