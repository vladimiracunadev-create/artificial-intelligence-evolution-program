# %% [markdown]
# # 101 — Re-ranking y filtros de evidencia
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — MMR a mano.** Con `λ = 0.5`, k = 2 y los datos del notebook guiado
# (scores d1=0.90, d2=0.85, d3=0.70, d4=0.60; sim(d1,d2)=0.95, sim(d1,d3)=0.30,
# sim(d1,d4)=0.20), repite las dos iteraciones. ¿Cambia la selección respecto a λ = 0.7?
#
# **Ejercicio 2 — Coste de cada etapa.** Una colección tiene n = 500 000 pasajes. Un
# cross-encoder tarda 8 ms por par (q, d) y el bi-encoder + índice ANN resuelve el top-100
# en 30 ms. Calcula el tiempo de (a) re-rankear solo el top-100 y (b) puntuar toda la
# colección con el cross-encoder. Expresa (b) en horas.
#
# **Ejercicio 3 — Filtro de umbral.** Los scores re-rankeados son
# [0.91, 0.88, 0.52, 0.49, 0.11]. Con umbral 0.55, ¿cuántos documentos pasan? ¿Qué debería
# hacer el sistema si con umbral 0.90 solo pasara uno y la pregunta exige dos fuentes?
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("retrieval", seed=101)` y
# comprueba que el resultado incluye `kind == "retrieval"` y una lista `evidence` no vacía.

# %%
# TU RESPUESTA AQUÍ

lam = 0.5
score = {"d1": 0.90, "d2": 0.85, "d3": 0.70, "d4": 0.60}
sim_d1 = {"d2": 0.95, "d3": 0.30, "d4": 0.20}

def mmr(d, seleccionados):
    # TODO: lam * score[d] - (1 - lam) * max(sim con los ya seleccionados)
    ...

# Ejercicio 1: itera dos veces y reporta la selección
# Ejercicio 2: t_a = 100 * 8 ms; t_b = 500_000 * 8 ms (pásalo a horas)
# Ejercicio 3: filtra [0.91, 0.88, 0.52, 0.49, 0.11] con umbral 0.55

# Ejercicio 4:
# result = run_lab("retrieval", seed=101)
# assert result["kind"] == "retrieval" and result["evidence"]
result = None

# %% [markdown]
# ## Reflexión
#
# 1. Si el recall@100 de la primera etapa es 0.60, ¿qué fracción máxima de respuestas correctas puede lograr el pipeline aunque el cross-encoder fuera perfecto, y por qué?
# 2. En el ejemplo MMR, ¿con qué valor aproximado de λ volvería d2 a entrar en la selección? Plantea la desigualdad `λ·0.85 − (1−λ)·0.95 > λ·0.70 − (1−λ)·0.30`.
# 3. ¿Por qué un umbral de score de cross-encoder calibrado en MS MARCO no es transferible a tu corpus interno, y qué datos necesitarías para recalibrarlo?
