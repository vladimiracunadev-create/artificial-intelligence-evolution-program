# %% [markdown]
# # 108 — Memoria de corto y largo plazo
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Clasificar recuerdos.** Clasifica cada ítem como episódico, semántico o
# procedimental: a) "el usuario trabaja en zona horaria UTC-3", b) "el 14 de junio el
# deploy falló por certificado caducado", c) "antes de responder sobre precios, consultar
# la tabla vigente", d) "el cliente renovó contrato en enero", e) "el proyecto usa Python 3.11".
#
# **Ejercicio 2 — Presupuesto de compactación.** Un hilo tiene 6 000 tokens y el
# presupuesto es 3 000. El resumen ocupa 250 tokens y cada turno reciente ~220. ¿Cuántos
# turnos recientes caben junto al resumen? ¿Qué criterio usarías para elegir *cuáles*
# además de "los últimos"?
#
# **Ejercicio 3 — Diseño de olvido.** Propón (en 3-4 líneas) la política de olvido para
# un asistente de soporte: qué caduca con TTL, qué se sobrescribe, qué no debe borrarse
# nunca y por qué.
#
# **Ejercicio 4 — Contrato del laboratorio.** Ejecuta `run_lab("agent", seed=108)` y
# comprueba que el resultado incluye `kind == "agent"` y una lista `evidence` no vacía.

# %%
# TU RESPUESTA AQUÍ

# Ejercicio 1: dict item -> "episodica" | "semantica" | "procedimental"
clasificacion = {"a": None, "b": None, "c": None, "d": None, "e": None}

# Ejercicio 2:
presupuesto = 3000
resumen = 250
por_turno = 220
# turnos_que_caben = ...

# Ejercicio 3: escribe tu política como string multilínea
politica_olvido = None

# Ejercicio 4:
# result = run_lab("agent", seed=108)
# assert result["kind"] == "agent" and result["evidence"]
result = None

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué una ventana de contexto de un millón de tokens no elimina la necesidad de memoria de largo plazo? Da al menos dos razones independientes (coste, persistencia, atención).
# 2. En el ejemplo, ¿qué política aplicarías si la compactación extrae "prefiere respuestas detalladas" y el store ya contiene "prefiere brevedad"? Compara sobrescribir, versionar y preguntar.
# 3. ¿Por qué la memoria procedimental exige más control de escritura que la episódica? Razona en términos de radio de daño de un error.
