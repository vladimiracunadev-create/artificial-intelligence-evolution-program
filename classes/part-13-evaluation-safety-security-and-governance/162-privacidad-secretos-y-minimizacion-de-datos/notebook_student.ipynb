# %% [markdown]
# # 162 — Privacidad, secretos y minimización de datos
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Contrato del laboratorio.** Ejecuta `run_lab("safety", seed=162)` y verifica las
# claves `kind` y `evidence`. ¿Qué punto de fuga de datos crees que un contrato auditable como este
# ayuda a controlar?
#
# **Ejercicio 2 — Tasa de memorización a mano.** Un test con canarios da: 50 canarios a 1 aparición
# (3 extraídos), 30 a 10 apariciones (12 extraídos), 20 a 50 apariciones (15 extraídos). Calcula la
# tasa de extracción por grupo y la global. Explica por qué reportar solo la global oculta el riesgo.
#
# **Ejercicio 3 — Minimización en contexto.** Un agente de atención necesita el nombre y el número de
# pedido para consultar el estado. El sistema le pasa el registro completo del cliente (nombre,
# dirección, DNI, historial de compras, tarjeta). Reescribe qué campos debería recibir y nombra dos
# fugas que evita la minimización.
#
# **Ejercicio 4 — Elegir la técnica.** Para cada caso elige entre {redacción, seudonimización,
# tokenización de secretos, privacidad diferencial, retención/TTL}: (a) API keys que el sistema debe
# usar pero nunca mostrar; (b) publicar estadísticas agregadas de usuarios con garantía formal; (c)
# logs de soporte que deben conservarse 30 días y luego borrarse; (d) datasets de análisis donde hay
# que poder re-vincular al usuario internamente.

# %%
# Ejercicio 1
# TODO: ejecuta run_lab("safety", seed=162) y comprueba 'kind' y 'evidence'
result = None
# TU RESPUESTA AQUÍ

# %%
# Ejercicio 2 — verifica tu cálculo
grupos = {"1x": (3, 50), "10x": (12, 30), "50x": (15, 20)}  # (extraidos, total)
# TU RESPUESTA AQUÍ: tasa por grupo y global

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué la memorización es una propiedad esperable del entrenamiento y no un bug ocasional?
# 2. ¿Cuál de los cuatro puntos de fuga es el más barato de cerrar y por qué se descuida tanto?
# 3. ¿Qué garantiza y qué NO garantiza la privacidad diferencial?
