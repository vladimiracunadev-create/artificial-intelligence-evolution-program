# %% [markdown]
# # 163 — Sesgo, fairness y grupos afectados
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Contrato del laboratorio.** Ejecuta `run_lab("evaluation", seed=163)` y verifica
# las claves `kind` y `evidence`. ¿Por qué una auditoría de fairness necesita evidencia reproducible?
#
# **Ejercicio 2 — Disparate impact a mano.** Un proceso de selección evalúa 400 candidatos del grupo
# X (contratados 100) y 300 del grupo Y (contratados 45). Calcula la tasa de selección de cada grupo,
# identifica el desfavorecido, calcula el DI y aplica la regla del 80 %.
#
# **Ejercicio 3 — Igualdad de oportunidad.** Con estos datos calcula el TPR por grupo y di si se
# cumple igualdad de oportunidad:
# grupo X: 120 realmente aptos, 96 seleccionados entre ellos;
# grupo Y: 80 realmente aptos, 52 seleccionados entre ellos.
#
# **Ejercicio 4 — Elegir criterio.** Un banco usa el score como probabilidad de impago para fijar la
# tasa de interés. Argumenta en 3-4 frases qué criterio de equidad (calibración vs equalized odds) es
# más defendible aquí y qué se sacrifica al elegirlo (invoca a Kleinberg).

# %%
# Ejercicio 1
# TODO: ejecuta run_lab("evaluation", seed=163) y comprueba 'kind' y 'evidence'
result = None
# TU RESPUESTA AQUÍ

# %%
# Ejercicio 2 y 3 — verifica tus cálculos
seleccion = {"X": (100, 400), "Y": (45, 300)}       # (seleccionados, total)
aptos = {"X": (96, 120), "Y": (52, 80)}             # (seleccionados_aptos, aptos)
# TU RESPUESTA AQUÍ: tasas, desfavorecido, DI, regla 80%, TPR por grupo

# %% [markdown]
# ## Reflexión
#
# 1. ¿Cuál es la principal fuente de sesgo en la mayoría de los sistemas y por qué?
# 2. ¿Qué dice exactamente el teorema de imposibilidad de Kleinberg?
# 3. ¿Por qué DI ≥ 0.80 no basta para declarar un sistema justo?
