# %% [markdown]
# # 171 — Proyecto: respuesta a incidentes de IA
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Contrato del laboratorio.** Ejecuta `run_lab("capstone", seed=171)` y verifica las
# claves `kind` y `evidence`. ¿Qué fase del ciclo de IR se apoya más en tener evidencia reproducible?
#
# **Ejercicio 2 — Ordenar el ciclo.** Te dan estas acciones desordenadas: (a) correr la regresión con
# el caso reproducido; (b) desactivar la tool por feature flag; (c) documentar la causa raíz y añadir
# el caso al golden set; (d) confirmar el incidente y clasificar su severidad; (e) parchear la
# allowlist de destinatarios. Ordénalas según el ciclo de respuesta y nombra la fase de cada una.
#
# **Ejercicio 3 — Contención sin destruir evidencia.** Para un incidente de fuga de PII en los logs,
# propón dos acciones de contención *reversibles y que preserven evidencia* y una acción que NO harías
# por destruir evidencia, justificando por qué.
#
# **Ejercicio 4 — Diseñar el playbook.** Redacta un playbook mínimo (6-8 líneas) para el incidente
# "el asistente da consejos médicos peligrosos sin abstenerse": detección, severidad, contención,
# erradicación, recuperación y prevención, citando qué clase previa alimenta cada fase.

# %%
# Ejercicio 1
# TODO: ejecuta run_lab("capstone", seed=171) y comprueba 'kind' y 'evidence'
result = None
# TU RESPUESTA AQUÍ

# %%
# Ejercicio 2 — define el orden y la fase de cada acción
acciones = {
    "a": "correr regresión con el caso reproducido",
    "b": "desactivar la tool por feature flag",
    "c": "documentar causa raíz y añadir al golden set",
    "d": "confirmar el incidente y clasificar severidad",
    "e": "parchear la allowlist de destinatarios",
}
# TU RESPUESTA AQUÍ: lista ordenada de claves y la fase de cada una
orden = []

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué preparación y post-incidente son las fases más valiosas y más descuidadas?
# 2. ¿Qué distingue un incidente de IA de un simple bug?
# 3. ¿Cómo evita el post-mortem que un incidente se repita?
