# %% [markdown]
# # 168 — Alucinación, grounding y abstención
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Contrato del laboratorio.** Ejecuta `run_lab("evaluation", seed=168)` y verifica
# las claves `kind` y `evidence`. ¿Qué papel juega la lista `evidence` en un sistema con grounding?
#
# **Ejercicio 2 — Riesgo-cobertura a mano.** Con estas 8 respuestas (conf, correcta):
# (0.95,1),(0.9,1),(0.85,0),(0.8,1),(0.7,1),(0.65,0),(0.6,0),(0.55,1), calcula cobertura y riesgo
# selectivo para los umbrales 0.0, 0.8 y 0.9. ¿Qué umbral elegirías para un dominio legal y por qué?
#
# **Ejercicio 3 — Clasificar alucinaciones.** Indica si cada caso es intrínseco o extrínseco: (a) el
# resumen dice "el contrato vence en 2026" pero el documento dice 2025; (b) el modelo añade un
# teléfono de contacto que no aparece en ninguna fuente; (c) cita el "artículo 5" cuando la fuente
# solo tiene 4 artículos.
#
# **Ejercicio 4 — Diseñar la política.** Para un asistente de dosis de medicamentos, define la
# política de abstención y grounding: qué umbral, qué exige citar, cuándo deriva a un humano y qué
# métrica reportarías a los reguladores.

# %%
# Ejercicio 1
# TODO: ejecuta run_lab("evaluation", seed=168) y comprueba 'kind' y 'evidence'
result = None
# TU RESPUESTA AQUÍ

# %%
# Ejercicio 2 — verifica cobertura y riesgo
preds = [(0.95,1),(0.9,1),(0.85,0),(0.8,1),(0.7,1),(0.65,0),(0.6,0),(0.55,1)]
# TU RESPUESTA AQUÍ: para umbrales 0.0, 0.8, 0.9

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué la alucinación no se "parchea" sino que se gestiona?
# 2. ¿Qué relación hay entre calibración (clase 167) y abstención?
# 3. ¿Por qué la presencia de una cita no garantiza que la respuesta sea correcta?
