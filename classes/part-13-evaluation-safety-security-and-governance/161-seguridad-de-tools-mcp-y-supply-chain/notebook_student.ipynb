# %% [markdown]
# # 161 — Seguridad de tools, MCP y supply chain
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Contrato del laboratorio.** Ejecuta `run_lab("safety", seed=161)` y verifica las
# claves `kind` y `evidence`. ¿Qué plano de la superficie de tools (descripción/ejecución/supply
# chain) crees que modela un contrato de veredicto como este?
#
# **Ejercicio 2 — Identificar la amenaza.** Clasifica cada caso (confused deputy / tool poisoning /
# rug pull / supply chain): (a) un paquete `reqeusts` con una letra cambiada instala un backdoor;
# (b) la descripción de una tool le dice al modelo que exporte variables de entorno; (c) el agente
# usa su token de admin para borrar un bucket porque un ticket se lo pidió; (d) un servidor MCP
# benigno se actualiza y su tool ahora filtra datos.
#
# **Ejercicio 3 — Privilegio mínimo.** Un agente resume documentos de un bucket S3 y actualmente usa
# un token con `s3:*` sobre toda la cuenta. Propón el scope mínimo (acción + recurso + límites) y
# explica qué ataque concreto se vuelve imposible tras el cambio.
#
# **Ejercicio 4 — SBOM.** Describe qué campos mínimos incluirías por componente en un SBOM y cómo lo
# usarías el día que se publica un CVE. ¿Por qué el pinning sin SBOM es insuficiente?

# %%
# Ejercicio 1
# TODO: ejecuta run_lab("safety", seed=161) y comprueba 'kind' y 'evidence'
result = None
# TU RESPUESTA AQUÍ

# %%
# Ejercicio 2 — completa la clasificación
casos = {"a": None, "b": None, "c": None, "d": None}
# opciones: 'confused_deputy', 'tool_poisoning', 'rug_pull', 'supply_chain'
# TU RESPUESTA AQUÍ

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué "acotar la autoridad delegada" es mejor defensa que "instruir al modelo que no se deje engañar"?
# 2. ¿Qué diferencia hay entre tool poisoning y una inyección de prompt clásica (clase 160)?
# 3. ¿Qué añade el SBOM que el pinning por sí solo no da?
