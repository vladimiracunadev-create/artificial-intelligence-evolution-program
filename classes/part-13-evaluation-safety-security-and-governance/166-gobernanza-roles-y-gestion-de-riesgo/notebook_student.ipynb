# %% [markdown]
# # 166 — Gobernanza, roles y gestión de riesgo
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Contrato del laboratorio.** Ejecuta `run_lab("safety", seed=166)` y verifica las
# claves `kind` y `evidence`. ¿En cuál de las cuatro funciones del NIST AI RMF encaja generar
# evidencia estructurada como esta?
#
# **Ejercicio 2 — Clasificar por función.** Asigna cada actividad a GOVERN, MAP, MEASURE o MANAGE:
# (a) calcular el disparate impact por grupo; (b) nombrar un risk owner con autoridad para detener;
# (c) listar las partes afectadas y el uso previsto; (d) decidir mitigar vs aceptar un riesgo.
#
# **Ejercicio 3 — Matriz de riesgo a mano.** Un chatbot de salud tiene: R1 (consejo médico erróneo)
# P=3 I=5; R2 (caída del servicio) P=4 I=2; R3 (fuga de historial) P=2 I=5. Calcula P·I, ordena por
# prioridad y propón un tratamiento (mitigar/aceptar/transferir/evitar) para cada uno.
#
# **Ejercicio 4 — Tres líneas.** Para el chatbot anterior, asigna a la 1ª, 2ª y 3ª línea de defensa
# quién: (i) implementa el filtro de consejo médico, (ii) define la política y el umbral de derivación
# a un médico, (iii) verifica que la derivación ocurre en la práctica. Explica por qué (iii) debe ser
# independiente.

# %%
# Ejercicio 1
# TODO: ejecuta run_lab("safety", seed=166) y comprueba 'kind' y 'evidence'
result = None
# TU RESPUESTA AQUÍ

# %%
# Ejercicio 3 — verifica prioridades
riesgos = {"R1": (3, 5), "R2": (4, 2), "R3": (2, 5)}  # (P, I)
# TU RESPUESTA AQUÍ: P*I por riesgo y orden de prioridad

# %% [markdown]
# ## Reflexión
#
# 1. ¿Qué distingue la gobernanza real del "teatro de cumplimiento"?
# 2. ¿Por qué la 3ª línea debe ser independiente de la 1ª y la 2ª?
# 3. ¿Qué significa aceptar un riesgo residual?
