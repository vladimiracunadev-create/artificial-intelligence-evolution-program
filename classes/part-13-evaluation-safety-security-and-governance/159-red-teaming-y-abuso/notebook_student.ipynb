# %% [markdown]
# # 159 — Red teaming y abuso
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Contrato del laboratorio.** Ejecuta `run_lab("safety", seed=159)` y verifica las
# claves `kind` y `evidence`. ¿Qué familia de la taxonomía ejercita este laboratorio?
#
# **Ejercicio 2 — Modelo de amenazas.** Para un tutor de IA escolar (chat, sin herramientas),
# escribe un modelo de amenazas con: 2 perfiles de adversario, su objetivo, su capacidad y la
# superficie que usarían. No escribas prompts de ataque: describe la *categoría* del intento.
#
# **Ejercicio 3 — ASR a mano.** Un ejercicio registra: elusión 3/60 éxitos, extracción 1/25,
# abuso 9/40. Calcula el ASR por familia y el agregado. Explica en 2-3 frases por qué el agregado
# es la peor cifra para tomar decisiones si la extracción expone datos personales.
#
# **Ejercicio 4 — Del hallazgo a la regresión.** Toma un hallazgo hipotético ("el asistente revela
# su system prompt ante cierta reformulación") y redacta el ítem de golden set resultante: entrada
# (descrita, no literal), veredicto esperado, severidad y criterio de re-test.

# %%
# Ejercicio 1
# TODO: ejecuta run_lab("safety", seed=159) y comprueba 'kind' y 'evidence'
result = None
# TU RESPUESTA AQUÍ

# %%
# Ejercicio 3 — verifica tu cálculo
intentos = {"elusion": (3, 60), "extraccion": (1, 25), "abuso": (9, 40)}
# TU RESPUESTA AQUÍ: asr por familia y agregado

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué el red teaming nunca demuestra ausencia de fallos?
# 2. ¿Qué distingue un ejercicio de red teaming responsable de la publicación de jailbreaks?
# 3. ¿Con qué frecuencia debería repetirse el ejercicio y qué eventos lo disparan?
