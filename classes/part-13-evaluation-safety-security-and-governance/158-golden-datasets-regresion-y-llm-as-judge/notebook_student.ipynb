# %% [markdown]
# # 158 — Golden datasets, regresión y LLM-as-judge
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Contrato del laboratorio.** Ejecuta `run_lab("evaluation", seed=158)` y verifica
# las claves `kind` y `evidence`. ¿Qué papel jugaría este JSON en una suite de regresión?
#
# **Ejercicio 2 — Kappa a mano.** Un juez y un humano califican 100 respuestas:
# juez acepta 60 (de las cuales el humano acepta 48); juez rechaza 40 (de las cuales el humano
# rechaza 28). Calcula a mano p_o, p_e y kappa de Cohen. Clasifica el acuerdo con la guía
# (<0.2 pobre, 0.2-0.4 débil, 0.4-0.6 moderado, 0.6-0.8 sustancial, >0.8 casi perfecto).
#
# **Ejercicio 3 — Sesgo de posición.** Diseña (en texto) un protocolo de comparación A/B con juez
# que neutralice el sesgo de posición. ¿Qué haces con los veredictos inconsistentes entre órdenes?
#
# **Ejercicio 4 — Diseño de golden set.** Escribe 5 ítems (entrada + salida esperada + severidad)
# para un bot que responde preguntas sobre políticas de reembolso. Al menos uno debe ser un caso
# borde y uno un caso de riesgo (p. ej. petición de excepción indebida).

# %%
# Ejercicio 1
# TODO: ejecuta run_lab("evaluation", seed=158) y comprueba 'kind' y 'evidence'
result = None
# TU RESPUESTA AQUÍ

# %%
# Ejercicio 2 — verifica tu cálculo manual
# Contingencia: juez_acepta&humano_acepta=48, juez_acepta&humano_rechaza=12,
#               juez_rechaza&humano_acepta=12, juez_rechaza&humano_rechaza=28
# TU RESPUESTA AQUÍ: p_o, p_e, kappa

# %% [markdown]
# ## Reflexión
#
# 1. ¿Por qué kappa y no acuerdo bruto para calibrar un juez?
# 2. ¿Qué sesgos del LLM-as-judge documenta Zheng et al. y cuál te parece más peligroso en tu caso de uso?
# 3. ¿Cuándo un ítem del golden set debe cambiar de etiqueta y quién debe aprobarlo?
