# %% [markdown]
# # 157 — Diseño de evaluaciones y criterios de éxito
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Contrato del laboratorio.** Ejecuta `run_lab("evaluation", seed=157)` y comprueba
# que el resultado incluye las claves `kind` y `evidence`. ¿Qué elemento del contrato de una eval
# (D, T, M, C) representa la semilla?
#
# **Ejercicio 2 — Baseline a mano.** Un test tiene 500 correos, 25 son phishing. Un filtro marca 40
# como phishing y acierta 20. Calcula a mano: accuracy del baseline trivial ("todo legítimo"),
# accuracy del filtro, recall y precisión de la clase phishing. ¿Qué métrica reportarías como
# principal y por qué?
#
# **Ejercicio 3 — Detectar contaminación.** Un modelo obtiene 95 % en un benchmark público y 62 %
# en una versión parafraseada de los mismos ítems. Escribe 2-3 frases: ¿qué hipótesis explica la
# caída y qué experimento adicional la confirmaría o descartaría?
#
# **Ejercicio 4 — Metric shopping.** Da un ejemplo concreto de cómo elegir la métrica *después* de
# ver los resultados puede hacer aprobar un sistema que no cumple su constructo.

# %%
# Ejercicio 1
# TODO: ejecuta run_lab("evaluation", seed=157) y comprueba 'kind' y 'evidence'
result = None
# TU RESPUESTA AQUÍ

# %%
# Ejercicio 2 — calcula y verifica con Python
total, phishing = 500, 25
marcados, aciertos = 40, 20
# TU RESPUESTA AQUÍ: accuracy_baseline, accuracy_filtro, recall, precision

# %% [markdown]
# ## Reflexión
#
# 1. Si un modelo sube 15 puntos en MMLU entre dos versiones, ¿qué chequeo harías antes de
#    atribuirlo a mejor razonamiento y no a contaminación?
# 2. ¿Por qué el criterio de éxito debe declararse antes de medir?
# 3. ¿Qué costo de error domina en tu dominio de trabajo y cómo debería reflejarse en la métrica?
