# %% [markdown]
# # 167 — Normativa, auditoría y evidencia
#
# Este notebook reutiliza el mismo núcleo ejecutable que `lab.py`. El objetivo no es
# ocultar la implementación, sino separar exploración, ejercicio y solución.
#
# **Evidencia esperada:** resultado JSON, interpretación de una decisión y una
# limitación documentada.

# %%
from ai_evolution.labs import run_lab
import json

def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Ejercicios
#
# **Ejercicio 1 — Contrato del laboratorio.** Ejecuta `run_lab("safety", seed=167)` y verifica las
# claves `kind` y `evidence`. ¿Cómo encaja un resultado reproducible en la cadena de evidencia de una
# auditoría?
#
# **Ejercicio 2 — Clasificar por riesgo.** Asigna cada sistema a un nivel del EU AI Act (inaceptable/
# alto/limitado/mínimo): (a) filtro de spam de correo; (b) IA que evalúa exámenes para admisión
# universitaria; (c) chatbot de atención que se identifica como IA; (d) scoring social de ciudadanos
# por comportamiento.
#
# **Ejercicio 3 — Model card vs datasheet.** Clasifica cada ítem como propio de una model card o de
# una datasheet: (i) disparate impact por grupo; (ii) cómo se recolectaron y consintieron los datos;
# (iii) usos no recomendados del modelo; (iv) qué representa cada instancia del dataset y si contiene PII.
#
# **Ejercicio 4 — Mapear evidencia.** Para un sistema de diagnóstico por imagen (alto riesgo), enumera
# 4 obligaciones del AI Act y, para cada una, qué artefacto de las clases 157-166 la evidencia.

# %%
# Ejercicio 1
# TODO: ejecuta run_lab("safety", seed=167) y comprueba 'kind' y 'evidence'
result = None
# TU RESPUESTA AQUÍ

# %%
# Ejercicio 2 y 3 — completa
niveles = {"a": None, "b": None, "c": None, "d": None}  # inaceptable|alto|limitado|minimo
fichas = {"i": None, "ii": None, "iii": None, "iv": None}  # 'model_card'|'datasheet'
# TU RESPUESTA AQUÍ

# %% [markdown]
# ## Reflexión
#
# 1. ¿Qué determina el nivel de riesgo de un sistema según el EU AI Act?
# 2. ¿Por qué se documentan por separado el modelo y el dataset?
# 3. ¿Qué diferencia una auditoría con evidencia de una mera declaración de cumplimiento?
