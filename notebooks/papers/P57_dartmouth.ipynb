# %% [markdown]
# # P57 — Propuesta para el proyecto de investigación de verano de Dartmouth sobre inteligencia artificial
#
# ## 1. Título y paper
#
# **Paper:** *A Proposal for the Dartmouth Summer Research Project on Artificial Intelligence*
# **Autoría:** John McCarthy, Marvin L. Minsky, Nathaniel Rochester, Claude E. Shannon
# **Año y venue:** 1955 · Solicitud a la Fundación Rockefeller · reimpresa en AI Magazine 27(4), 2006
# **Nivel:** L1 · **Motor:** `dartmouth`
# **Ficha completa:** [`P57_dartmouth`](../../papers/foundational/P57_dartmouth/README.md)
#
# **Hito:** Bautiza el campo y fija su agenda: siete temas que aún organizan buena parte de la investigación.
#
# - [Texto original (archivo de John McCarthy, Stanford)](http://jmc.stanford.edu/articles/dartmouth/dartmouth.pdf)
# - [DOI de la reimpresión en AI Magazine (2006)](https://doi.org/10.1609/aimag.v27i4.1904)
#
# > Este notebook implementa una **miniatura** del mecanismo. No reproduce el experimento original ni sus métricas: reproduce la idea para que se pueda inspeccionar y discutir.

# %% [markdown]
# ## 2. Objetivos
#
# 1. Explicar qué problema resolvió el paper: Los trabajos sobre autómatas, redes nerviosas, teoría de la información y resolución de problemas avanzaban por separado y sin un nombre común ni una agenda compartida.
# 2. Ejecutar una implementación mínima de la propuesta: Reunir a diez investigadores durante dos meses sobre la conjetura de que todo aspecto del aprendizaje puede describirse con precisión suficiente para simularlo.
# 3. Predecir el resultado antes de ejecutar, y contrastar la predicción con la salida.
# 4. Identificar al menos una limitación de la miniatura y una del paper original.
# 5. Conectar el hito con el siguiente eslabón de la ruta.

# %% [markdown]
# ## 3. Prerrequisitos
#
# - Python 3.11+ y el paquete del programa instalado (`pip install -e .`).
# - Haber leído la guía [método de lectura en 5 pasadas](../../papers/guides/METODO_DE_LECTURA_EN_5_PASADAS.md).
# - Hitos previos:
# - P56
# - Shannon (1948), teoría de la información
# - Wiener (1948), cibernética

# %% [markdown]
# ## 4. Intuición
#
# Diez personas, dos meses de verano y una lista de siete problemas. La propuesta de 1955 no trae resultados: trae un nombre —«inteligencia artificial»— y una agenda. Setenta años después, seis de esos siete temas tienen respuesta y uno sigue abierto.

# %% [markdown]
# ## 5. Concepto mínimo
#
# ```text
# Los siete temas propuestos en 1955:
#     1. computadoras automáticas          5. automejora
#     2. usar lenguaje                     6. abstracciones
#     3. redes de neuronas                 7. aleatoriedad y creatividad
#     4. teoría del tamaño de un cálculo
#
# Conjetura fundacional: todo aspecto del aprendizaje puede describirse con
# precisión suficiente para que una máquina lo simule.
# ```

# %% [markdown]
# ## 6. Código explicado
#
# El motor aísla el mecanismo del paper con datos de juguete y salida inspeccionable.

# %%
import json
import pathlib
import sys

ROOT = pathlib.Path.cwd()
while not (ROOT / "pyproject.toml").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

from ai_evolution.papers_lab import run_paper_lab


def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %%
r = run_paper_lab('dartmouth', seed=7)['result']
show(r)

# %% [markdown]
# ## 7. Predicción antes de ejecutar
#
# 1. ¿Cuántos años tardó de media cada tema en tener un resultado sólido?
# 2. ¿Cuál tardó más?
# 3. ¿Cuál sigue abierto?
#
# > Escribe tu respuesta aquí antes de continuar.

# %% [markdown]
# ## 8. Experimento controlado
#
# Se varía una sola cosa y se observa el efecto.

# %%
for semilla in (1, 7, 42):
    r = run_paper_lab('dartmouth', seed=semilla)
    print(f'semilla {semilla:>2} · evidencia principal:')
    for e in r['evidence']:
        print('   +', e)
    break  # determinista: basta una para ver la estructura
for semilla in (1, 7, 42):
    r = run_paper_lab('dartmouth', seed=semilla)['result']
    print(f'semilla {semilla:>2} → claves: {list(r)[:4]}')

# %% [markdown]
# ## 9. Salida interpretable
#
# La media es de 25,5 años frente a los dos meses previstos. El que más tardó es el lenguaje: 62 años hasta el Transformer. Y el que sigue abierto es la **automejora**, que es justamente lo que hoy se discute en los agentes que se corrigen a sí mismos.

# %% [markdown]
# ## 10. Comentario pedagógico
#
# Este es el documento que hay que tener a mano cada vez que alguien anuncia un plazo. No porque sus autores fueran ingenuos —eran de los mejores del campo— sino porque el error de estimación en IA es estructural: se subestima lo que parece fácil para una persona.

# %% [markdown]
# ## 11. Error o anti-patrón deliberado
#
# Anti-patrón: tratar la propuesta como un paper con resultados.

# %%
print('No hay experimentos, ni datos, ni evaluacion: es una solicitud de financiacion.')
print('Pedian 13.500 dolares. Citarla como evidencia de algo es un error de categoria.')
print('Su valor es historico y programatico, no empirico.')

# %% [markdown]
# ## 12. Corrección
#
# Lo que sí aporta el documento:

# %%
r = run_paper_lab('dartmouth', seed=7)['result']
print('temas propuestos      :', len(r['temas']))
print('con resultado solido  :', r['temas_con_resultado_solido'])
print('abiertos              :', r['temas_abiertos'])
print('media de anios        :', r['media_de_anios_hasta_el_resultado'])
print('aporta un NOMBRE y una AGENDA, no un metodo.')

# %% [markdown]
# ## 13. Desafío guiado
#
# Discute la columna `anio_resultado`: elige un tema y argumenta una fecha distinta a la del motor. Cualquier fecha defendible sirve si viene con criterio.

# %%
r = run_paper_lab('dartmouth', seed=3)['result']
show(r)

# %% [markdown]
# ## 14. Desafío autónomo
#
# Escribe la propuesta de Dartmouth para 2026: siete problemas abiertos, con criterio explícito de qué contaría como resuelto. Después busca en el temario del programa dónde vive cada uno.

# %% [markdown]
# ## 15. Evidencia de aprendizaje
#
# Guarda la tabla de los siete temas con su año de resolución y tu argumento sobre el tema que sigue abierto.
#
# Autoevaluación y respuestas esperadas: [ficha del paper](../../papers/foundational/P57_dartmouth/README.md) · evaluación formal: [`assessments/papers/P57_dartmouth.md`](../../assessments/papers/P57_dartmouth.md)

# %% [markdown]
# ## 16. Cierre
#
# El campo ya tiene nombre y agenda. Veinte años después, dos de sus fundadores enuncian qué han aprendido: que todo se reduce a símbolos y a búsqueda.

# %% [markdown]
# ## 17. Conexión con el siguiente hito
#
# - P01
# - P58
#
# Ruta completa: [`papers/ROADMAP.md`](../../papers/ROADMAP.md)
