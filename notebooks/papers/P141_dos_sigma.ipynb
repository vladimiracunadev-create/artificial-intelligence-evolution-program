# %% [markdown]
# # P141 — El problema de las dos sigmas: buscar instrucción grupal tan eficaz como la tutoría individual
#
# ## 1. Título y paper
#
# **Paper:** *The 2 Sigma Problem: The Search for Methods of Group Instruction as Effective as One-to-One Tutoring*
# **Autoría:** Benjamin S. Bloom
# **Año y venue:** 1984 · Educational Researcher, 13(6), 4–16
# **Nivel:** L1 · **Motor:** `dos_sigma`
# **Ficha completa:** [`P141_dos_sigma`](../../papers/foundational/P141_dos_sigma/README.md)
#
# **Hito:** Cuantifica en desviaciones típicas cuánto mejora la tutoría individual sobre la clase convencional, y convierte esa cifra en un problema de ingeniería educativa.
#
# - [JSTOR 1175554 · doi:10.2307/1175554](https://www.jstor.org/stable/1175554)
#
# > Este notebook implementa una **miniatura** del mecanismo. No reproduce el experimento original ni sus métricas: reproduce la idea para que se pueda inspeccionar y discutir.

# %% [markdown]
# ## 2. Objetivos
#
# 1. Explicar qué problema resolvió el paper: La tutoría uno a uno funciona muchísimo mejor que la clase convencional, y es imposible de desplegar: exige un docente por alumno. Sin una medida comparable entre asignaturas y exámenes, no se podía ni discutir cuánto se pierde por no poder pagarla.
# 2. Ejecutar una implementación mínima de la propuesta: Medir el efecto en desviaciones típicas —el tamaño del efecto— y plantear explícitamente el problema: encontrar métodos de instrucción **grupal** que consigan el efecto de la tutoría. El aprendizaje para el dominio consigue la mitad con coste de clase convencional.
# 3. Predecir el resultado antes de ejecutar, y contrastar la predicción con la salida.
# 4. Identificar al menos una limitación de la miniatura y una del paper original.
# 5. Conectar el hito con el siguiente eslabón de la ruta.

# %% [markdown]
# ## 3. Prerrequisitos
#
# - Python 3.11+ y el paquete del programa instalado (`pip install -e .`).
# - Haber leído la guía [método de lectura en 5 pasadas](../../papers/guides/METODO_DE_LECTURA_EN_5_PASADAS.md).
# - Hitos previos:

# %% [markdown]
# ## 4. Intuición
#
# La tutoría uno a uno mueve al alumno medio **dos desviaciones típicas**. Y exige un docente por alumno, así que el hallazgo no es la tutoría: es el problema que plantea.

# %% [markdown]
# ## 5. Concepto mínimo
#
# ```text
# clase convencional          σ + 0   → 52 % supera al alumno medio
# aprendizaje para el dominio σ + 1   → 85 %
# tutoría uno a uno           σ + 2   → 97,5 %
#
# el efecto se mide en DESVIACIONES, para poder comparar entre asignaturas
# ```

# %% [markdown]
# ## 6. Código explicado
#
# El motor aísla el mecanismo del paper con datos de juguete y salida inspeccionable.

# %%
import json
import pathlib
import sys

ROOT = pathlib.Path.cwd()
while not (ROOT / "pyproject.toml").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

from ai_evolution.papers_lab import run_paper_lab


def show(value):
    print(json.dumps(value, ensure_ascii=False, indent=2))

# %%
r = run_paper_lab('dos_sigma', seed=7)['result']
show(r)

# %% [markdown]
# ## 7. Predicción antes de ejecutar
#
# 1. ¿Qué fracción de los tutorizados supera al alumno medio convencional?
# 2. ¿Y con aprendizaje para el dominio?
# 3. ¿Cuántos docentes exige cada opción?
#
# > Escribe tu respuesta aquí antes de continuar.

# %% [markdown]
# ## 8. Experimento controlado
#
# Se varía una sola cosa y se observa el efecto.

# %%
for semilla in (1, 7, 42):
    r = run_paper_lab('dos_sigma', seed=semilla)
    print(f'semilla {semilla:>2} · evidencia principal:')
    for e in r['evidence']:
        print('   +', e)
    break  # determinista: basta una para ver la estructura
for semilla in (1, 7, 42):
    r = run_paper_lab('dos_sigma', seed=semilla)['result']
    print(f'semilla {semilla:>2} → claves: {list(r)[:4]}')

# %% [markdown]
# ## 9. Salida interpretable
#
# Tutoría: el **97,5 %** supera al alumno medio convencional, frente al **52,2 %** esperable por azar. Aprendizaje para el dominio: **85,0 %** — la mitad del efecto. Y el coste: **400** docentes para 400 alumnos frente a **14**.

# %% [markdown]
# ## 10. Comentario pedagógico
#
# Ese contraste de coste es el artículo entero. Bloom no está demostrando que la tutoría funcione —eso ya se sabía—: está formulando el problema de encontrar cómo conseguir su efecto **en grupo**. Cuarenta años después, esa formulación es exactamente la promesa que se le hace a la IA educativa, y conviene recordar que el propio Bloom advertía que sus estudios eran cortos y en asignaturas concretas.

# %% [markdown]
# ## 11. Error o anti-patrón deliberado
#
# Anti-patrón: citar «2 sigma» como si fuera una constante de la naturaleza.

# %%
print('Las replicas posteriores encuentran efectos menores que 2 sigma.')
print('VanLehn (2011) mide los tutores inteligentes cerca de 0,76 sigma.')
print('La cifra se cita con mas confianza de la que el propio articulo pide.')

# %% [markdown]
# ## 12. Corrección
#
# El efecto y su coste, lado a lado:

# %%
r = run_paper_lab('dos_sigma', seed=3)['result']
for c in r['condiciones']:
    print(c)
for c in r['coste_de_cada_condicion']:
    print(c)

# %% [markdown]
# ## 13. Desafío guiado
#
# Explica por qué medir en desviaciones típicas permite comparar entre asignaturas y exámenes distintos, y qué se pierde al hacerlo.

# %%
r = run_paper_lab('dos_sigma', seed=3)['result']
show(r)

# %% [markdown]
# ## 14. Desafío autónomo
#
# Busca el tamaño del efecto reportado por una herramienta educativa que conozcas. Comprueba si lo declara y contra qué línea base.

# %% [markdown]
# ## 15. Evidencia de aprendizaje
#
# Guarda la cifra —o la constatación de que no la declara—.
#
# Autoevaluación y respuestas esperadas: [ficha del paper](../../papers/foundational/P141_dos_sigma/README.md) · evaluación formal: [`assessments/papers/P141_dos_sigma.md`](../../assessments/papers/P141_dos_sigma.md)

# %% [markdown]
# ## 16. Cierre
#
# Abre la ruta de gobernanza: qué se puede prometer, qué se puede medir y quién responde.

# %% [markdown]
# ## 17. Conexión con el siguiente hito
#
#
#
# Ruta completa: [`papers/ROADMAP.md`](../../papers/ROADMAP.md)
